# %%
from bs4 import BeautifulSoup as bs
import requests as req
import pandas as pd

# %%
base_url='https://www.instiz.net/pt?page=1'
headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.54 Safari/537.36"}

# %%
cnt=1
result=[]
for i in range(1,11):
    params={"page":i}
    raw=req.get(base_url,params=params, headers=headers)
    soup=bs(raw.content, 'html.parser')
    contents = soup.find_all('tr')
    del contents[:20]
    del contents[19:len(contents)]
    
    for i in contents:
        tmp={}
        print('-'*15)
        print(cnt)
        cnt=cnt+1


        # 제목 추출
        title=i.find('span',{"id":"subject"}).text.strip()
        print("제목: ", title)



        # 글쓴이 추출
        writer_tag = i.find('td', {"class":"minitext2 listnm"})
        if writer_tag is not None: # None 값이 있으므로 조건문을 통해 회피 
            writer = writer_tag.text

        else:
            writer = "없음"
        print("글쓴이: ", writer)

    #     # 유동이나 고닉이 아닌 글쓴이 옆에 있는 ip 추출
    #     ip_tag = i.find('td', class_='gall_writer ub-writer').find('span', class_='ip')
    #     if ip_tag is not None:  # None 값이 있으므로 조건문을 통해 회피 
    #         ip = ip_tag.text
    #         print("ip: ", ip)



        # 날짜 추출 
        date=i.find('td',{"class":"listno regdate"}).text
        print("날짜: ",date)


        # 조회 수 추출
        views = i.find_all('td', {"class":"listno"})[2].text
        print("조회수: ", views)


        # 댓글 수
        comment=i.find('a',{"id":"view_cmt"})
        if comment==None:
            comment=0
        else:
            comment=comment.text
        print("댓글수: ", comment)

        # 추천 수 추출
        recommend = i.find_all('td', {"class":"listno"})[3].text
        print("추천수: ", recommend)


        tmp['제목']=title
        tmp['글쓴이']=writer
        tmp['날짜']=date
        tmp['조회수']=views
        tmp['댓글수']=comment
        tmp['추천수']=recommend

        result.append(tmp)
# Out:
# ---------------
# 1
# 제목:  생일파티한 한소희 목걸이 귀걸이 브랜드.. 대박 예쁨
# 글쓴이:  누눈나난
# 날짜:  17:59
# 조회수:  207
# 댓글수:  0
# 추천수:  0
# ---------------
# 2
# 제목:  "새끼 길고양이 얼굴을 토치로 불질러”...경찰, 수사 착수
# 글쓴이:  MANSAE
# 날짜:  17:59
# 조회수:  186
# 댓글수:  2
# 추천수:  0
# ---------------
# 3
# 제목:  화려수수 조합으로 데뷔 첫 화보 찍은 여돌
# 글쓴이:  버가버가뷰
# 날짜:  17:56
# 조회수:  227
# 댓글수:  0
# 추천수:  0
# ---------------
# 4
# 제목:  붐 담당 일진.jpg
# 글쓴이:  윤정한 아내
# 날짜:  17:55
# 조회수:  386
# 댓글수:  1
# 추천수:  0
# ---------------
# 5
# 제목:  젤다의 전설 안해본 사람들은 잘 모르는 것 jpg
# 글쓴이:  몹시호시
# 날짜:  17:51
# 조회수:  785
# 댓글수:  3
# 추천수:  0
# ---------------
# 6
# 제목:  황당해진 대만 상황
# 글쓴이:  알케이
# 날짜:  17:51
# 조회수:  952
# 댓글수:  1
# 추천수:  0
# ---------------
# 7
# 제목:  정상수에게 직접듣는 킬링벌스 소감 및 카운팅스타
# 글쓴이:  큐랑둥이
# 날짜:  17:51
# 조회수:  4
# 댓글수:  0
# 추천수:  0
# ---------------
# 8
# 제목:  신서유기 연말굿즈.jpg
# 글쓴이:  Twenty_Four
# 날짜:  17:51
# 조회수:  739
# 댓글수:  0
# 추천수:  0
# ---------------
# 9
# 제목:  편의점 성추행 벌금 100만원
# 글쓴이:  ~~
# 날짜:  17:48
# 조회수:  738
# 댓글수:  0
# 추천수:  0
# ---------------
# 10
# 제목:  붐이 홈쇼핑 못 나오는 이유.JPG
# 글쓴이:  션국이네 메르
# 날짜:  17:48
# 조회수:  1034
# 댓글수:  3
# 추천수:  0
# ---------------
# 11
# 제목:  필력 미친 홈플러스더클럽 인스타그램 게시물.jpg
# 글쓴이:  나천재
# 날짜:  17:45
# 조회수:  1500
# 댓글수:  1
# 추천수:  1
# ---------------
# 12
# 제목:  냄새에 정신줄 놓은 고양이들 영상 모음
# 글쓴이:  누눈나난
# 날짜:  17:41
# 조회수:  369
# 댓글수:  0
# 추천수:  1
# ---------------
# 13
# 제목:  레전드 충김볶 레시피에 이은 박나래 해장주스 레시피
# 글쓴이:  야들아해장하
# 날짜:  17:31
# 조회수:  2671
# 댓글수:  1
# 추천수:  0
# ---------------
# 14
# 제목:  [충격] 이재명 수행실장 한준호 前 아나 "영부인 출산해야 국격 높아져"...
# 글쓴이:  햅뿌
# 날짜:  17:30
# 조회수:  3379
# 댓글수:  9
# 추천수:  0
# ---------------
# 15
# 제목:  한국인으로 이루어진 남자아이돌 그룹
# 글쓴이:  강쥐강아쥐
# 날짜:  17:29
# 조회수:  1163
# 댓글수:  0
# 추천수:  1
# ---------------
# 16
# 제목:  판) 십몇년 전 입양보낸 아이를 찾는 것... 너무 이기적일까요
# 글쓴이:  겟
# 날짜:  17:25
# 조회수:  6283
# 댓글수:  18
# 추천수:  3
# ---------------
# 17
# 제목:  추억의 전략 시뮬레이션 게임.jpgif
# 글쓴이:  김용국 아내
# 날짜:  17:22
# 조회수:  1165
# 댓글수:  0
# 추천수:  0
# ---------------
# 18
# 제목:  그동안 자료 공개를 막는 협박에 시달렸다 박동희 대표 기자
# 글쓴이:  사랑을먹고자
# 날짜:  17:19
# 조회수:  430
# 댓글수:  0
# 추천수:  0
# ---------------
# 19
# 제목:  이센스 인생곡
# 글쓴이:  토끼네
# 날짜:  17:15
# 조회수:  227
# 댓글수:  0
# 추천수:  0
# ---------------
# 20
# 제목:  라면의 면발이 노란색인 이유
# 글쓴이:  겟
# 날짜:  17:14
# 조회수:  5299
# 댓글수:  13
# 추천수:  1
# ---------------
# 21
# 제목:  해리포터 팬들이 뽑은 시리즈 최악의 영화
# 글쓴이:  세븐틴 비니
# 날짜:  17:11
# 조회수:  5520
# 댓글수:  15
# 추천수:  9
# ---------------
# 22
# 제목:  섹시를 잘못 이해하고 있는 남돌
# 글쓴이:  몽몽댕
# 날짜:  17:08
# 조회수:  2184
# 댓글수:  0
# 추천수:  0
# ---------------
# 23
# 제목:  윾쾌한 식당 아지매.jpg
# 글쓴이:  류준열 강다니
# 날짜:  17:06
# 조회수:  2089
# 댓글수:  0
# 추천수:  0
# ---------------
# 24
# 제목:  시대를 앞서갔던 20년전 게임
# 글쓴이:  sweetly
# 날짜:  17:04
# 조회수:  2720
# 댓글수:  0
# 추천수:  1
# ---------------
# 25
# 제목:  사과티비 수위 ㄹㅇ 실화냐 ㄷㄷ...
# 글쓴이:  sweetly
# 날짜:  17:00
# 조회수:  14658
# 댓글수:  46
# 추천수:  11
# ---------------
# 26
# 제목:  지난주 구내식당 생선 메뉴
# 글쓴이:  초코틴틴세븐
# 날짜:  17:00
# 조회수:  2129
# 댓글수:  0
# 추천수:  0
# ---------------
# 27
# 제목:  우동이 짜다
# 글쓴이:  다시 태어날
# 날짜:  17:00
# 조회수:  1290
# 댓글수:  0
# 추천수:  0
# ---------------
# 28
# 제목:  난 이 음료수들 눈감고 마시면 다 구별 가능하다 vs 아니다
# 글쓴이:  김상연
# 날짜:  17:00
# 조회수:  1283
# 댓글수:  1
# 추천수:  0
# ---------------
# 29
# 제목:  한문철아님) 형사전문변호사에게 보복운전한 운전자
# 글쓴이:  패딩조끼
# 날짜:  17:00
# 조회수:  1587
# 댓글수:  0
# 추천수:  0
# ---------------
# 30
# 제목:  신곡 낸 에이브릴 라빈
# 글쓴이:  She
# 날짜:  16:58
# 조회수:  247
# 댓글수:  0
# 추천수:  0
# ---------------
# 31
# 제목:  논두렁에 꼬라박는 오토바이.gif
# 글쓴이:  데이비드썸원
# 날짜:  16:56
# 조회수:  1382
# 댓글수:  0
# 추천수:  0
# ---------------
# 32
# 제목:  미국의 로켓 발사 기술 근황.gif
# 글쓴이:  더보이즈 상
# 날짜:  16:55
# 조회수:  1220
# 댓글수:  0
# 추천수:  2
# ---------------
# 33
# 제목:  여돌의 새로운 청순계보 이을 것 같은 방과후설렘 참가자
# 글쓴이:  즐겨즐겨
# 날짜:  16:47
# 조회수:  4536
# 댓글수:  4
# 추천수:  2
# ---------------
# 34
# 제목:  어제 일어난 하이마트 돌진 사고 전말
# 글쓴이:  벤츄리
# 날짜:  16:43
# 조회수:  13048
# 댓글수:  48
# 추천수:  7
# ---------------
# 35
# 제목:  [EP.13] 어제자 스테픈 커리.GIF
# 글쓴이:  세븐틴 비니
# 날짜:  16:41
# 조회수:  430
# 댓글수:  0
# 추천수:  0
# ---------------
# 36
# 제목:  육룡이나르샤 - 척사광 윤랑 gif
# 글쓴이:  김규년
# 날짜:  16:34
# 조회수:  842
# 댓글수:  0
# 추천수:  0
# ---------------
# 37
# 제목:  성과급, 인센티브 퇴직금 꿀팁
# 글쓴이:  Vitro
# 날짜:  16:31
# 조회수:  3731
# 댓글수:  3
# 추천수:  2
# ---------------
# 38
# 제목:  현실적인 캡틴 아메리카
# 글쓴이:  sweetly
# 날짜:  16:28
# 조회수:  3073
# 댓글수:  0
# 추천수:  0
# ---------------
# 39
# 제목:  대면공연이 신기한 에스파 윈터
# 글쓴이:  오이카와 토비
# 날짜:  16:24
# 조회수:  16093
# 댓글수:  26
# 추천수:  10
# ---------------
# 40
# 제목:  청담역의 위엄.jpg
# 글쓴이:  중 천러
# 날짜:  16:23
# 조회수:  10275
# 댓글수:  5
# 추천수:  1
# ---------------
# 41
# 제목:  드라마 고독한미식가 스키야키 먹방
# 글쓴이:  몹시호시
# 날짜:  16:20
# 조회수:  1861
# 댓글수:  0
# 추천수:  0
# ---------------
# 42
# 제목:  피가 되고 살이 되는 현실 인생 팁
# 글쓴이:  BGRU
# 날짜:  16:18
# 조회수:  14135
# 댓글수:  29
# 추천수:  4
# ---------------
# 43
# 제목:  꿀잼실험
# 글쓴이:  다시 태어날
# 날짜:  16:15
# 조회수:  1270
# 댓글수:  1
# 추천수:  0
# ---------------
# 44
# 제목:  집돌이 and 밖순이 결혼은 파국인가요?
# 글쓴이:  MANSAE
# 날짜:  16:13
# 조회수:  11427
# 댓글수:  34
# 추천수:  4
# ---------------
# 45
# 제목:  시레기 말리는 중인 음식점
# 글쓴이:  천러러러
# 날짜:  16:08
# 조회수:  9857
# 댓글수:  18
# 추천수:  2
# ---------------
# 46
# 제목:  흔한 시골 국수집 풍경
# 글쓴이:  쿵쾅맨
# 날짜:  16:06
# 조회수:  4527
# 댓글수:  3
# 추천수:  1
# ---------------
# 47
# 제목:  45층에서 의자를 던진 여자.gif
# 글쓴이:  따릉해요
# 날짜:  15:59
# 조회수:  13416
# 댓글수:  25
# 추천수:  7
# ---------------
# 48
# 제목:  사람들이 스파이더맨을 좋아하는 이유를 잘 보여준다는 영화 장면.jpg
# 글쓴이:  아이디할게너
# 날짜:  15:54
# 조회수:  7009
# 댓글수:  13
# 추천수:  19
# ---------------
# 49
# 제목:  한편의 수필같은 정상수 인생벌스
# 글쓴이:  MANSAE
# 날짜:  15:53
# 조회수:  774
# 댓글수:  0
# 추천수:  0
# ---------------
# 50
# 제목:  19세기 러시아의 달 덕후 화가
# 글쓴이:  송희진
# 날짜:  15:47
# 조회수:  6955
# 댓글수:  10
# 추천수:  14
# ---------------
# 51
# 제목:  군대가면 총만 쏜다는 미필들 봐라
# 글쓴이:  용시대박
# 날짜:  15:45
# 조회수:  3479
# 댓글수:  3
# 추천수:  0
# ---------------
# 52
# 제목:  의외로 국내 판타지 소설 입문 작품으로 많이 꼽히는 소설
# 글쓴이:  윤세원
# 날짜:  15:44
# 조회수:  10923
# 댓글수:  53
# 추천수:  3
# ---------------
# 53
# 제목:  日 언론"오징어게임 방영된 모든 나라에서 대히트를 기록한 이유"일본 반응
# 글쓴이:  김성규내꺼`ワ
# 날짜:  15:40
# 조회수:  13589
# 댓글수:  33
# 추천수:  5
# ---------------
# 54
# 제목:  노빠꾸 러시아 근황
# 글쓴이:  djekxn
# 날짜:  15:39
# 조회수:  3372
# 댓글수:  0
# 추천수:  0
# ---------------
# 55
# 제목:  아빠한테 배틀넷 아이디 걸렸다 저런
# 글쓴이:  할리뱅입니더
# 날짜:  15:30
# 조회수:  3460
# 댓글수:  1
# 추천수:  0
# ---------------
# 56
# 제목:  요즘 머하나 궁금한 아티스트
# 글쓴이:  '''
# 날짜:  15:23
# 조회수:  1523
# 댓글수:  0
# 추천수:  0
# ---------------
# 57
# 제목:  몽골 최초 외교장관
# 글쓴이:  초코틴틴세븐
# 날짜:  15:20
# 조회수:  2209
# 댓글수:  0
# 추천수:  0
# ---------------
# 58
# 제목:  '생수병 사건' 인사 불만 등으로 동료 3인 콕 집어 범행
# 글쓴이:  맠맠잉
# 날짜:  15:17
# 조회수:  3371
# 댓글수:  0
# 추천수:  1
# ---------------
# 59
# 제목:  프로필 사진으로 리즈 찍은 뮤지컬 배우
# 글쓴이:  멍멍개
# 날짜:  15:13
# 조회수:  8788
# 댓글수:  4
# 추천수:  1
# ---------------
# 60
# 제목:  [속보] 정부 "30세 미만, 모더나 대신 화이자 코로나19 백신 권고”
# 글쓴이:  소고기 육전
# 날짜:  15:12
# 조회수:  28961
# 댓글수:  96
# 추천수:  3
# ---------------
# 61
# 제목:  요즘 유치원생 노래실력(이승철 - 잊었니 소향 ver)
# 글쓴이:  無地태
# 날짜:  15:10
# 조회수:  315
# 댓글수:  0
# 추천수:  0
# ---------------
# 62
# 제목:  앙버터빵 급발진
# 글쓴이:  윤세원
# 날짜:  15:08
# 조회수:  18800
# 댓글수:  31
# 추천수:  10
# ---------------
# 63
# 제목:  차은우 아닌척 수업 듣는 차은우
# 글쓴이:  다시 태어날
# 날짜:  15:04
# 조회수:  16543
# 댓글수:  24
# 추천수:  8
# ---------------
# 64
# 제목:  안철수 "대입 수시 폐지, 사법고시 부활시킨다"
# 글쓴이:  사라나
# 날짜:  15:02
# 조회수:  22174
# 댓글수:  103
# 추천수:  19
# ---------------
# 65
# 제목:  조선족이 한국에 불만인점
# 글쓴이:  solio
# 날짜:  14:57
# 조회수:  22894
# 댓글수:  99
# 추천수:  2
# ---------------
# 66
# 제목:  유튜브 스타로 떡상하고 있는 정상수.JPG
# 글쓴이:  다시 태어날
# 날짜:  14:55
# 조회수:  4199
# 댓글수:  1
# 추천수:  0
# ---------------
# 67
# 제목:  유전자 이상 때문에 귀가 4개인 고양이
# 글쓴이:  널 사랑해 영
# 날짜:  14:53
# 조회수:  16328
# 댓글수:  45
# 추천수:  15
# ---------------
# 68
# 제목:  큐브 아이돌 2022 시즌그리팅 출시 공지
# 글쓴이:  닐라닐라
# 날짜:  14:44
# 조회수:  1528
# 댓글수:  0
# 추천수:  0
# ---------------
# 69
# 제목:  [단독] "판사님, 시x 진짜" 욕설한 한서희, 필로폰 투약 징역 '1년 ..
# 글쓴이:  초코B
# 날짜:  14:42
# 조회수:  25306
# 댓글수:  38
# 추천수:  11
# ---------------
# 70
# 제목:  지방 사람들이 처음 서울 왔을때 의외로 가장 놀란다는 것
# 글쓴이:  아야나미
# 날짜:  14:36
# 조회수:  3850
# 댓글수:  1
# 추천수:  1
# ---------------
# 71
# 제목:  애기들한테 똥 닦는 법 알려주시는 유치원 선생님
# 글쓴이:  djekxn
# 날짜:  14:34
# 조회수:  11432
# 댓글수:  13
# 추천수:  2
# ---------------
# 72
# 제목:  짐 옮기는거 도와주는 리트리버들
# 글쓴이:  유기현 (25)
# 날짜:  14:28
# 조회수:  11745
# 댓글수:  22
# 추천수:  15
# ---------------
# 73
# 제목:  방탄소년단, 오늘 미국 출국…LA 콘서트→시상식서 팬들 만난다
# 글쓴이:  행복한왕만두
# 날짜:  14:19
# 조회수:  1136
# 댓글수:  0
# 추천수:  0
# ---------------
# 74
# 제목:  '한겨레 광고 철회' 서울시, 올해 예정된 광고 0건
# 글쓴이:  바닐라코
# 날짜:  14:12
# 조회수:  917
# 댓글수:  0
# 추천수:  0
# ---------------
# 75
# 제목:  UAE "한국산 방공 미사일 '천궁' 구매 의향…4조원 규모”(종합)
# 글쓴이:  토토얌
# 날짜:  14:09
# 조회수:  737
# 댓글수:  2
# 추천수:  1
# ---------------
# 76
# 제목:  2년만에 콘서트 & 시상식으로 미국 가는 방탄소년단 공항사진
# 글쓴이:  누눈나난
# 날짜:  14:07
# 조회수:  4103
# 댓글수:  9
# 추천수:  0
# ---------------
# 77
# 제목:  여친이 화장실갈때 노트북을 덮고 간 이유...jpg
# 글쓴이:  슈슈슈슈슈슈
# 날짜:  14:06
# 조회수:  32098
# 댓글수:  22
# 추천수:  35
# ---------------
# 78
# 제목:  올림픽 트젠선수 늘어날까…IOC "남성호르몬 수치 안 따지겠다"
# 글쓴이:  555
# 날짜:  14:03
# 조회수:  9018
# 댓글수:  35
# 추천수:  1
# ---------------
# 79
# 제목:  의외로 운전중에 박으면 ㅈ 되는 것들
# 글쓴이:  방탄전용날개
# 날짜:  14:00
# 조회수:  4720
# 댓글수:  0
# 추천수:  0
# ---------------
# 80
# 제목:  콜라로 만든 솜사탕
# 글쓴이:  오징어게임 일
# 날짜:  13:59
# 조회수:  4441
# 댓글수:  2
# 추천수:  1
# ---------------
# 81
# 제목:  스파이더맨 노웨이홈 2차예고편
# 글쓴이:  쌈자리즈
# 날짜:  13:53
# 조회수:  316
# 댓글수:  0
# 추천수:  1
# ---------------
# 82
# 제목:  알고보면 정말 착한 친구들
# 글쓴이:  영국닭집
# 날짜:  13:52
# 조회수:  2943
# 댓글수:  2
# 추천수:  0
# ---------------
# 83
# 제목:  대륙의 원룸청소
# 글쓴이:  Side to Side
# 날짜:  13:47
# 조회수:  4534
# 댓글수:  2
# 추천수:  0
# ---------------
# 84
# 제목:  "적군이 병사들에게 6kg 단검을 보급하고있다고?"
# 글쓴이:  윤정한 아내
# 날짜:  13:44
# 조회수:  3081
# 댓글수:  1
# 추천수:  0
# ---------------
# 85
# 제목:  서울 한번도 안 가봤는데 이렇게 생긴거 맞나요?
# 글쓴이:  남준이는왜이
# 날짜:  13:43
# 조회수:  6128
# 댓글수:  9
# 추천수:  2
# ---------------
# 86
# 제목:  90년대 원탑 영화 여배우
# 글쓴이:  오동잎한잎
# 날짜:  13:39
# 조회수:  2354
# 댓글수:  0
# 추천수:  0
# ---------------
# 87
# 제목:  넘어진 람보르기니
# 글쓴이:  307559_return
# 날짜:  13:39
# 조회수:  3277
# 댓글수:  1
# 추천수:  0
# ---------------
# 88
# 제목:  한류 때문에 생긴 편견
# 글쓴이:  벤츄리
# 날짜:  13:25
# 조회수:  12997
# 댓글수:  13
# 추천수:  5
# ---------------
# 89
# 제목:  논란중이라는 초등학교 국어 문제.jpg
# 글쓴이:  데이비드썸원
# 날짜:  13:23
# 조회수:  17575
# 댓글수:  42
# 추천수:  7
# ---------------
# 90
# 제목:  여자 키 146cm의 슬픔.jpg
# 글쓴이:  풀썬이동혁
# 날짜:  13:23
# 조회수:  5995
# 댓글수:  1
# 추천수:  1
# ---------------
# 91
# 제목:  박성웅, 유지태 피지컬.gif
# 글쓴이:  헤에에이~
# 날짜:  13:22
# 조회수:  4472
# 댓글수:  1
# 추천수:  0
# ---------------
# 92
# 제목:  비트코인으로 술사먹는 황현희
# 글쓴이:  게임을시작하
# 날짜:  13:18
# 조회수:  11224
# 댓글수:  6
# 추천수:  2
# ---------------
# 93
# 제목:  요즘 애들 월급별 자동차
# 글쓴이:  NCT 지 성
# 날짜:  13:10
# 조회수:  21639
# 댓글수:  46
# 추천수:  2
# ---------------
# 94
# 제목:  배달 시켰는데 졸지에 저팔계 돼버림.jpg
# 글쓴이:  Tony Stark
# 날짜:  13:10
# 조회수:  25193
# 댓글수:  22
# 추천수:  8
# ---------------
# 95
# 제목:  국민 세금으로 조선족 이미지 인식 개선 시키는 나라
# 글쓴이:  solio
# 날짜:  13:03
# 조회수:  3233
# 댓글수:  2
# 추천수:  0
# ---------------
# 96
# 제목:  김옥빈 전남친 얘기 들은 신동엽의 반응 ㅋㅋㅋ
# 글쓴이:  던던둔둔
# 날짜:  12:48
# 조회수:  18838
# 댓글수:  17
# 추천수:  11
# ---------------
# 97
# 제목:  나이먹고 결혼식장 가면서 가장 변한것.txt
# 글쓴이:  wjjdkkdkrk
# 날짜:  12:47
# 조회수:  10825
# 댓글수:  6
# 추천수:  0
# ---------------
# 98
# 제목:  아빠의 만행에, 절규하는 딸
# 글쓴이:  푸른미소
# 날짜:  12:40
# 조회수:  6906
# 댓글수:  3
# 추천수:  0
# ---------------
# 99
# 제목:  콩나물국밥집의 무료 애기밥...한국인의 정.jpg
# 글쓴이:  어니부깅
# 날짜:  12:36
# 조회수:  38916
# 댓글수:  75
# 추천수:  15
# ---------------
# 100
# 제목:  영화 남한산성을 보고 어리둥절한 중국인들
# 글쓴이:  남준이는왜이
# 날짜:  12:33
# 조회수:  14894
# 댓글수:  32
# 추천수:  11
# ---------------
# 101
# 제목:  "하데스! 어찌 생자들의 일에 나서는가?"
# 글쓴이:  세븐틴 원 +
# 날짜:  12:32
# 조회수:  4065
# 댓글수:  5
# 추천수:  0
# ---------------
# 102
# 제목:  부스터샷 간격 3~4개월로 단축 검토…18일 계획 발표
# 글쓴이:  참섭
# 날짜:  12:31
# 조회수:  2480
# 댓글수:  2
# 추천수:  0
# ---------------
# 103
# 제목:  '한국어 기원' 논문에 흥분한 中누리꾼들.."역시 우주의 중심은 중국"
# 글쓴이:  윤세원
# 날짜:  12:28
# 조회수:  33093
# 댓글수:  90
# 추천수:  4
# ---------------
# 104
# 제목:  오늘 우리팀 신입 지각했는데.blind
# 글쓴이:  천러러러
# 날짜:  12:27
# 조회수:  24655
# 댓글수:  74
# 추천수:  17
# ---------------
# 105
# 제목:  진짜 어린이들은 못 따라잡는다..내가 어쩔티비 하는동안..twt
# 글쓴이:  소고기 육전
# 날짜:  12:12
# 조회수:  20270
# 댓글수:  42
# 추천수:  3
# ---------------
# 106
# 제목:  실력파 보이밴드 원위, 신곡 '별' 개인 콘셉트 포토 공개
# 글쓴이:  이리저리요리
# 날짜:  12:12
# 조회수:  350
# 댓글수:  1
# 추천수:  2
# ---------------
# 107
# 제목:  드라마 선덕여왕 세계관 최고의 천재 gif
# 글쓴이:  키토제닉
# 날짜:  12:07
# 조회수:  6019
# 댓글수:  2
# 추천수:  1
# ---------------
# 108
# 제목:  한국 정부는 난민들이 못 견디고 떠나게 만들어요”
# 글쓴이:  solio
# 날짜:  12:06
# 조회수:  40490
# 댓글수:  84
# 추천수:  14
# ---------------
# 109
# 제목:  개그맨 황현희 근황..jpg
# 글쓴이:  311342_return
# 날짜:  12:02
# 조회수:  19330
# 댓글수:  13
# 추천수:  6
# ---------------
# 110
# 제목:  자신을 잡으러 출동한 형사와의 대화 .JPG
# 글쓴이:  에어리어 스타
# 날짜:  11:59
# 조회수:  3095
# 댓글수:  0
# 추천수:  4
# ---------------
# 111
# 제목:  한국 런칭하는 고든램지 햄버거 실물
# 글쓴이:  He
# 날짜:  11:59
# 조회수:  26943
# 댓글수:  39
# 추천수:  15
# ---------------
# 112
# 제목:  철인3종 국내 여성 1위
# 글쓴이:  쇼콘!23
# 날짜:  11:58
# 조회수:  4204
# 댓글수:  6
# 추천수:  0
# ---------------
# 113
# 제목:  이번주 pd수첩 예고(feat 쿠펑)
# 글쓴이:  311869_return
# 날짜:  11:58
# 조회수:  2984
# 댓글수:  2
# 추천수:  2
# ---------------
# 114
# 제목:  이재영 그리스서 귀국…검진 후 왼쪽 무릎 수술·재활 예정.gisa
# 글쓴이:  임팩트FBI
# 날짜:  11:48
# 조회수:  5814
# 댓글수:  2
# 추천수:  0
# ---------------
# 115
# 제목:  21세기 드라마라는게 믿기지 않는.. 일본 새드라마 (주연: 아라시 니노미..
# 글쓴이:  누눈나난
# 날짜:  11:36
# 조회수:  14487
# 댓글수:  20
# 추천수:  5
# ---------------
# 116
# 제목:  염치없는친구 손절
# 글쓴이:  키토제닉
# 날짜:  11:33
# 조회수:  13195
# 댓글수:  21
# 추천수:  2
# ---------------
# 117
# 제목:  스파이더맨 예고편에서 ptsd를 불러온 장면
# 글쓴이:  벤츄리
# 날짜:  11:25
# 조회수:  21346
# 댓글수:  42
# 추천수:  1
# ---------------
# 118
# 제목:  다이아몬드 세척
# 글쓴이:  Wannable(워너
# 날짜:  11:22
# 조회수:  9157
# 댓글수:  10
# 추천수:  7
# ---------------
# 119
# 제목:  흑화된 사회복지공무원
# 글쓴이:  다시한번말씀
# 날짜:  11:21
# 조회수:  8454
# 댓글수:  3
# 추천수:  0
# ---------------
# 120
# 제목:  누나 둘 등쌀에 남매타투 맞춘 막내 남동생.jpg
# 글쓴이:  거미의해안
# 날짜:  11:17
# 조회수:  36469
# 댓글수:  37
# 추천수:  17
# ---------------
# 121
# 제목:  테슬라 대량매도한 머스크, 샌더스 조롱하며"주식 더 팔까?"
# 글쓴이:  용시대박
# 날짜:  11:16
# 조회수:  2480
# 댓글수:  1
# 추천수:  0
# ---------------
# 122
# 제목:  무인카페서 담배 피우며 난장판으로 만들고 도망간 5명의 남성
# 글쓴이:  션국이네 메르
# 날짜:  11:09
# 조회수:  19181
# 댓글수:  45
# 추천수:  10
# ---------------
# 123
# 제목:  엑스원 해체 당시 경력직 멤버들이 했던 생각들
# 글쓴이:  벤츄리
# 날짜:  11:00
# 조회수:  63520
# 댓글수:  193
# 추천수:  43
# ---------------
# 124
# 제목:  mbti 신뢰도 증가
# 글쓴이:  JOSHUA95
# 날짜:  10:51
# 조회수:  12906
# 댓글수:  13
# 추천수:  4
# ---------------
# 125
# 제목:  방탄소년단 오늘(17일) LA 출국, AMA 대상후보→스타디움 콘서트 개최..
# 글쓴이:  누눈나난
# 날짜:  10:49
# 조회수:  1590
# 댓글수:  0
# 추천수:  1
# ---------------
# 126
# 제목:  술도녀 정은지&한선화 길거리 싸움 씬 직캠
# 글쓴이:  바보같은그대
# 날짜:  10:48
# 조회수:  4237
# 댓글수:  2
# 추천수:  1
# ---------------
# 127
# 제목:  황순현 NC 전 대표이사"방역당국이 잘못했다고 생각"
# 글쓴이:  유기현 (25)
# 날짜:  10:47
# 조회수:  1056
# 댓글수:  1
# 추천수:  0
# ---------------
# 128
# 제목:  로키야 머리에 김붙었다
# 글쓴이:  이진기(30)
# 날짜:  10:47
# 조회수:  2287
# 댓글수:  2
# 추천수:  0
# ---------------
# 129
# 제목:  서공예 만년 1등이였던 남돌이 추는 제시 'Cold Blooded'
# 글쓴이:  이리저리요리
# 날짜:  10:28
# 조회수:  5409
# 댓글수:  6
# 추천수:  2
# ---------------
# 130
# 제목:  어제자 확진자 수 3187명
# 글쓴이:  11541
# 날짜:  10:23
# 조회수:  4862
# 댓글수:  3
# 추천수:  0
# ---------------
# 131
# 제목:  연합뉴스, 네이버/다음카카오 뉴스란에서 퇴출... '언론 탄압인가'
# 글쓴이:  거미의해안
# 날짜:  10:21
# 조회수:  731
# 댓글수:  0
# 추천수:  1
# ---------------
# 132
# 제목:  경연이 아니라 공연을 하고 있는 어제자 풍류대장 역대급 무대들
# 글쓴이:  바보같은그대
# 날짜:  10:10
# 조회수:  897
# 댓글수:  0
# 추천수:  0
# ---------------
# 133
# 제목:  알바한지 한 달 짼데 사장님이랑 첫 카톡
# 글쓴이:  더보이즈 이주
# 날짜:  10:09
# 조회수:  17158
# 댓글수:  10
# 추천수:  5
# ---------------
# 134
# 제목:  소갈비 버거.jpg
# 글쓴이:  보라차라떼
# 날짜:  10:05
# 조회수:  4961
# 댓글수:  3
# 추천수:  0
# ---------------
# 135
# 제목:  속보) 페이커 FA
# 글쓴이:  보이프렌드 민
# 날짜:  9:59
# 조회수:  7343
# 댓글수:  13
# 추천수:  2
# ---------------
# 136
# 제목:  내일 골때녀 결방
# 글쓴이:  .서로가 서로
# 날짜:  9:58
# 조회수:  1403
# 댓글수:  0
# 추천수:  2
# ---------------
# 137
# 제목:  세서미 스트리트에 한국 캐릭터 추가
# 글쓴이:  션국이네 메르
# 날짜:  9:58
# 조회수:  9433
# 댓글수:  14
# 추천수:  6
# ---------------
# 138
# 제목:  사과가 3개있는데 2개 더 사면 몇개임? .jpg
# 글쓴이:  뇌잘린
# 날짜:  9:45
# 조회수:  59114
# 댓글수:  136
# 추천수:  3
# ---------------
# 139
# 제목:  우리 엄마 특징.real
# 글쓴이:  남준선배
# 날짜:  9:45
# 조회수:  5741
# 댓글수:  3
# 추천수:  0
# ---------------
# 140
# 제목:  90년생은 공감하는 추억의 장난감.JPG
# 글쓴이:  한 편의 너
# 날짜:  9:39
# 조회수:  4349
# 댓글수:  3
# 추천수:  5
# ---------------
# 141
# 제목:  에이팩스 레전드 코스프레 한 디시인.jpg
# 글쓴이:  더보이즈 김영
# 날짜:  9:39
# 조회수:  2439
# 댓글수:  1
# 추천수:  0
# ---------------
# 142
# 제목:  26년만에 밝혀진 직장 상사의 정체.jpg
# 글쓴이:  션국이네 메르
# 날짜:  9:36
# 조회수:  25981
# 댓글수:  40
# 추천수:  28
# ---------------
# 143
# 제목:  기안84가 말하는 최고의 컵라면.JPG
# 글쓴이:  호롤로롤롤
# 날짜:  9:36
# 조회수:  25007
# 댓글수:  25
# 추천수:  13
# ---------------
# 144
# 제목:  시험공부하는 공대생
# 글쓴이:  다시한번말씀
# 날짜:  9:26
# 조회수:  1946
# 댓글수:  1
# 추천수:  0
# ---------------
# 145
# 제목:  "다 내쫓고 쑥대밭"…담배 나무라자 들이닥친 중학생들.news
# 글쓴이:  우물밖 여고
# 날짜:  9:24
# 조회수:  5001
# 댓글수:  3
# 추천수:  1
# ---------------
# 146
# 제목:  공대생 부부의 솔루션.jpg
# 글쓴이:  218023_return
# 날짜:  9:13
# 조회수:  6114
# 댓글수:  1
# 추천수:  0
# ---------------
# 147
# 제목:  헬스장 민폐유형
# 글쓴이:  큐랑둥이
# 날짜:  9:00
# 조회수:  4130
# 댓글수:  1
# 추천수:  3
# ---------------
# 148
# 제목:  일본의원룸
# 글쓴이:  He
# 날짜:  8:58
# 조회수:  51672
# 댓글수:  110
# 추천수:  18
# ---------------
# 149
# 제목:  중국인에게 빌드업 시전.jpeg
# 글쓴이:  마유
# 날짜:  8:57
# 조회수:  6827
# 댓글수:  1
# 추천수:  2
# ---------------
# 150
# 제목:  SS501 노래중에 숨겨진 명곡.JPG
# 글쓴이:  Side to Side
# 날짜:  8:57
# 조회수:  847
# 댓글수:  0
# 추천수:  3
# ---------------
# 151
# 제목:  수능 당일 레전드 사진.JPG
# 글쓴이:  에자키카루
# 날짜:  8:47
# 조회수:  39703
# 댓글수:  44
# 추천수:  22
# ---------------
# 152
# 제목:  뭔가 어색한 호크아이 드라마
# 글쓴이:  남준선배
# 날짜:  8:47
# 조회수:  6164
# 댓글수:  4
# 추천수:  1
# ---------------
# 153
# 제목:  혐주의) 홍대골목에서 발견된 저주인형
# 글쓴이:  송희진
# 날짜:  8:34
# 조회수:  104357
# 댓글수:  1321
# 추천수:  48
# ---------------
# 154
# 제목:  [단독] 엉덩이 살갗 까지고 3도 화상 신생아 울린 의료사고
# 글쓴이:  초코B
# 날짜:  8:25
# 조회수:  33238
# 댓글수:  62
# 추천수:  11
# ---------------
# 155
# 제목:  내년 콩의 날.jpg
# 글쓴이:  윤세원
# 날짜:  8:25
# 조회수:  2238
# 댓글수:  2
# 추천수:  0
# ---------------
# 156
# 제목:  4수생 정준하가 알려주는 시험문제 찍기 팁.gif
# 글쓴이:  311342_return
# 날짜:  8:15
# 조회수:  7513
# 댓글수:  6
# 추천수:  6
# ---------------
# 157
# 제목:  최근 심각하다는 백신 부작용.JPG
# 글쓴이:  위례신다도시
# 날짜:  8:13
# 조회수:  31765
# 댓글수:  21
# 추천수:  24
# ---------------
# 158
# 제목:  진짜 당황스러운 세븐틴 팬덤 상태
# 글쓴이:  신짱구,
# 날짜:  8:02
# 조회수:  68576
# 댓글수:  201
# 추천수:  26
# ---------------
# 159
# 제목:  ???: 님 왤케 잘함?? 어디섭이에요?
# 글쓴이:  Tony Stark
# 날짜:  7:31
# 조회수:  4618
# 댓글수:  1
# 추천수:  0
# ---------------
# 160
# 제목:  서점에서 불법인데 의외로 많이하는거.JPG
# 글쓴이:  950107
# 날짜:  7:26
# 조회수:  36385
# 댓글수:  26
# 추천수:  10
# ---------------
# 161
# 제목:  [단독] '이건희 컬렉션' 작품에 의문의 서명.. 미술계 술렁
# 글쓴이:  218023_return
# 날짜:  7:25
# 조회수:  27821
# 댓글수:  4
# 추천수:  23
# ---------------
# 162
# 제목:  김동현이 공무원준비를 포기한 이유
# 글쓴이:  김용국 아내
# 날짜:  7:16
# 조회수:  25272
# 댓글수:  15
# 추천수:  16
# ---------------
# 163
# 제목:  임용준비생 눈물쏟은 사연
# 글쓴이:  호롤로롤롤
# 날짜:  7:03
# 조회수:  6421
# 댓글수:  2
# 추천수:  4
# ---------------
# 164
# 제목:  DRX 쏭 , 보리 FA
# 글쓴이:  윤세원
# 날짜:  7:03
# 조회수:  215
# 댓글수:  0
# 추천수:  2
# ---------------
# 165
# 제목:  나 아이유로 자기세뇌 했는데 효과는 굉장해따ㅎ
# 글쓴이:  WANNA ONE 하
# 날짜:  6:49
# 조회수:  71459
# 댓글수:  149
# 추천수:  33
# ---------------
# 166
# 제목:  악마의 탈을 쓴 부모
# 글쓴이:  싯떼루네`ワ
# 날짜:  6:44
# 조회수:  5939
# 댓글수:  1
# 추천수:  0
# ---------------
# 167
# 제목:  20대 여성은 청년 아닌듯…이·윤, 남성 표심잡기 매몰
# 글쓴이:  자두야♡♡
# 날짜:  6:32
# 조회수:  7392
# 댓글수:  8
# 추천수:  6
# ---------------
# 168
# 제목:  교수님이 미소녀 목소리였으면 좋겠다는 대학생
# 글쓴이:  더보이즈 김영
# 날짜:  6:00
# 조회수:  4553
# 댓글수:  0
# 추천수:  2
# ---------------
# 169
# 제목:  유재석이 듣고 방송에서 개빡친 일화
# 글쓴이:  비비의주인
# 날짜:  5:58
# 조회수:  42199
# 댓글수:  40
# 추천수:  44
# ---------------
# 170
# 제목:  회사가 너무 기계적이라 퇴사함.jpg
# 글쓴이:  비비의주인
# 날짜:  5:56
# 조회수:  99207
# 댓글수:  212
# 추천수:  33
# ---------------
# 171
# 제목:  레전드 카톡 착각남.jpg
# 글쓴이:  김규년
# 날짜:  5:55
# 조회수:  65438
# 댓글수:  158
# 추천수:  28
# ---------------
# 172
# 제목:  Post Malone and The Weeknd - One Right No..
# 글쓴이:  게임을시작하
# 날짜:  5:54
# 조회수:  14
# 댓글수:  0
# 추천수:  0
# ---------------
# 173
# 제목:  켜진 컴퓨터의 램을 빼봤다.jpg
# 글쓴이:  최민호(26)
# 날짜:  5:26
# 조회수:  11605
# 댓글수:  3
# 추천수:  1
# ---------------
# 174
# 제목:  근래 본 여자아이돌 단발 투탑
# 글쓴이:  311342_return
# 날짜:  4:27
# 조회수:  11209
# 댓글수:  3
# 추천수:  5
# ---------------
# 175
# 제목:  10년도 더 전에 유행하고 요즘은 안보이는 하교 길거리 음식.jpg
# 글쓴이:  에자키히카루
# 날짜:  4:25
# 조회수:  21418
# 댓글수:  33
# 추천수:  1
# ---------------
# 176
# 제목:  화성인 바이러스 초딩남 근황
# 글쓴이:  JOSHUA95
# 날짜:  4:24
# 조회수:  19382
# 댓글수:  8
# 추천수:  9
# ---------------
# 177
# 제목:  상큼하게 무대하는 핑크악동 트와이스.jpgif
# 글쓴이:  최승처
# 날짜:  4:23
# 조회수:  1032
# 댓글수:  0
# 추천수:  2
# ---------------
# 178
# 제목:  현재 서울 서초구 근황
# 글쓴이:  김상연
# 날짜:  4:16
# 조회수:  120108
# 댓글수:  263
# 추천수:  30
# ---------------
# 179
# 제목:  스파이더맨 노웨이홈 포스터
# 글쓴이:  류준열 강다니
# 날짜:  4:15
# 조회수:  1289
# 댓글수:  1
# 추천수:  2
# ---------------
# 180
# 제목:  골병들거같은 놀이기구
# 글쓴이:  몹시섹시
# 날짜:  4:01
# 조회수:  1291
# 댓글수:  0
# 추천수:  3
# ---------------
# 181
# 제목:  남자가 남자번호 땀
# 글쓴이:  참섭
# 날짜:  4:01
# 조회수:  4892
# 댓글수:  1
# 추천수:  2
# ---------------
# 182
# 제목:  외국인들이 놀라는 k양심 실험.JPG
# 글쓴이:  218023_return
# 날짜:  3:55
# 조회수:  13235
# 댓글수:  5
# 추천수:  4
# ---------------
# 183
# 제목:  음식 그릇 이렇게 내놨다고 배달기사랑 싸움.JPG
# 글쓴이:  몹시섹시
# 날짜:  3:55
# 조회수:  5931
# 댓글수:  6
# 추천수:  1
# ---------------
# 184
# 제목:  2000년대 중반 숨겨진 발라드 명곡.JPG
# 글쓴이:  배진영(a.k.a발
# 날짜:  3:54
# 조회수:  24
# 댓글수:  0
# 추천수:  1
# ---------------
# 185
# 제목:  주방 자동화 .gif
# 글쓴이:  중 천러
# 날짜:  3:47
# 조회수:  427
# 댓글수:  0
# 추천수:  2
# ---------------
# 186
# 제목:  오징어 게임의 세계적인 인기... 그리고 넷플릭스와 우리나라 방송사의 차이..
# 글쓴이:  더보이즈 김영
# 날짜:  3:42
# 조회수:  3154
# 댓글수:  3
# 추천수:  2
# ---------------
# 187
# 제목:  60m 높이에서 멈춘 롤러코스터
# 글쓴이:  남준선배
# 날짜:  3:42
# 조회수:  1549
# 댓글수:  1
# 추천수:  1
# ---------------
# 188
# 제목:  PC요소가 추가된 와우 근황
# 글쓴이:  비비의주인
# 날짜:  3:40
# 조회수:  863
# 댓글수:  0
# 추천수:  2
# ---------------
# 189
# 제목:  작가가 잡아준 컨셉을 활용 못하는 배우들...jpg
# 글쓴이:  비비의주인
# 날짜:  2:54
# 조회수:  2467
# 댓글수:  0
# 추천수:  2
# ---------------
# 190
# 제목:  사장이 주문 취소해서 화난 사람.JPG
# 글쓴이:  천러러러
# 날짜:  2:53
# 조회수:  24568
# 댓글수:  31
# 추천수:  2

# %%
df=pd.DataFrame(result)
df
# Out:
#                                               제목      글쓴이     날짜    조회수 댓글수  \
# 0                  생일파티한 한소희 목걸이 귀걸이 브랜드.. 대박 예쁨     누눈나난  17:59    207   0
# 1              "새끼 길고양이 얼굴을 토치로 불질러”...경찰, 수사 착수   MANSAE  17:59    186   2
# 2                        화려수수 조합으로 데뷔 첫 화보 찍은 여돌    버가버가뷰  17:56    227   0
# 3                                    붐 담당 일진.jpg   윤정한 아내  17:55    386   1
# 4                    젤다의 전설 안해본 사람들은 잘 모르는 것 jpg     몹시호시  17:51    785   3
# ..                                           ...      ...    ...    ...  ..
# 185  오징어 게임의 세계적인 인기... 그리고 넷플릭스와 우리나라 방송사의 차이..  더보이즈 김영   3:42   3154   3
# 186                            60m 높이에서 멈춘 롤러코스터     남준선배   3:42   1549   1
# 187                              PC요소가 추가된 와우 근황    비비의주인   3:40    863   0
# 188                 작가가 잡아준 컨셉을 활용 못하는 배우들...jpg    비비의주인   2:54   2467   0
# 189                        사장이 주문 취소해서 화난 사람.JPG     천러러러   2:53  24568  31
#
#     추천수
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
# ..   ..
# 185   2
# 186   1
# 187   2
# 188   2
# 189   2
#
# [190 rows x 6 columns]

# %%
df.to_excel('data/instiz_인티포털.xlsx')

# %%
# 전체 인기글

# %%
contents2=soup.select('#rank1to10 > div')
contents2.extend(soup.select('#rank11to20 > div'))

# %%
#전체 인기글
cnt=1
result2=[]
for i in contents2:
    tmp={}
    print('-'*15)
    print(cnt)
    
    #게시판 추출
    category=i.find('div', {"class":"minitext"}).text
    print("게시판: ", category)
    
    
    # 제목 추출
    if cnt<11:
        title=i.select_one('#rank1to10 > div > div.rank_subject > a').text.strip()
    else:
        title=i.select_one('#rank11to20 > div > div.rank_subject > a').text.strip()
    print("제목: ", title)
    
   
    
#    # 글쓴이 추출
#    writer_tag = i.find('td', {"class":"minitext2 listnm"})
#    if writer_tag is not None: # None 값이 있으므로 조건문을 통해 회피 
#        writer = writer_tag.text
#      
#    else:
#        writer = "없음"
#    print("글쓴이: ", writer)
    
#     # 유동이나 고닉이 아닌 글쓴이 옆에 있는 ip 추출
#     ip_tag = i.find('td', class_='gall_writer ub-writer').find('span', class_='ip')
#     if ip_tag is not None:  # None 값이 있으므로 조건문을 통해 회피 
#         ip = ip_tag.text
#         print("ip: ", ip)



#    # 날짜 추출 
#    date=i.find('td',{"class":"listno regdate"}).text
#    print("날짜: ",date)
    
    
#    # 조회 수 추출
#    views = i.find_all('td', {"class":"listno"})[2].text
#    print("조회수: ", views)


    # 댓글 수
    comment=i.find('a',{"class":"cmt"})
    if comment==None:
        comment=0
    else:
        comment=comment.text
    print("댓글수: ", comment)
    
#    # 추천 수 추출
#    recommend = i.find_all('td', {"class":"listno"})[3].text
#    print("추천수: ", recommend)

    tmp['게시판']=category
    tmp['제목']=title
#    tmp['글쓴이']=writer
#    tmp['날짜']=date
#    tmp['조회수']=views
    tmp['댓글수']=comment
#    tmp['추천수']=recommend
    
    result2.append(tmp)
    
    cnt=cnt+1
# Out:
# ---------------
# 1
# 게시판:  인티포털
# 제목:  임시완이 공개한 연애횟수.jpg
# 댓글수:  10
# ---------------
# 2
# 게시판:  익명잡담
# 제목:  우리집 고삼이 바람 쐬고 온다고 하고 이 시간에 울면서 나갔..
# 댓글수:  6
# ---------------
# 3
# 게시판:  익명잡담
# 제목:  와씨 라면스프 먹는데 대.존.맛
# 댓글수:  12
# ---------------
# 4
# 게시판:  인티포털
# 제목:  용산 아이맥스때문에 남친이랑 싸운 여자.jpg
# 댓글수:  49
# ---------------
# 5
# 게시판:  익명잡담
# 제목:  이틀에 한번 샤워하면 더러워?
# 댓글수:  39
# ---------------
# 6
# 게시판:  인티포털
# 제목:  최근들어 정말 예쁘다는 생각이 드는 분
# 댓글수:  33
# ---------------
# 7
# 게시판:  익명잡담
# 제목:  하루에 6~7시간 씩 하는
# 댓글수:  5
# ---------------
# 8
# 게시판:  인티포털
# 제목:  미쳐버린 어느 웹소설 설정
# 댓글수:  6
# ---------------
# 9
# 게시판:  인티포털
# 제목:  트위치 어느 여스트리머의 방송정지 사유.jpgif
# 댓글수:  4
# ---------------
# 10
# 게시판:  익명잡담
# 제목:  브라렛이랑 그냥 브라랑 뭐가달라??
# 댓글수:  11
# ---------------
# 11
# 게시판:  익명잡담
# 제목:  [연애중] 계란말이된 썰 푼다,,
# 댓글수:  2
# ---------------
# 12
# 게시판:  인티포털
# 제목:  요즘 sns에 미남들이 많은 이유
# 댓글수:  18
# ---------------
# 13
# 게시판:  인티포털
# 제목:  삼성 핸드폰 테스트 엔지니어도 어쩔 수 없는 취향
# 댓글수:  1
# ---------------
# 14
# 게시판:  익명잡담
# 제목:  나 쌍수 망한 걸까… 심각하게 재수술 고민 중인데 한번씩 봐..
# 댓글수:  23
# ---------------
# 15
# 게시판:  인티포털
# 제목:  KFC 선넘는 신메뉴 폰치밥.jpg
# 댓글수:  12
# ---------------
# 16
# 게시판:  인티포털
# 제목:  환경호르몬 많이 나오는데 흐린눈 하는 사람 많은 것.jpg
# 댓글수:  42
# ---------------
# 17
# 게시판:  익명잡담
# 제목:  어른들 말 중에 틀린말 하나 없다..를 느끼게해준 말
# 댓글수:  7
# ---------------
# 18
# 게시판:  익명잡담
# 제목:  나 네일아트 자랑해도 될까?(두근
# 댓글수:  14
# ---------------
# 19
# 게시판:  인티포털
# 제목:  다음날 숙취가 없다는 술
# 댓글수:  13
# ---------------
# 20
# 게시판:  익명잡담
# 제목:  아빠가 대기업 임원인게 엄청 대단한거임?
# 댓글수:  8

# %%
df2=pd.DataFrame(result2)
df2
# Out:
#      게시판                                   제목 댓글수
# 0   인티포털                    임시완이 공개한 연애횟수.jpg  10
# 1   익명잡담  우리집 고삼이 바람 쐬고 온다고 하고 이 시간에 울면서 나갔..   6
# 2   익명잡담                    와씨 라면스프 먹는데 대.존.맛  12
# 3   인티포털            용산 아이맥스때문에 남친이랑 싸운 여자.jpg  49
# 4   익명잡담                     이틀에 한번 샤워하면 더러워?  39
# 5   인티포털                최근들어 정말 예쁘다는 생각이 드는 분  33
# 6   익명잡담                       하루에 6~7시간 씩 하는   5
# 7   인티포털                       미쳐버린 어느 웹소설 설정   6
# 8   인티포털          트위치 어느 여스트리머의 방송정지 사유.jpgif   4
# 9   익명잡담                  브라렛이랑 그냥 브라랑 뭐가달라??  11
# 10  익명잡담                   [연애중] 계란말이된 썰 푼다,,   2
# 11  인티포털                   요즘 sns에 미남들이 많은 이유  18
# 12  인티포털          삼성 핸드폰 테스트 엔지니어도 어쩔 수 없는 취향   1
# 13  익명잡담  나 쌍수 망한 걸까… 심각하게 재수술 고민 중인데 한번씩 봐..  23
# 14  인티포털                  KFC 선넘는 신메뉴 폰치밥.jpg  12
# 15  인티포털     환경호르몬 많이 나오는데 흐린눈 하는 사람 많은 것.jpg  42
# 16  익명잡담        어른들 말 중에 틀린말 하나 없다..를 느끼게해준 말   7
# 17  익명잡담                   나 네일아트 자랑해도 될까?(두근  14
# 18  인티포털                        다음날 숙취가 없다는 술  13
# 19  익명잡담               아빠가 대기업 임원인게 엄청 대단한거임?   8

# %%
df2.to_excel('data/instiz_전체인기글.xlsx')

# %%
# 인티포털 인기글

# %%
contents3=soup.select('#rank1to10_menu > div')
contents3.extend(soup.select('#rank11to20_menu > div'))

# %%
#전체 인기글
cnt=1
result3=[]
for i in contents3:
    tmp={}
    print('-'*15)
    print(cnt)
    
    
    # 제목 추출
    if cnt<11:
        title=i.select_one('#rank1to10_menu > div > div.rank_subject > a').text.strip()
    else:
        title=i.select_one('#rank11to20_menu > div > div.rank_subject > a').text.strip()
    print("제목: ", title)
    
   
    
#    # 글쓴이 추출
#    writer_tag = i.find('td', {"class":"minitext2 listnm"})
#    if writer_tag is not None: # None 값이 있으므로 조건문을 통해 회피 
#        writer = writer_tag.text
#      
#    else:
#        writer = "없음"
#    print("글쓴이: ", writer)
    
#     # 유동이나 고닉이 아닌 글쓴이 옆에 있는 ip 추출
#     ip_tag = i.find('td', class_='gall_writer ub-writer').find('span', class_='ip')
#     if ip_tag is not None:  # None 값이 있으므로 조건문을 통해 회피 
#         ip = ip_tag.text
#         print("ip: ", ip)



#    # 날짜 추출 
#    date=i.find('td',{"class":"listno regdate"}).text
#    print("날짜: ",date)
    
    
#    # 조회 수 추출
#    views = i.find_all('td', {"class":"listno"})[2].text
#    print("조회수: ", views)


    # 댓글 수
    comment=i.find('a',{"class":"cmt"})
    if comment==None:
        comment=0
    else:
        comment=comment.text
    print("댓글수: ", comment)
    
#    # 추천 수 추출
#    recommend = i.find_all('td', {"class":"listno"})[3].text
#    print("추천수: ", recommend)

    tmp['제목']=title
#    tmp['글쓴이']=writer
#    tmp['날짜']=date
#    tmp['조회수']=views
    tmp['댓글수']=comment
#    tmp['추천수']=recommend
    
    result3.append(tmp)
    
    cnt=cnt+1
# Out:
# ---------------
# 1
# 제목:  임시완이 공개한 연애횟수.jpg
# 댓글수:  10
# ---------------
# 2
# 제목:  용산 아이맥스때문에 남친이랑 싸운 여자.jpg
# 댓글수:  49
# ---------------
# 3
# 제목:  최근들어 정말 예쁘다는 생각이 드는 분
# 댓글수:  33
# ---------------
# 4
# 제목:  미쳐버린 어느 웹소설 설정
# 댓글수:  6
# ---------------
# 5
# 제목:  요즘 sns에 미남들이 많은 이유
# 댓글수:  18
# ---------------
# 6
# 제목:  다음날 숙취가 없다는 술
# 댓글수:  13
# ---------------
# 7
# 제목:  트위치 어느 여스트리머의 방송정지 사유.jpgif
# 댓글수:  4
# ---------------
# 8
# 제목:  환경호르몬 많이 나오는데 흐린눈 하는 사람 많은 것.jpg
# 댓글수:  42
# ---------------
# 9
# 제목:  삼성 핸드폰 테스트 엔지니어도 어쩔 수 없는 취향
# 댓글수:  1
# ---------------
# 10
# 제목:  KFC 선넘는 신메뉴 폰치밥.jpg
# 댓글수:  12
# ---------------
# 11
# 제목:  4만원에 여친한테 정떨어지면 내가 이상한건가?
# 댓글수:  0
# ---------------
# 12
# 제목:  일반인이 아이돌 메이크업을 받았을때.jpg
# 댓글수:  42
# ---------------
# 13
# 제목:  연구원에게 발각되어 만짐당하는 팔라스고양이
# 댓글수:  14
# ---------------
# 14
# 제목:  털관리 잘한 리트리버
# 댓글수:  2
# ---------------
# 15
# 제목:  파리에서 오징어게임 배우로 오해받는 유튜버
# 댓글수:  36
# ---------------
# 16
# 제목:  마블 최초로 토마토 썩은 이터널스
# 댓글수:  38
# ---------------
# 17
# 제목:  할로윈때 뚱뚱해지는 서양다람쥐들
# 댓글수:  67
# ---------------
# 18
# 제목:  사고치는 고양이.jpg
# 댓글수:  3
# ---------------
# 19
# 제목:  서울 뷔페 3대장
# 댓글수:  0
# ---------------
# 20
# 제목:  영국 데일리메일 홈피에서 발견된 한류...jpg
# 댓글수:  0

# %%
df3=pd.DataFrame(result3)
df3
# Out:
#                                   제목 댓글수
# 0                  임시완이 공개한 연애횟수.jpg  10
# 1          용산 아이맥스때문에 남친이랑 싸운 여자.jpg  49
# 2              최근들어 정말 예쁘다는 생각이 드는 분  33
# 3                     미쳐버린 어느 웹소설 설정   6
# 4                 요즘 sns에 미남들이 많은 이유  18
# 5                      다음날 숙취가 없다는 술  13
# 6        트위치 어느 여스트리머의 방송정지 사유.jpgif   4
# 7   환경호르몬 많이 나오는데 흐린눈 하는 사람 많은 것.jpg  42
# 8        삼성 핸드폰 테스트 엔지니어도 어쩔 수 없는 취향   1
# 9                KFC 선넘는 신메뉴 폰치밥.jpg  12
# 10         4만원에 여친한테 정떨어지면 내가 이상한건가?   0
# 11           일반인이 아이돌 메이크업을 받았을때.jpg  42
# 12           연구원에게 발각되어 만짐당하는 팔라스고양이  14
# 13                       털관리 잘한 리트리버   2
# 14           파리에서 오징어게임 배우로 오해받는 유튜버  36
# 15                마블 최초로 토마토 썩은 이터널스  38
# 16                 할로윈때 뚱뚱해지는 서양다람쥐들  67
# 17                      사고치는 고양이.jpg   3
# 18                         서울 뷔페 3대장   0
# 19        영국 데일리메일 홈피에서 발견된 한류...jpg   0

# %%
df3.to_excel('data/instiz_인티포털인기글.xlsx')
