# %%
from bs4 import BeautifulSoup as bs
import requests as req
import pandas as pd
import datetime
from datetime import timedelta

# %%
base_url='https://www.instiz.net/pt?page=1'
headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.54 Safari/537.36"}

# %%
d = datetime.datetime.now()
now = d.strftime('%X')

# %%
cnt=1
result=[]
for i in range(1,11):
    params={"page":i}
    raw=req.get(base_url,params=params, headers=headers)
    soup=bs(raw.content, 'html.parser')
    contents = soup.find_all('tr')
    del contents[:20]
    del contents[19:len(contents)]
    
    for i in contents:
        tmp={}
        print('-'*15)
        print(cnt)
        cnt=cnt+1


        # 제목 추출
        title=i.find('span',{"id":"subject"}).text.strip()
        print("제목: ", title)



        # 글쓴이 추출
        writer_tag = i.find('td', {"class":"minitext2 listnm"})
        if writer_tag is not None: # None 값이 있으므로 조건문을 통해 회피 
            writer = writer_tag.text

        else:
            writer = "없음"
        print("글쓴이: ", writer)

    #     # 유동이나 고닉이 아닌 글쓴이 옆에 있는 ip 추출
    #     ip_tag = i.find('td', class_='gall_writer ub-writer').find('span', class_='ip')
    #     if ip_tag is not None:  # None 값이 있으므로 조건문을 통해 회피 
    #         ip = ip_tag.text
    #         print("ip: ", ip)



        # 날짜 추출 
        date=i.find('td',{"class":"listno regdate"}).text
        if len(date)<=5:
            if len(date)<=4:
                date=d.strftime('%Y.%m.%d ')+'0'+date
            else:
                date=d.strftime('%Y.%m.%d ')+date
        else:
            date=d.strftime('%Y')+'.'+date[:5]
        print("날짜: ",date)


        # 조회 수 추출
        views = i.find_all('td', {"class":"listno"})[2].text
        print("조회수: ", views)


        # 댓글 수
        comment=i.find('a',{"id":"view_cmt"})
        if comment==None:
            comment=0
        else:
            comment=comment.text
        print("댓글수: ", comment)

        # 추천 수 추출
        recommend = i.find_all('td', {"class":"listno"})[3].text
        print("추천수: ", recommend)


        tmp['제목']=title
        tmp['글쓴이']=writer
        tmp['날짜']=date
        tmp['조회수']=views
        tmp['댓글수']=comment
        tmp['추천수']=recommend

        result.append(tmp)
# Out:
# ---------------
# 1
# 제목:  졸업안시켜준 교수 죽인 대학원생
# 글쓴이:  남준이는왜이
# 날짜:  2021.11.18 01:09
# 조회수:  1
# 댓글수:  0
# 추천수:  0
# ---------------
# 2
# 제목:  배달음식에 이물질이 나왔을때 대처법.JPG
# 글쓴이:  ♡김태형♡
# 날짜:  2021.11.18 01:04
# 조회수:  278
# 댓글수:  0
# 추천수:  0
# ---------------
# 3
# 제목:  열라면 누가 맛있다 그랬니? .JPG
# 글쓴이:  Wannable(워너
# 날짜:  2021.11.18 01:04
# 조회수:  282
# 댓글수:  0
# 추천수:  0
# ---------------
# 4
# 제목:  19세 이상만
# 글쓴이:  방탄소년단★
# 날짜:  2021.11.18 00:56
# 조회수:  550
# 댓글수:  0
# 추천수:  0
# ---------------
# 5
# 제목:  노웨이홈 삼파이더맨 출연이 99퍼인 이유.jpg
# 글쓴이:  뇌잘린
# 날짜:  2021.11.18 00:50
# 조회수:  1642
# 댓글수:  5
# 추천수:  1
# ---------------
# 6
# 제목:  위스키를 제대로 마시는법.gif
# 글쓴이:  임팩트FBI
# 날짜:  2021.11.18 00:48
# 조회수:  649
# 댓글수:  0
# 추천수:  1
# ---------------
# 7
# 제목:  이름은 모르는데 익숙한 새 .jpg
# 글쓴이:  Jeddd
# 날짜:  2021.11.18 00:48
# 조회수:  1065
# 댓글수:  0
# 추천수:  0
# ---------------
# 8
# 제목:  스파이더맨 예고편에서 뭔가 이상한 MJ 구해주는 장면
# 글쓴이:  시어머니블루
# 날짜:  2021.11.18 00:47
# 조회수:  1250
# 댓글수:  0
# 추천수:  0
# ---------------
# 9
# 제목:  노가다 아이스크림 심부름
# 글쓴이:  Wannable(워너
# 날짜:  2021.11.18 00:47
# 조회수:  666
# 댓글수:  0
# 추천수:  0
# ---------------
# 10
# 제목:  여성의 생물학적 노산 기준 나이.jpg
# 글쓴이:  오징어게임 일
# 날짜:  2021.11.18 00:44
# 조회수:  3959
# 댓글수:  9
# 추천수:  0
# ---------------
# 11
# 제목:  3스파이더맨 확정짤(수정)
# 글쓴이:  멍ㅇ멍이 소리
# 날짜:  2021.11.18 00:44
# 조회수:  627
# 댓글수:  0
# 추천수:  0
# ---------------
# 12
# 제목:  대한민국남자 평균 비주얼 가능하다vs어서오고
# 글쓴이:  비비의주인
# 날짜:  2021.11.18 00:42
# 조회수:  850
# 댓글수:  0
# 추천수:  0
# ---------------
# 13
# 제목:  외국인들한테 인기 많은 한식.JPG
# 글쓴이:  無地태
# 날짜:  2021.11.18 00:40
# 조회수:  1459
# 댓글수:  0
# 추천수:  0
# ---------------
# 14
# 제목:  아파트 도서관에서 아이들 보며 4시간 바지 내린 '그놈'…징역 9개월 실형..
# 글쓴이:  김낑깡
# 날짜:  2021.11.18 00:39
# 조회수:  508
# 댓글수:  0
# 추천수:  0
# ---------------
# 15
# 제목:  나쁜 묘사를 듣고 어떤 직업인지 맞추기.jpg
# 글쓴이:  옹뇸뇸뇸
# 날짜:  2021.11.18 00:39
# 조회수:  935
# 댓글수:  0
# 추천수:  0
# ---------------
# 16
# 제목:  LG에서 출시한 역대급 매출이였다는 폰.JPG
# 글쓴이:  싯떼루네`ワ
# 날짜:  2021.11.18 00:39
# 조회수:  3559
# 댓글수:  5
# 추천수:  2
# ---------------
# 17
# 제목:  2021 로스트메모리즈
# 글쓴이:  오징어게임 일
# 날짜:  2021.11.18 00:39
# 조회수:  503
# 댓글수:  0
# 추천수:  0
# ---------------
# 18
# 제목:  카더가든이 재해석해서 부른 크라잉넛의 명동콜링
# 글쓴이:  Vitro
# 날짜:  2021.11.18 00:25
# 조회수:  190
# 댓글수:  1
# 추천수:  1
# ---------------
# 19
# 제목:  미국 3대 시상식 AMAs 시상식에서 BTS가 할 무대
# 글쓴이:  행복한왕만두
# 날짜:  2021.11.18 00:21
# 조회수:  3200
# 댓글수:  11
# 추천수:  2
# ---------------
# 20
# 제목:  생면부지 남성 가슴 만진 여성, '강제추행죄' 벌금 100만원
# 글쓴이:  용시대박
# 날짜:  2021.11.18 00:21
# 조회수:  1118
# 댓글수:  0
# 추천수:  0
# ---------------
# 21
# 제목:  뭐 추억의 소드가 왔다고?
# 글쓴이:  세븐틴 원 +
# 날짜:  2021.11.18 00:18
# 조회수:  319
# 댓글수:  0
# 추천수:  0
# ---------------
# 22
# 제목:  나가긴 귀찮고 주인은 반가운 댕댕
# 글쓴이:  데이비드썸원
# 날짜:  2021.11.18 00:13
# 조회수:  2446
# 댓글수:  0
# 추천수:  0
# ---------------
# 23
# 제목:  빠니보틀 : 곽튜브 성공의 1할은 내 덕이다
# 글쓴이:  헤에에이~
# 날짜:  2021.11.18 00:13
# 조회수:  5872
# 댓글수:  4
# 추천수:  4
# ---------------
# 24
# 제목:  발렌시아가 행사에 참석한 한소희, 모니카, 더보이즈 주연
# 글쓴이:  지수
# 날짜:  2021.11.18 00:08
# 조회수:  7107
# 댓글수:  26
# 추천수:  11
# ---------------
# 25
# 제목:  쓰니 기준 우리나라에서 화보 가장 잘찍는 남자배우
# 글쓴이:  Busu031
# 날짜:  2021.11.17
# 조회수:  2958
# 댓글수:  3
# 추천수:  0
# ---------------
# 26
# 제목:  굴삭기 고인물
# 글쓴이:  한 편의 너
# 날짜:  2021.11.17
# 조회수:  402
# 댓글수:  0
# 추천수:  0
# ---------------
# 27
# 제목:  아이슬란드 파그라달스퍄들 화산폭발
# 글쓴이:  에자키카루
# 날짜:  2021.11.17
# 조회수:  565
# 댓글수:  0
# 추천수:  0
# ---------------
# 28
# 제목:  귀여운 새끼멍뭉이
# 글쓴이:  임팩트FBI
# 날짜:  2021.11.17
# 조회수:  1106
# 댓글수:  1
# 추천수:  1
# ---------------
# 29
# 제목:  34살 먹고 첫 직장 생김...내 썰 좀 들어주라
# 글쓴이:  아야나미
# 날짜:  2021.11.17
# 조회수:  7303
# 댓글수:  19
# 추천수:  4
# ---------------
# 30
# 제목:  무스펙 서울대생의 취업후기 및 준비과정
# 글쓴이:  임팩트FBI
# 날짜:  2021.11.17
# 조회수:  9584
# 댓글수:  14
# 추천수:  4
# ---------------
# 31
# 제목:  다이어트 위해 소식 시작한 매직박 오늘 점심 식단.jpg
# 글쓴이:  옹뇸뇸뇸
# 날짜:  2021.11.17
# 조회수:  4637
# 댓글수:  0
# 추천수:  0
# ---------------
# 32
# 제목:  영화 많이 본
# 글쓴이:  용시대박
# 날짜:  2021.11.17
# 조회수:  263
# 댓글수:  0
# 추천수:  0
# ---------------
# 33
# 제목:  가을,겨울에 흔히 볼 수있는 공대생 패션
# 글쓴이:  오징어게임 일
# 날짜:  2021.11.17
# 조회수:  2855
# 댓글수:  0
# 추천수:  0
# ---------------
# 34
# 제목:  야외야스로 몸살앓는 천혜의 경관....news
# 글쓴이:  다시 태어날
# 날짜:  2021.11.17
# 조회수:  2691
# 댓글수:  1
# 추천수:  0
# ---------------
# 35
# 제목:  개발자인줄 알았던 내가 눈떠보니 디자이너.jpg
# 글쓴이:  에자키히카루
# 날짜:  2021.11.17
# 조회수:  11188
# 댓글수:  34
# 추천수:  8
# ---------------
# 36
# 제목:  롤 중계할 때 클템어 해석ㅋㅋㅋ.jpg
# 글쓴이:  언행일치
# 날짜:  2021.11.17
# 조회수:  503
# 댓글수:  0
# 추천수:  0
# ---------------
# 37
# 제목:  옛날 메이플스토리 추억의 희귀템들 - 2
# 글쓴이:  세정언니링
# 날짜:  2021.11.17
# 조회수:  697
# 댓글수:  0
# 추천수:  0
# ---------------
# 38
# 제목:  남편이 저 모르게 또 어린이집을 안보냈네요.jpgif
# 글쓴이:  토끼네
# 날짜:  2021.11.17
# 조회수:  6668
# 댓글수:  6
# 추천수:  3
# ---------------
# 39
# 제목:  스파이더맨 예고 내려갔었던 이유.gif
# 글쓴이:  싯떼루네`ワ
# 날짜:  2021.11.17
# 조회수:  5289
# 댓글수:  5
# 추천수:  1
# ---------------
# 40
# 제목:  연합뉴스 근황.jpg
# 글쓴이:  따온
# 날짜:  2021.11.17
# 조회수:  1272
# 댓글수:  0
# 추천수:  0
# ---------------
# 41
# 제목:  요즘 해외 영화 수입 열심히 하는 소지섭
# 글쓴이:  '''
# 날짜:  2021.11.17
# 조회수:  2178
# 댓글수:  0
# 추천수:  1
# ---------------
# 42
# 제목:  바람핀 친엄마 vs 새엄마
# 글쓴이:  그녀의이름은
# 날짜:  2021.11.17
# 조회수:  3431
# 댓글수:  0
# 추천수:  2
# ---------------
# 43
# 제목:  '무단 이탈→복귀'한 IBK 조송화
# 글쓴이:  세상에 잘생긴
# 날짜:  2021.11.17
# 조회수:  483
# 댓글수:  0
# 추천수:  0
# ---------------
# 44
# 제목:  벌새를 닮은 귀여운 벌레
# 글쓴이:  송희진
# 날짜:  2021.11.17
# 조회수:  708
# 댓글수:  1
# 추천수:  0
# ---------------
# 45
# 제목:  닥터 옥토퍼스는 머리가 띵했을듯
# 글쓴이:  옹뇸뇸뇸
# 날짜:  2021.11.17
# 조회수:  828
# 댓글수:  0
# 추천수:  0
# ---------------
# 46
# 제목:  군대 선임이 비빔면 미지근하다고 다시 해오래.eta
# 글쓴이:  청량섹시 김태
# 날짜:  2021.11.17
# 조회수:  3667
# 댓글수:  0
# 추천수:  0
# ---------------
# 47
# 제목:  전소민도 한수 접고 가는 민경훈 예능력
# 글쓴이:  김상연
# 날짜:  2021.11.17
# 조회수:  1613
# 댓글수:  0
# 추천수:  0
# ---------------
# 48
# 제목:  지능이 높을수록 성욕이 강하다.jpg
# 글쓴이:  311869_return
# 날짜:  2021.11.17
# 조회수:  11649
# 댓글수:  17
# 추천수:  1
# ---------------
# 49
# 제목:  초봉 6500만원·휴가 기간 무제한…그래도 '노는 직원' 없는 비결
# 글쓴이:  위례신다도시
# 날짜:  2021.11.17
# 조회수:  15489
# 댓글수:  23
# 추천수:  11
# ---------------
# 50
# 제목:  곧 룰루 0티어 만들어줄 픽스 버그
# 글쓴이:  원 + 원
# 날짜:  2021.11.17
# 조회수:  503
# 댓글수:  0
# 추천수:  0
# ---------------
# 51
# 제목:  만델라 효과 모음.jpg
# 글쓴이:  펄스
# 날짜:  2021.11.17
# 조회수:  497
# 댓글수:  0
# 추천수:  0
# ---------------
# 52
# 제목:  김재우 근황.jpg
# 글쓴이:  알케이
# 날짜:  2021.11.17
# 조회수:  2438
# 댓글수:  1
# 추천수:  1
# ---------------
# 53
# 제목:  프랑스 대박별 한국학&한국어 전공 경쟁률 현황 ㄷㄷㄷ jpg
# 글쓴이:  뇌잘린
# 날짜:  2021.11.17
# 조회수:  12186
# 댓글수:  28
# 추천수:  5
# ---------------
# 54
# 제목:  조용히 시장 평가가 올라가고 있는 1인
# 글쓴이:  오징어게임 일
# 날짜:  2021.11.17
# 조회수:  1662
# 댓글수:  0
# 추천수:  0
# ---------------
# 55
# 제목:  타짜의 야바위 기술을 일반인이 캐치 할 수 있을까???
# 글쓴이:  위례신다도시
# 날짜:  2021.11.17
# 조회수:  483
# 댓글수:  0
# 추천수:  0
# ---------------
# 56
# 제목:  유튜브에서 킬링타임용으로 역주행중인 애니.JPG
# 글쓴이:  널 사랑해 영
# 날짜:  2021.11.17
# 조회수:  2360
# 댓글수:  1
# 추천수:  1
# ---------------
# 57
# 제목:  실시간 T1 상황
# 글쓴이:  WANNA ONE 하
# 날짜:  2021.11.17
# 조회수:  827
# 댓글수:  0
# 추천수:  0
# ---------------
# 58
# 제목:  약쟁이 검거 완료
# 글쓴이:  ㄷH학수학능력
# 날짜:  2021.11.17
# 조회수:  1948
# 댓글수:  1
# 추천수:  0
# ---------------
# 59
# 제목:  사람들이 은근 모르는 레드벨벳 명곡
# 글쓴이:  세븐틴 원 +
# 날짜:  2021.11.17
# 조회수:  15038
# 댓글수:  62
# 추천수:  0
# ---------------
# 60
# 제목:  데스노트가 디씨유저에게 갔다면
# 글쓴이:  311342_return
# 날짜:  2021.11.17
# 조회수:  1104
# 댓글수:  0
# 추천수:  0
# ---------------
# 61
# 제목:  헌신짝돼서 차였는데 결혼한뒤 연락 온 전남친
# 글쓴이:  용시대박
# 날짜:  2021.11.17
# 조회수:  17260
# 댓글수:  18
# 추천수:  4
# ---------------
# 62
# 제목:  여친이랑 모텔 옴
# 글쓴이:  까까까
# 날짜:  2021.11.17
# 조회수:  13335
# 댓글수:  18
# 추천수:  1
# ---------------
# 63
# 제목:  스파이더맨 노웨이홈 쿠키 유출 논란...jpg
# 글쓴이:  게임을시작하
# 날짜:  2021.11.17
# 조회수:  2870
# 댓글수:  1
# 추천수:  0
# ---------------
# 64
# 제목:  현재 매탈남 유튜브 상황.JPG
# 글쓴이:  알케이
# 날짜:  2021.11.17
# 조회수:  4071
# 댓글수:  5
# 추천수:  2
# ---------------
# 65
# 제목:  [서울] 상습 체납자 만296명 공개...서울시 체납 1위는 중국인
# 글쓴이:  누눈나난
# 날짜:  2021.11.17
# 조회수:  8201
# 댓글수:  13
# 추천수:  3
# ---------------
# 66
# 제목:  일본 편의점 2년차 알바생 후기
# 글쓴이:  김상연
# 날짜:  2021.11.17
# 조회수:  15507
# 댓글수:  10
# 추천수:  2
# ---------------
# 67
# 제목:  일본에서 av배우 인식
# 글쓴이:  김상연
# 날짜:  2021.11.17
# 조회수:  12642
# 댓글수:  18
# 추천수:  5
# ---------------
# 68
# 제목:  탕수육 부먹
# 글쓴이:  한 편의 너
# 날짜:  2021.11.17
# 조회수:  557
# 댓글수:  1
# 추천수:  0
# ---------------
# 69
# 제목:  먹고싶은걸 먹으면 수명이 줄어드는 병...jpg
# 글쓴이:  디귿
# 날짜:  2021.11.17
# 조회수:  3344
# 댓글수:  1
# 추천수:  1
# ---------------
# 70
# 제목:  공대생이 체크남방만 입는다는 편견을 버려달라는 사람. jpg
# 글쓴이:  키토제닉
# 날짜:  2021.11.17
# 조회수:  7141
# 댓글수:  3
# 추천수:  0
# ---------------
# 71
# 제목:  집에서 나갈땐 다리가 6개인데, 돌아올땐 2개인 것은?
# 글쓴이:  qksxks ghtjr
# 날짜:  2021.11.17
# 조회수:  1625
# 댓글수:  1
# 추천수:  0
# ---------------
# 72
# 제목:  (혐오주의) 윤서인 "안중근은 대한민국 군인과 아무런 상관이 없다"
# 글쓴이:  미니온즈
# 날짜:  2021.11.17
# 조회수:  1857
# 댓글수:  3
# 추천수:  0
# ---------------
# 73
# 제목:  미친 다 어렵네
# 글쓴이:  다니엘_린데
# 날짜:  2021.11.17
# 조회수:  1048
# 댓글수:  0
# 추천수:  0
# ---------------
# 74
# 제목:  서장훈이 말하는 찐 남사친과 위장 남사친.jpg
# 글쓴이:  next
# 날짜:  2021.11.17
# 조회수:  17534
# 댓글수:  16
# 추천수:  8
# ---------------
# 75
# 제목:  과장이 지각한 신입을 불러 지적했는데
# 글쓴이:  션국이네 메르
# 날짜:  2021.11.17
# 조회수:  1807
# 댓글수:  1
# 추천수:  0
# ---------------
# 76
# 제목:  넥슨 최악의 업데이트 원탑은?.jpg
# 글쓴이:  천러러러
# 날짜:  2021.11.17
# 조회수:  2521
# 댓글수:  2
# 추천수:  0
# ---------------
# 77
# 제목:  대기업 14년 후기.jpg
# 글쓴이:  윤정한 아내
# 날짜:  2021.11.17
# 조회수:  25176
# 댓글수:  34
# 추천수:  22
# ---------------
# 78
# 제목:  아기들을 버리고 가는 엄마.jpg
# 글쓴이:  ㄷH학수학능력
# 날짜:  2021.11.17
# 조회수:  7662
# 댓글수:  6
# 추천수:  0
# ---------------
# 79
# 제목:  틴더 어플 쓴다고 온갖 악플 받은 여자유튜버.jpg
# 글쓴이:  캐리와 장난감
# 날짜:  2021.11.17
# 조회수:  15261
# 댓글수:  26
# 추천수:  7
# ---------------
# 80
# 제목:  넷플릭스 지옥 imdb 평가.....jpg
# 글쓴이:  S.COUPS.
# 날짜:  2021.11.17
# 조회수:  7390
# 댓글수:  2
# 추천수:  1
# ---------------
# 81
# 제목:  요즘 청소년 희망직업 1위 공무원 아님
# 글쓴이:  해르반창식
# 날짜:  2021.11.17
# 조회수:  27513
# 댓글수:  31
# 추천수:  14
# ---------------
# 82
# 제목:  강아지 산책중 동네 다른 강아지 목줄이 풀려있어서 깜짝 놀랐는데
# 글쓴이:  방탄전용날개
# 날짜:  2021.11.17
# 조회수:  10580
# 댓글수:  11
# 추천수:  3
# ---------------
# 83
# 제목:  식물갤의 전투력 ㄷㄷㄷ
# 글쓴이:  세정언니링
# 날짜:  2021.11.17
# 조회수:  2528
# 댓글수:  0
# 추천수:  2
# ---------------
# 84
# 제목:  섹시한 톰포드 신제품.jpg
# 글쓴이:  영은수
# 날짜:  2021.11.17
# 조회수:  3783
# 댓글수:  1
# 추천수:  1
# ---------------
# 85
# 제목:  1억에 대한 인식
# 글쓴이:  널 사랑해 영
# 날짜:  2021.11.17
# 조회수:  5740
# 댓글수:  4
# 추천수:  0
# ---------------
# 86
# 제목:  세상에서 가장 신기한 도형
# 글쓴이:  311869_return
# 날짜:  2021.11.17
# 조회수:  4167
# 댓글수:  6
# 추천수:  0
# ---------------
# 87
# 제목:  '김종국 약물' 주장한 유튜버, 전과 기록
# 글쓴이:  할리뱅입니더
# 날짜:  2021.11.17
# 조회수:  25666
# 댓글수:  30
# 추천수:  8
# ---------------
# 88
# 제목:  한때 유행하더니 요즘 아무도 안입는 옷
# 글쓴이:  '''
# 날짜:  2021.11.17
# 조회수:  43956
# 댓글수:  123
# 추천수:  15
# ---------------
# 89
# 제목:  무도 장면중 너무 웃겼던 장면
# 글쓴이:  방탄전용날개
# 날짜:  2021.11.17
# 조회수:  2896
# 댓글수:  3
# 추천수:  0
# ---------------
# 90
# 제목:  여자친구가 순수아리아인 혈통.JPG
# 글쓴이:  She
# 날짜:  2021.11.17
# 조회수:  35715
# 댓글수:  23
# 추천수:  12
# ---------------
# 91
# 제목:  자위대 식사.jpg
# 글쓴이:  더보이즈 상
# 날짜:  2021.11.17
# 조회수:  4190
# 댓글수:  1
# 추천수:  0
# ---------------
# 92
# 제목:  中, 가상사설망(VPN) 단속 강화…역대 최고 강력 규제
# 글쓴이:  몹시호시
# 날짜:  2021.11.17
# 조회수:  1513
# 댓글수:  2
# 추천수:  1
# ---------------
# 93
# 제목:  서로 좋아하면 섹스하는 세상
# 글쓴이:  JOSHUA95
# 날짜:  2021.11.17
# 조회수:  6618
# 댓글수:  8
# 추천수:  0
# ---------------
# 94
# 제목:  다꾸는 코르셋+유아퇴행 하는 행위이다
# 글쓴이:  꿍치따치
# 날짜:  2021.11.17
# 조회수:  3158
# 댓글수:  3
# 추천수:  0
# ---------------
# 95
# 제목:  식물갤의 품격
# 글쓴이:  보이프렌드 민
# 날짜:  2021.11.17
# 조회수:  2382
# 댓글수:  3
# 추천수:  2
# ---------------
# 96
# 제목:  하성운 6번째 미니앨범 'Electrified : Urban Nostalg..
# 글쓴이:  던던둔둔
# 날짜:  2021.11.17
# 조회수:  44
# 댓글수:  0
# 추천수:  0
# ---------------
# 97
# 제목:  현재 논란중인 편의점 옷 안에 손 넣고 강제 추행 사건
# 글쓴이:  깐부
# 날짜:  2021.11.17
# 조회수:  4230
# 댓글수:  2
# 추천수:  1
# ---------------
# 98
# 제목:  [영화] 킹스맨 : 퍼스트 에이전트 국내 12월 22일 개봉 확정
# 글쓴이:  성우야♡
# 날짜:  2021.11.17
# 조회수:  1572
# 댓글수:  3
# 추천수:  0
# ---------------
# 99
# 제목:  킅갤) 창원 카페에 도란 출몰
# 글쓴이:  이진기(30)
# 날짜:  2021.11.17
# 조회수:  4362
# 댓글수:  4
# 추천수:  0
# ---------------
# 100
# 제목:  기안84 동물학대 논란
# 글쓴이:  다시 태어날
# 날짜:  2021.11.17
# 조회수:  43733
# 댓글수:  125
# 추천수:  11
# ---------------
# 101
# 제목:  일제시절 일본도 놀라게한 매국노
# 글쓴이:  311342_return
# 날짜:  2021.11.17
# 조회수:  14549
# 댓글수:  17
# 추천수:  8
# ---------------
# 102
# 제목:  내일 수능 세상에서 가장 요란하게 보는 아이돌
# 글쓴이:  베리베리 연
# 날짜:  2021.11.17
# 조회수:  26889
# 댓글수:  55
# 추천수:  35
# ---------------
# 103
# 제목:  연우 vs 조이 vs 쯔위.gif
# 글쓴이:  더보이즈 김영
# 날짜:  2021.11.17
# 조회수:  2492
# 댓글수:  2
# 추천수:  0
# ---------------
# 104
# 제목:  메밀소바 먹다 죽을 뻔한 사람.jpg
# 글쓴이:  세기말
# 날짜:  2021.11.17
# 조회수:  2692
# 댓글수:  2
# 추천수:  1
# ---------------
# 105
# 제목:  평생 생선구이를 제공받을 수 있다면?
# 글쓴이:  Side to Side
# 날짜:  2021.11.17
# 조회수:  3302
# 댓글수:  12
# 추천수:  0
# ---------------
# 106
# 제목:  올리브영 핸드크림 판매순
# 글쓴이:  307559_return
# 날짜:  2021.11.17
# 조회수:  53948
# 댓글수:  337
# 추천수:  8
# ---------------
# 107
# 제목:  90년대생 이상만 안다는 책
# 글쓴이:  solio
# 날짜:  2021.11.17
# 조회수:  2872
# 댓글수:  1
# 추천수:  0
# ---------------
# 108
# 제목:  메이플스토리에서 가장 희귀하고 인기가 많은 데미지 스킨
# 글쓴이:  맠맠잉
# 날짜:  2021.11.17
# 조회수:  4824
# 댓글수:  5
# 추천수:  0
# ---------------
# 109
# 제목:  요즘 학생들은 못 믿는 시간표
# 글쓴이:  Jeddd
# 날짜:  2021.11.17
# 조회수:  33754
# 댓글수:  106
# 추천수:  9
# ---------------
# 110
# 제목:  수능 앞두고 도시락 예행 연습중이신 수험생 어머님들.jpg
# 글쓴이:  Side to Side
# 날짜:  2021.11.17
# 조회수:  17335
# 댓글수:  28
# 추천수:  8
# ---------------
# 111
# 제목:  데뷔 첫 음방 1위 해냈다…원어스, '쇼! 챔피언' 정상 '눈물 소감'
# 글쓴이:  이리저리요리
# 날짜:  2021.11.17
# 조회수:  1522
# 댓글수:  2
# 추천수:  2
# ---------------
# 112
# 제목:  여대생 두명 음주운전 ㅈ됐다
# 글쓴이:  키토제닉
# 날짜:  2021.11.17
# 조회수:  58945
# 댓글수:  152
# 추천수:  5
# ---------------
# 113
# 제목:  형 여기 남자 알바중 제일 잘생겼어요
# 글쓴이:  비비의주인
# 날짜:  2021.11.17
# 조회수:  3514
# 댓글수:  4
# 추천수:  0
# ---------------
# 114
# 제목:  10대들이 뽑은 호불호 음식 1위.jpg
# 글쓴이:  더보이즈 상
# 날짜:  2021.11.17
# 조회수:  42999
# 댓글수:  131
# 추천수:  6
# ---------------
# 115
# 제목:  한시간의 접전끝에
# 글쓴이:  bongsunha22
# 날짜:  2021.11.17
# 조회수:  140
# 댓글수:  0
# 추천수:  0
# ---------------
# 116
# 제목:  회사 구내식당에 제철 생선이 나온다길래 부리나케 갔더니
# 글쓴이:  따온
# 날짜:  2021.11.17
# 조회수:  21238
# 댓글수:  13
# 추천수:  3
# ---------------
# 117
# 제목:  신혼부부 젓가락 방향 논란
# 글쓴이:  방탄전용날개
# 날짜:  2021.11.17
# 조회수:  59973
# 댓글수:  213
# 추천수:  4
# ---------------
# 118
# 제목:  아들 컴퓨터를 무참히 박살낸 디시인의 아버지
# 글쓴이:  마카롱꿀떡
# 날짜:  2021.11.17
# 조회수:  9033
# 댓글수:  7
# 추천수:  2
# ---------------
# 119
# 제목:  여자친구가 있는데 여사친 만나는거 오바임?
# 글쓴이:  유기현 (25)
# 날짜:  2021.11.17
# 조회수:  5263
# 댓글수:  3
# 추천수:  0
# ---------------
# 120
# 제목:  대학동기 손절한 이유
# 글쓴이:  백챠
# 날짜:  2021.11.17
# 조회수:  4072
# 댓글수:  1
# 추천수:  0
# ---------------
# 121
# 제목:  뚱냥이의 비애
# 글쓴이:  따온
# 날짜:  2021.11.17
# 조회수:  4130
# 댓글수:  4
# 추천수:  3
# ---------------
# 122
# 제목:  요즘애들키가 네덜란드수준으로 큰 이유
# 글쓴이:  사랑을먹고자
# 날짜:  2021.11.17
# 조회수:  4862
# 댓글수:  3
# 추천수:  1
# ---------------
# 123
# 제목:  다이어트 카페 아웃풋 투탑.jpg
# 글쓴이:  더보이즈 상
# 날짜:  2021.11.17
# 조회수:  41264
# 댓글수:  60
# 추천수:  27
# ---------------
# 124
# 제목:  2000년대 초반 인기 폭발이였던 소개팅 예능.JPG
# 글쓴이:  토끼네
# 날짜:  2021.11.17
# 조회수:  9049
# 댓글수:  10
# 추천수:  4
# ---------------
# 125
# 제목:  서로 아싸화법 쓰는 레드벨벳 슬기 웬디.jpg
# 글쓴이:  오징어게임 일
# 날짜:  2021.11.17
# 조회수:  28545
# 댓글수:  36
# 추천수:  25
# ---------------
# 126
# 제목:  중학생들이 복도에서 담배피고 오줌까지 싸서 주의줬더니 다음날 식당에 벌어진..
# 글쓴이:  307559_return
# 날짜:  2021.11.17
# 조회수:  9588
# 댓글수:  43
# 추천수:  4
# ---------------
# 127
# 제목:  전성기 시절 잘 나갔던 과자 원탑.JPG
# 글쓴이:  디귿
# 날짜:  2021.11.17
# 조회수:  3016
# 댓글수:  3
# 추천수:  0
# ---------------
# 128
# 제목:  투신하러 아파트 올라갔다더니..여고생 집 '주거 침입'
# 글쓴이:  별빛쏟아지는
# 날짜:  2021.11.17
# 조회수:  3640
# 댓글수:  0
# 추천수:  2
# ---------------
# 129
# 제목:  비주얼 살벌한 개구리 음식을 먹은 여돌의 반응.jpg
# 글쓴이:  슈슈슈슈슈슈
# 날짜:  2021.11.17
# 조회수:  3577
# 댓글수:  3
# 추천수:  1
# ---------------
# 130
# 제목:  자담치킨4000원 할인받자!!
# 글쓴이:  방탄소년단★
# 날짜:  2021.11.17
# 조회수:  2195
# 댓글수:  6
# 추천수:  0
# ---------------
# 131
# 제목:  정준하가 말하는 무도 멤버들 예능 순위 (ft.찐경규)
# 글쓴이:  kang7561
# 날짜:  2021.11.17
# 조회수:  2570
# 댓글수:  1
# 추천수:  0
# ---------------
# 132
# 제목:  팀장한테 퇴사권유받은 직원
# 글쓴이:  용시대박
# 날짜:  2021.11.17
# 조회수:  25706
# 댓글수:  90
# 추천수:  6
# ---------------
# 133
# 제목:  겨울간식 칼로리
# 글쓴이:  스트로베리문
# 날짜:  2021.11.17
# 조회수:  4351
# 댓글수:  5
# 추천수:  1
# ---------------
# 134
# 제목:  거대한 고양이
# 글쓴이:  다시 태어날
# 날짜:  2021.11.17
# 조회수:  1987
# 댓글수:  2
# 추천수:  1
# ---------------
# 135
# 제목:  치즈케이크에 로고찍기
# 글쓴이:  한 편의 너
# 날짜:  2021.11.17
# 조회수:  19777
# 댓글수:  51
# 추천수:  13
# ---------------
# 136
# 제목:  영화 흥행 후 판매량 70배 떡상했다는 앨범
# 글쓴이:  태 리
# 날짜:  2021.11.17
# 조회수:  29756
# 댓글수:  15
# 추천수:  7
# ---------------
# 137
# 제목:  경찰,'윤석열 처가 양평 공흥지구 특혜' 의혹 정식 수사 전환
# 글쓴이:  토토얌
# 날짜:  2021.11.17
# 조회수:  257
# 댓글수:  0
# 추천수:  0
# ---------------
# 138
# 제목:  생일파티한 한소희 목걸이 귀걸이 브랜드.. 대박 예쁨
# 글쓴이:  누눈나난
# 날짜:  2021.11.17
# 조회수:  37150
# 댓글수:  64
# 추천수:  19
# ---------------
# 139
# 제목:  "새끼 길고양이 얼굴을 토치로 불질러”...경찰, 수사 착수
# 글쓴이:  MANSAE
# 날짜:  2021.11.17
# 조회수:  4850
# 댓글수:  23
# 추천수:  1
# ---------------
# 140
# 제목:  화려수수 조합으로 데뷔 첫 화보 찍은 여돌
# 글쓴이:  버가버가뷰
# 날짜:  2021.11.17
# 조회수:  1480
# 댓글수:  0
# 추천수:  0
# ---------------
# 141
# 제목:  붐 담당 일진.jpg
# 글쓴이:  윤정한 아내
# 날짜:  2021.11.17
# 조회수:  2071
# 댓글수:  1
# 추천수:  0
# ---------------
# 142
# 제목:  젤다의 전설 안해본 사람들은 잘 모르는 것 jpg
# 글쓴이:  몹시호시
# 날짜:  2021.11.17
# 조회수:  2809
# 댓글수:  3
# 추천수:  0
# ---------------
# 143
# 제목:  황당해진 대만 상황
# 글쓴이:  알케이
# 날짜:  2021.11.17
# 조회수:  11647
# 댓글수:  15
# 추천수:  3
# ---------------
# 144
# 제목:  신서유기 연말굿즈.jpg
# 글쓴이:  Twenty_Four
# 날짜:  2021.11.17
# 조회수:  9986
# 댓글수:  12
# 추천수:  4
# ---------------
# 145
# 제목:  편의점 성추행 벌금 100만원
# 글쓴이:  ~~
# 날짜:  2021.11.17
# 조회수:  1185
# 댓글수:  0
# 추천수:  0
# ---------------
# 146
# 제목:  붐이 홈쇼핑 못 나오는 이유.JPG
# 글쓴이:  션국이네 메르
# 날짜:  2021.11.17
# 조회수:  10505
# 댓글수:  6
# 추천수:  1
# ---------------
# 147
# 제목:  필력 미친 홈플러스더클럽 인스타그램 게시물.jpg
# 글쓴이:  나천재
# 날짜:  2021.11.17
# 조회수:  4435
# 댓글수:  6
# 추천수:  1
# ---------------
# 148
# 제목:  냄새에 정신줄 놓은 고양이들 영상 모음
# 글쓴이:  누눈나난
# 날짜:  2021.11.17
# 조회수:  665
# 댓글수:  0
# 추천수:  1
# ---------------
# 149
# 제목:  레전드 충김볶 레시피에 이은 박나래 해장주스 레시피
# 글쓴이:  야들아해장하
# 날짜:  2021.11.17
# 조회수:  4154
# 댓글수:  1
# 추천수:  0
# ---------------
# 150
# 제목:  [충격] 이재명 수행실장 한준호 前 아나 '영부인 출산 국격 여부' 논란 ..
# 글쓴이:  햅뿌
# 날짜:  2021.11.17
# 조회수:  6535
# 댓글수:  20
# 추천수:  3
# ---------------
# 151
# 제목:  한국인으로 이루어진 남자아이돌 그룹
# 글쓴이:  강쥐강아쥐
# 날짜:  2021.11.17
# 조회수:  1757
# 댓글수:  0
# 추천수:  2
# ---------------
# 152
# 제목:  판) 십몇년 전 입양보낸 아이를 찾는 것... 너무 이기적일까요
# 글쓴이:  겟
# 날짜:  2021.11.17
# 조회수:  18595
# 댓글수:  34
# 추천수:  4
# ---------------
# 153
# 제목:  라면의 면발이 노란색인 이유
# 글쓴이:  겟
# 날짜:  2021.11.17
# 조회수:  9137
# 댓글수:  18
# 추천수:  1
# ---------------
# 154
# 제목:  해리포터 팬들이 뽑은 시리즈 최악의 영화
# 글쓴이:  세븐틴 비니
# 날짜:  2021.11.17
# 조회수:  11756
# 댓글수:  31
# 추천수:  11
# ---------------
# 155
# 제목:  섹시를 잘못 이해하고 있는 남돌
# 글쓴이:  몽몽댕
# 날짜:  2021.11.17
# 조회수:  2734
# 댓글수:  0
# 추천수:  0
# ---------------
# 156
# 제목:  시대를 앞서갔던 20년전 게임
# 글쓴이:  sweetly
# 날짜:  2021.11.17
# 조회수:  3169
# 댓글수:  1
# 추천수:  1
# ---------------
# 157
# 제목:  사과티비 수위 ㄹㅇ 실화냐 ㄷㄷ...
# 글쓴이:  sweetly
# 날짜:  2021.11.17
# 조회수:  52531
# 댓글수:  104
# 추천수:  27
# ---------------
# 158
# 제목:  난 이 음료수들 눈감고 마시면 다 구별 가능하다 vs 아니다
# 글쓴이:  김상연
# 날짜:  2021.11.17
# 조회수:  1525
# 댓글수:  1
# 추천수:  0
# ---------------
# 159
# 제목:  미국의 로켓 발사 기술 근황.gif
# 글쓴이:  더보이즈 상
# 날짜:  2021.11.17
# 조회수:  1800
# 댓글수:  0
# 추천수:  3
# ---------------
# 160
# 제목:  여돌의 새로운 청순계보 이을 것 같은 방과후설렘 참가자
# 글쓴이:  즐겨즐겨
# 날짜:  2021.11.17
# 조회수:  5113
# 댓글수:  4
# 추천수:  3
# ---------------
# 161
# 제목:  어제 일어난 하이마트 돌진 사고 전말
# 글쓴이:  벤츄리
# 날짜:  2021.11.17
# 조회수:  26730
# 댓글수:  59
# 추천수:  13
# ---------------
# 162
# 제목:  성과급, 인센티브 퇴직금 꿀팁
# 글쓴이:  Vitro
# 날짜:  2021.11.17
# 조회수:  4340
# 댓글수:  3
# 추천수:  2
# ---------------
# 163
# 제목:  대면공연이 신기한 에스파 윈터
# 글쓴이:  오이카와 토비
# 날짜:  2021.11.17
# 조회수:  32426
# 댓글수:  31
# 추천수:  17
# ---------------
# 164
# 제목:  청담역의 위엄.jpg
# 글쓴이:  중 천러
# 날짜:  2021.11.17
# 조회수:  14240
# 댓글수:  5
# 추천수:  1
# ---------------
# 165
# 제목:  피가 되고 살이 되는 현실 인생 팁
# 글쓴이:  BGRU
# 날짜:  2021.11.17
# 조회수:  44826
# 댓글수:  65
# 추천수:  11
# ---------------
# 166
# 제목:  꿀잼실험
# 글쓴이:  다시 태어날
# 날짜:  2021.11.17
# 조회수:  1358
# 댓글수:  1
# 추천수:  0
# ---------------
# 167
# 제목:  집돌이 and 밖순이 결혼은 파국인가요?
# 글쓴이:  MANSAE
# 날짜:  2021.11.17
# 조회수:  19113
# 댓글수:  47
# 추천수:  4
# ---------------
# 168
# 제목:  시레기 말리는 중인 음식점
# 글쓴이:  천러러러
# 날짜:  2021.11.17
# 조회수:  11803
# 댓글수:  18
# 추천수:  2
# ---------------
# 169
# 제목:  흔한 시골 국수집 풍경
# 글쓴이:  쿵쾅맨
# 날짜:  2021.11.17
# 조회수:  5181
# 댓글수:  3
# 추천수:  1
# ---------------
# 170
# 제목:  45층에서 의자를 던진 여자.gif
# 글쓴이:  따릉해요
# 날짜:  2021.11.17
# 조회수:  16431
# 댓글수:  29
# 추천수:  8
# ---------------
# 171
# 제목:  사람들이 스파이더맨을 좋아하는 이유를 잘 보여준다는 영화 장면.jpg
# 글쓴이:  아이디할게너
# 날짜:  2021.11.17
# 조회수:  8136
# 댓글수:  13
# 추천수:  19
# ---------------
# 172
# 제목:  19세기 러시아의 달 덕후 화가
# 글쓴이:  송희진
# 날짜:  2021.11.17
# 조회수:  8103
# 댓글수:  10
# 추천수:  16
# ---------------
# 173
# 제목:  군대가면 총만 쏜다는 미필들 봐라
# 글쓴이:  용시대박
# 날짜:  2021.11.17
# 조회수:  3968
# 댓글수:  3
# 추천수:  0
# ---------------
# 174
# 제목:  의외로 국내 판타지 소설 입문 작품으로 많이 꼽히는 소설
# 글쓴이:  윤세원
# 날짜:  2021.11.17
# 조회수:  14225
# 댓글수:  55
# 추천수:  4
# ---------------
# 175
# 제목:  日 언론"오징어게임 방영된 모든 나라에서 대히트를 기록한 이유"일본 반응
# 글쓴이:  김성규내꺼`ワ
# 날짜:  2021.11.17
# 조회수:  16657
# 댓글수:  33
# 추천수:  5
# ---------------
# 176
# 제목:  아빠한테 배틀넷 아이디 걸렸다 저런
# 글쓴이:  할리뱅입니더
# 날짜:  2021.11.17
# 조회수:  3593
# 댓글수:  1
# 추천수:  0
# ---------------
# 177
# 제목:  프로필 사진으로 리즈 찍은 뮤지컬 배우
# 글쓴이:  멍멍개
# 날짜:  2021.11.17
# 조회수:  9619
# 댓글수:  4
# 추천수:  1
# ---------------
# 178
# 제목:  [속보] 정부 "30세 미만, 모더나 대신 화이자 코로나19 백신 권고”
# 글쓴이:  소고기 육전
# 날짜:  2021.11.17
# 조회수:  91213
# 댓글수:  140
# 추천수:  4
# ---------------
# 179
# 제목:  앙버터빵 급발진
# 글쓴이:  윤세원
# 날짜:  2021.11.17
# 조회수:  30068
# 댓글수:  44
# 추천수:  11
# ---------------
# 180
# 제목:  차은우 아닌척 수업 듣는 차은우
# 글쓴이:  다시 태어날
# 날짜:  2021.11.17
# 조회수:  22190
# 댓글수:  31
# 추천수:  9
# ---------------
# 181
# 제목:  안철수 "대입 수시 폐지, 사법고시 부활시킨다"
# 글쓴이:  사라나
# 날짜:  2021.11.17
# 조회수:  54818
# 댓글수:  128
# 추천수:  24
# ---------------
# 182
# 제목:  조선족이 한국에 불만인점
# 글쓴이:  solio
# 날짜:  2021.11.17
# 조회수:  83783
# 댓글수:  224
# 추천수:  12
# ---------------
# 183
# 제목:  유튜브 스타로 떡상하고 있는 정상수.JPG
# 글쓴이:  다시 태어날
# 날짜:  2021.11.17
# 조회수:  4419
# 댓글수:  1
# 추천수:  1
# ---------------
# 184
# 제목:  유전자 이상 때문에 귀가 4개인 고양이
# 글쓴이:  널 사랑해 영
# 날짜:  2021.11.17
# 조회수:  20222
# 댓글수:  49
# 추천수:  15
# ---------------
# 185
# 제목:  큐브 아이돌 2022 시즌그리팅 출시 공지
# 글쓴이:  닐라닐라
# 날짜:  2021.11.17
# 조회수:  1645
# 댓글수:  0
# 추천수:  0
# ---------------
# 186
# 제목:  [단독] "판사님, 시x 진짜" 욕설한 한서희, 필로폰 투약 징역 '1년 ..
# 글쓴이:  초코B
# 날짜:  2021.11.17
# 조회수:  35177
# 댓글수:  44
# 추천수:  15
# ---------------
# 187
# 제목:  지방 사람들이 처음 서울 왔을때 의외로 가장 놀란다는 것
# 글쓴이:  아야나미
# 날짜:  2021.11.17
# 조회수:  4014
# 댓글수:  1
# 추천수:  1
# ---------------
# 188
# 제목:  애기들한테 똥 닦는 법 알려주시는 유치원 선생님
# 글쓴이:  djekxn
# 날짜:  2021.11.17
# 조회수:  12932
# 댓글수:  13
# 추천수:  3
# ---------------
# 189
# 제목:  짐 옮기는거 도와주는 리트리버들
# 글쓴이:  유기현 (25)
# 날짜:  2021.11.17
# 조회수:  13238
# 댓글수:  22
# 추천수:  15
# ---------------
# 190
# 제목:  방탄소년단, 오늘 미국 출국…LA 콘서트→시상식서 팬들 만난다
# 글쓴이:  행복한왕만두
# 날짜:  2021.11.17
# 조회수:  1181
# 댓글수:  0
# 추천수:  0

# %%
df=pd.DataFrame(result)
df
# Out:
#                                               제목          글쓴이  \
# 0                              졸업안시켜준 교수 죽인 대학원생       남준이는왜이
# 1                        배달음식에 이물질이 나왔을때 대처법.JPG        ♡김태형♡
# 2                           열라면 누가 맛있다 그랬니? .JPG  Wannable(워너
# 3                                        19세 이상만       방탄소년단★
# 4                     노웨이홈 삼파이더맨 출연이 99퍼인 이유.jpg          뇌잘린
# ..                                           ...          ...
# 185  [단독] "판사님, 시x 진짜" 욕설한 한서희, 필로폰 투약 징역 '1년 ..          초코B
# 186              지방 사람들이 처음 서울 왔을때 의외로 가장 놀란다는 것         아야나미
# 187                   애기들한테 똥 닦는 법 알려주시는 유치원 선생님       djekxn
# 188                            짐 옮기는거 도와주는 리트리버들     유기현 (25)
# 189           방탄소년단, 오늘 미국 출국…LA 콘서트→시상식서 팬들 만난다       행복한왕만두
#
#                    날짜    조회수 댓글수 추천수
# 0    2021.11.18 01:09      1   0   0
# 1    2021.11.18 01:04    278   0   0
# 2    2021.11.18 01:04    282   0   0
# 3    2021.11.18 00:56    550   0   0
# 4    2021.11.18 00:50   1642   5   1
# ..                ...    ...  ..  ..
# 185        2021.11.17  35177  44  15
# 186        2021.11.17   4014   1   1
# 187        2021.11.17  12932  13   3
# 188        2021.11.17  13238  22  15
# 189        2021.11.17   1181   0   0
#
# [190 rows x 6 columns]

# %%
df.to_excel('data/instiz_인티포털.xlsx')

# %%
# 전체 인기글

# %%
contents2=soup.select('#rank1to10 > div')
contents2.extend(soup.select('#rank11to20 > div'))

# %%
#전체 인기글
cnt=1
result2=[]
for i in contents2:
    tmp={}
    print('-'*15)
    print(cnt)
    
    #게시판 추출
    category=i.find('div', {"class":"minitext"}).text
    print("게시판: ", category)
    
    
    # 제목 추출
    if cnt<11:
        title=i.select_one('#rank1to10 > div > div.rank_subject > a').text.strip()
    else:
        title=i.select_one('#rank11to20 > div > div.rank_subject > a').text.strip()
    print("제목: ", title)
    
   
    
#    # 글쓴이 추출
#    writer_tag = i.find('td', {"class":"minitext2 listnm"})
#    if writer_tag is not None: # None 값이 있으므로 조건문을 통해 회피 
#        writer = writer_tag.text
#      
#    else:
#        writer = "없음"
#    print("글쓴이: ", writer)
    
#     # 유동이나 고닉이 아닌 글쓴이 옆에 있는 ip 추출
#     ip_tag = i.find('td', class_='gall_writer ub-writer').find('span', class_='ip')
#     if ip_tag is not None:  # None 값이 있으므로 조건문을 통해 회피 
#         ip = ip_tag.text
#         print("ip: ", ip)



#    # 날짜 추출 
#    date=i.find('td',{"class":"listno regdate"}).text
#    print("날짜: ",date)
    
    
#    # 조회 수 추출
#    views = i.find_all('td', {"class":"listno"})[2].text
#    print("조회수: ", views)


    # 댓글 수
    comment=i.find('a',{"class":"cmt"})
    if comment==None:
        comment=0
    else:
        comment=comment.text
    print("댓글수: ", comment)
    
#    # 추천 수 추출
#    recommend = i.find_all('td', {"class":"listno"})[3].text
#    print("추천수: ", recommend)

    tmp['게시판']=category
    tmp['제목']=title
#    tmp['글쓴이']=writer
#    tmp['날짜']=date
#    tmp['조회수']=views
    tmp['댓글수']=comment
#    tmp['추천수']=recommend
    
    result2.append(tmp)
    
    cnt=cnt+1
# Out:
# ---------------
# 1
# 게시판:  인티포털
# 제목:  임시완이 공개한 연애횟수.jpg
# 댓글수:  10
# ---------------
# 2
# 게시판:  익명잡담
# 제목:  우리집 고삼이 바람 쐬고 온다고 하고 이 시간에 울면서 나갔..
# 댓글수:  6
# ---------------
# 3
# 게시판:  익명잡담
# 제목:  와씨 라면스프 먹는데 대.존.맛
# 댓글수:  12
# ---------------
# 4
# 게시판:  인티포털
# 제목:  용산 아이맥스때문에 남친이랑 싸운 여자.jpg
# 댓글수:  49
# ---------------
# 5
# 게시판:  익명잡담
# 제목:  이틀에 한번 샤워하면 더러워?
# 댓글수:  39
# ---------------
# 6
# 게시판:  인티포털
# 제목:  최근들어 정말 예쁘다는 생각이 드는 분
# 댓글수:  33
# ---------------
# 7
# 게시판:  익명잡담
# 제목:  하루에 6~7시간 씩 하는
# 댓글수:  5
# ---------------
# 8
# 게시판:  인티포털
# 제목:  미쳐버린 어느 웹소설 설정
# 댓글수:  6
# ---------------
# 9
# 게시판:  인티포털
# 제목:  트위치 어느 여스트리머의 방송정지 사유.jpgif
# 댓글수:  4
# ---------------
# 10
# 게시판:  익명잡담
# 제목:  브라렛이랑 그냥 브라랑 뭐가달라??
# 댓글수:  11
# ---------------
# 11
# 게시판:  익명잡담
# 제목:  [연애중] 계란말이된 썰 푼다,,
# 댓글수:  2
# ---------------
# 12
# 게시판:  인티포털
# 제목:  요즘 sns에 미남들이 많은 이유
# 댓글수:  18
# ---------------
# 13
# 게시판:  인티포털
# 제목:  삼성 핸드폰 테스트 엔지니어도 어쩔 수 없는 취향
# 댓글수:  1
# ---------------
# 14
# 게시판:  익명잡담
# 제목:  나 쌍수 망한 걸까… 심각하게 재수술 고민 중인데 한번씩 봐..
# 댓글수:  23
# ---------------
# 15
# 게시판:  인티포털
# 제목:  KFC 선넘는 신메뉴 폰치밥.jpg
# 댓글수:  12
# ---------------
# 16
# 게시판:  인티포털
# 제목:  환경호르몬 많이 나오는데 흐린눈 하는 사람 많은 것.jpg
# 댓글수:  42
# ---------------
# 17
# 게시판:  익명잡담
# 제목:  어른들 말 중에 틀린말 하나 없다..를 느끼게해준 말
# 댓글수:  7
# ---------------
# 18
# 게시판:  익명잡담
# 제목:  나 네일아트 자랑해도 될까?(두근
# 댓글수:  14
# ---------------
# 19
# 게시판:  인티포털
# 제목:  다음날 숙취가 없다는 술
# 댓글수:  13
# ---------------
# 20
# 게시판:  익명잡담
# 제목:  아빠가 대기업 임원인게 엄청 대단한거임?
# 댓글수:  8

# %%
df2=pd.DataFrame(result2)
df2
# Out:
#      게시판                                   제목 댓글수
# 0   인티포털                    임시완이 공개한 연애횟수.jpg  10
# 1   익명잡담  우리집 고삼이 바람 쐬고 온다고 하고 이 시간에 울면서 나갔..   6
# 2   익명잡담                    와씨 라면스프 먹는데 대.존.맛  12
# 3   인티포털            용산 아이맥스때문에 남친이랑 싸운 여자.jpg  49
# 4   익명잡담                     이틀에 한번 샤워하면 더러워?  39
# 5   인티포털                최근들어 정말 예쁘다는 생각이 드는 분  33
# 6   익명잡담                       하루에 6~7시간 씩 하는   5
# 7   인티포털                       미쳐버린 어느 웹소설 설정   6
# 8   인티포털          트위치 어느 여스트리머의 방송정지 사유.jpgif   4
# 9   익명잡담                  브라렛이랑 그냥 브라랑 뭐가달라??  11
# 10  익명잡담                   [연애중] 계란말이된 썰 푼다,,   2
# 11  인티포털                   요즘 sns에 미남들이 많은 이유  18
# 12  인티포털          삼성 핸드폰 테스트 엔지니어도 어쩔 수 없는 취향   1
# 13  익명잡담  나 쌍수 망한 걸까… 심각하게 재수술 고민 중인데 한번씩 봐..  23
# 14  인티포털                  KFC 선넘는 신메뉴 폰치밥.jpg  12
# 15  인티포털     환경호르몬 많이 나오는데 흐린눈 하는 사람 많은 것.jpg  42
# 16  익명잡담        어른들 말 중에 틀린말 하나 없다..를 느끼게해준 말   7
# 17  익명잡담                   나 네일아트 자랑해도 될까?(두근  14
# 18  인티포털                        다음날 숙취가 없다는 술  13
# 19  익명잡담               아빠가 대기업 임원인게 엄청 대단한거임?   8

# %%
df2.to_excel('data/instiz_전체인기글.xlsx')

# %%
# 인티포털 인기글

# %%
contents3=soup.select('#rank1to10_menu > div')
contents3.extend(soup.select('#rank11to20_menu > div'))

# %%
#전체 인기글
cnt=1
result3=[]
for i in contents3:
    tmp={}
    print('-'*15)
    print(cnt)
    
    
    # 제목 추출
    if cnt<11:
        title=i.select_one('#rank1to10_menu > div > div.rank_subject > a').text.strip()
    else:
        title=i.select_one('#rank11to20_menu > div > div.rank_subject > a').text.strip()
    print("제목: ", title)
    
   
    
#    # 글쓴이 추출
#    writer_tag = i.find('td', {"class":"minitext2 listnm"})
#    if writer_tag is not None: # None 값이 있으므로 조건문을 통해 회피 
#        writer = writer_tag.text
#      
#    else:
#        writer = "없음"
#    print("글쓴이: ", writer)
    
#     # 유동이나 고닉이 아닌 글쓴이 옆에 있는 ip 추출
#     ip_tag = i.find('td', class_='gall_writer ub-writer').find('span', class_='ip')
#     if ip_tag is not None:  # None 값이 있으므로 조건문을 통해 회피 
#         ip = ip_tag.text
#         print("ip: ", ip)



#    # 날짜 추출 
#    date=i.find('td',{"class":"listno regdate"}).text
#    print("날짜: ",date)
    
    
#    # 조회 수 추출
#    views = i.find_all('td', {"class":"listno"})[2].text
#    print("조회수: ", views)


    # 댓글 수
    comment=i.find('a',{"class":"cmt"})
    if comment==None:
        comment=0
    else:
        comment=comment.text
    print("댓글수: ", comment)
    
#    # 추천 수 추출
#    recommend = i.find_all('td', {"class":"listno"})[3].text
#    print("추천수: ", recommend)

    tmp['제목']=title
#    tmp['글쓴이']=writer
#    tmp['날짜']=date
#    tmp['조회수']=views
    tmp['댓글수']=comment
#    tmp['추천수']=recommend
    
    result3.append(tmp)
    
    cnt=cnt+1
# Out:
# ---------------
# 1
# 제목:  임시완이 공개한 연애횟수.jpg
# 댓글수:  10
# ---------------
# 2
# 제목:  용산 아이맥스때문에 남친이랑 싸운 여자.jpg
# 댓글수:  49
# ---------------
# 3
# 제목:  최근들어 정말 예쁘다는 생각이 드는 분
# 댓글수:  33
# ---------------
# 4
# 제목:  미쳐버린 어느 웹소설 설정
# 댓글수:  6
# ---------------
# 5
# 제목:  요즘 sns에 미남들이 많은 이유
# 댓글수:  18
# ---------------
# 6
# 제목:  다음날 숙취가 없다는 술
# 댓글수:  13
# ---------------
# 7
# 제목:  트위치 어느 여스트리머의 방송정지 사유.jpgif
# 댓글수:  4
# ---------------
# 8
# 제목:  환경호르몬 많이 나오는데 흐린눈 하는 사람 많은 것.jpg
# 댓글수:  42
# ---------------
# 9
# 제목:  삼성 핸드폰 테스트 엔지니어도 어쩔 수 없는 취향
# 댓글수:  1
# ---------------
# 10
# 제목:  KFC 선넘는 신메뉴 폰치밥.jpg
# 댓글수:  12
# ---------------
# 11
# 제목:  4만원에 여친한테 정떨어지면 내가 이상한건가?
# 댓글수:  0
# ---------------
# 12
# 제목:  일반인이 아이돌 메이크업을 받았을때.jpg
# 댓글수:  42
# ---------------
# 13
# 제목:  연구원에게 발각되어 만짐당하는 팔라스고양이
# 댓글수:  14
# ---------------
# 14
# 제목:  털관리 잘한 리트리버
# 댓글수:  2
# ---------------
# 15
# 제목:  파리에서 오징어게임 배우로 오해받는 유튜버
# 댓글수:  36
# ---------------
# 16
# 제목:  마블 최초로 토마토 썩은 이터널스
# 댓글수:  38
# ---------------
# 17
# 제목:  할로윈때 뚱뚱해지는 서양다람쥐들
# 댓글수:  67
# ---------------
# 18
# 제목:  사고치는 고양이.jpg
# 댓글수:  3
# ---------------
# 19
# 제목:  서울 뷔페 3대장
# 댓글수:  0
# ---------------
# 20
# 제목:  영국 데일리메일 홈피에서 발견된 한류...jpg
# 댓글수:  0

# %%
df3=pd.DataFrame(result3)
df3
# Out:
#                                   제목 댓글수
# 0                  임시완이 공개한 연애횟수.jpg  10
# 1          용산 아이맥스때문에 남친이랑 싸운 여자.jpg  49
# 2              최근들어 정말 예쁘다는 생각이 드는 분  33
# 3                     미쳐버린 어느 웹소설 설정   6
# 4                 요즘 sns에 미남들이 많은 이유  18
# 5                      다음날 숙취가 없다는 술  13
# 6        트위치 어느 여스트리머의 방송정지 사유.jpgif   4
# 7   환경호르몬 많이 나오는데 흐린눈 하는 사람 많은 것.jpg  42
# 8        삼성 핸드폰 테스트 엔지니어도 어쩔 수 없는 취향   1
# 9                KFC 선넘는 신메뉴 폰치밥.jpg  12
# 10         4만원에 여친한테 정떨어지면 내가 이상한건가?   0
# 11           일반인이 아이돌 메이크업을 받았을때.jpg  42
# 12           연구원에게 발각되어 만짐당하는 팔라스고양이  14
# 13                       털관리 잘한 리트리버   2
# 14           파리에서 오징어게임 배우로 오해받는 유튜버  36
# 15                마블 최초로 토마토 썩은 이터널스  38
# 16                 할로윈때 뚱뚱해지는 서양다람쥐들  67
# 17                      사고치는 고양이.jpg   3
# 18                         서울 뷔페 3대장   0
# 19        영국 데일리메일 홈피에서 발견된 한류...jpg   0

# %%
df3.to_excel('data/instiz_인티포털인기글.xlsx')
