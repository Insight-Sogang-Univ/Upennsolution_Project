# %%
from bs4 import BeautifulSoup as bs
import requests as req
import pandas as pd

# %%
base_url='https://www.bobaedream.co.kr/list?code=best&vdate='
#headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.54 Safari/537.36"}

# %%
#페이지네이션

# %%
raw=req.get(base_url)
#soup=bs(raw.text, 'lxml')

# %%
soup=bs(raw.content, 'html.parser')

# %%
contents = soup.find('tbody').find_all('tr')   #,{'class':['li li_best2_pop1','li li_best2_pop0']}

# %%
len(contents)
# Out:
# 30

# %%
cnt=1
result=[]
for i in contents:
    tmp={}
    print('-'*15)
    print(cnt)
    cnt=cnt+1
    
    # 게시판 추출
    category=i.find('td', {"class":"category"}).get('title')
    print("분야: ", category)

    # 제목 추출
    title=i.find('a',{"class":"bsubject"}).text.strip()
    print("제목: ", title)
    
   
    
    # 글쓴이 추출
    writer_tag = i.find('span', {"class":"author"})
    if writer_tag is not None: # None 값이 있으므로 조건문을 통해 회피 
        writer = writer_tag.get('title')
      
    else:
        writer = "없음"
    print("글쓴이: ", writer)
    
#    # 유동이나 고닉이 아닌 글쓴이 옆에 있는 ip 추출
#    ip_tag = i.find('td', class_='gall_writer ub-writer').find('span', class_='ip')
#    if ip_tag is not None:  # None 값이 있으므로 조건문을 통해 회피 
#        ip = ip_tag.text
#        print("ip: ", ip)



    # 날짜 추출 
    date=i.find('td',{"class":"date"}).text
    print("날짜: ",date)
    
    
    # 조회 수 추출
    views = i.find('td',{"class":"count"}).text
    print("조회수: ", views)


    # 댓글 수
    comment=i.find('span',{"class":"Comment"})
    if comment==None:
        comment=0
    else:
        comment=comment.find('strong', {"class":"totreply"}).text
    print("댓글수: ", comment)
   

    # 추천 수 추출
    recommend = i.find('td', {"class":"recomm"}).text
    print("추천수: ", recommend)
    
    tmp['분야']=category
    tmp['제목']=title
    tmp['글쓴이']=writer
    tmp['날짜']=date
    tmp['조회수']=views
    tmp['댓글수']=comment
    tmp['추천수']=recommend
    
    result.append(tmp)
# Out:
# ---------------
# 1
# 분야:  유머게시판
# 제목:  오늘밤 열린공감tv 보세요~
# 글쓴이:  복수는처절하게
# 날짜:  18:52
# 조회수:  2101
# 댓글수:  8
# 추천수:  50
# ---------------
# 2
# 분야:  유머게시판
# 제목:  개인소장용 사진
# 글쓴이:  Quark
# 날짜:  18:39
# 조회수:  5395
# 댓글수:  19
# 추천수:  64
# ---------------
# 3
# 분야:  유머게시판
# 제목:  대가족 클라스.. jpg
# 글쓴이:  푸른거북이
# 날짜:  18:37
# 조회수:  3193
# 댓글수:  7
# 추천수:  23
# ---------------
# 4
# 분야:  유머게시판
# 제목:  "왜 이게 더럽게 무서운 거냐면" ㅡ
# 글쓴이:  U2Bono
# 날짜:  18:33
# 조회수:  7052
# 댓글수:  8
# 추천수:  108
# ---------------
# 5
# 분야:  유머게시판
# 제목:  로봇학대??
# 글쓴이:  몽키들의리틀보이
# 날짜:  18:28
# 조회수:  1764
# 댓글수:  9
# 추천수:  44
# ---------------
# 6
# 분야:  유머게시판
# 제목:  요즘 가장 무서운 사람
# 글쓴이:  미스박닭똥집
# 날짜:  18:20
# 조회수:  11257
# 댓글수:  35
# 추천수:  157
# ---------------
# 7
# 분야:  유머게시판
# 제목:  대통령 선거 2등이 누구죠?
# 글쓴이:  미스박닭똥집
# 날짜:  18:13
# 조회수:  6843
# 댓글수:  17
# 추천수:  85
# ---------------
# 8
# 분야:  유머게시판
# 제목:  난 이재명이 존나 싫다!!!!!
# 글쓴이:  slineTT
# 날짜:  18:12
# 조회수:  1397
# 댓글수:  18
# 추천수:  27
# ---------------
# 9
# 분야:  유머게시판
# 제목:  이재명 페북
# 글쓴이:  복수는처절하게
# 날짜:  18:10
# 조회수:  6400
# 댓글수:  17
# 추천수:  188
# ---------------
# 10
# 분야:  유머게시판
# 제목:  《전우용 학자》이건 '로봇성' 문제인가요? ㅡ
# 글쓴이:  U2Bono
# 날짜:  18:05
# 조회수:  839
# 댓글수:  5
# 추천수:  30
# ---------------
# 11
# 분야:  유머게시판
# 제목:  계급낮은 알바세끼들아
# 글쓴이:  개같은남자
# 날짜:  18:05
# 조회수:  4943
# 댓글수:  39
# 추천수:  116
# ---------------
# 12
# 분야:  유머게시판
# 제목:  헝가리 방문 중인 문 대통령이 제일 먼저 찾은 곳
# 글쓴이:  윈스9192
# 날짜:  17:59
# 조회수:  9885
# 댓글수:  21
# 추천수:  232
# ---------------
# 13
# 분야:  유머게시판
# 제목:  '우리가 반격할 기회'
# 글쓴이:  베스트댓글러
# 날짜:  17:59
# 조회수:  5740
# 댓글수:  14
# 추천수:  145
# ---------------
# 14
# 분야:  유머게시판
# 제목:  투표를 똑바로 해야하는 이유
# 글쓴이:  걸인28호
# 날짜:  17:58
# 조회수:  3295
# 댓글수:  11
# 추천수:  84
# ---------------
# 15
# 분야:  유머게시판
# 제목:  이재명이 형수한테 욕했다고????패륜이라고?
# 글쓴이:  Quark
# 날짜:  17:57
# 조회수:  6794
# 댓글수:  41
# 추천수:  173
# ---------------
# 16
# 분야:  유머게시판
# 제목:  대통령의 한 걸음 한 걸음씩
# 글쓴이:  바보멘
# 날짜:  17:49
# 조회수:  6489
# 댓글수:  15
# 추천수:  103
# ---------------
# 17
# 분야:  유머게시판
# 제목:  윤짜장 지지하는 기생충
# 글쓴이:  동대장
# 날짜:  17:47
# 조회수:  5776
# 댓글수:  11
# 추천수:  87
# ---------------
# 18
# 분야:  유머게시판
# 제목:  대장동 어이 없는거 4 가지
# 글쓴이:  수색저격수
# 날짜:  17:45
# 조회수:  3856
# 댓글수:  17
# 추천수:  74
# ---------------
# 19
# 분야:  유머게시판
# 제목:  화목하고 정다운 가족사진^^
# 글쓴이:  Quark
# 날짜:  17:44
# 조회수:  4921
# 댓글수:  11
# 추천수:  66
# ---------------
# 20
# 분야:  유머게시판
# 제목:  중국 "중국영화가 한국에서 1위 할 것"
# 글쓴이:  스폰지밥뚱이
# 날짜:  17:43
# 조회수:  13718
# 댓글수:  59
# 추천수:  189
# ---------------
# 21
# 분야:  유머게시판
# 제목:  김빙삼옹 트윗 ㅎㄷㄷ
# 글쓴이:  장여사남편
# 날짜:  17:41
# 조회수:  7109
# 댓글수:  11
# 추천수:  200
# ---------------
# 22
# 분야:  유머게시판
# 제목:  연매출 400억원 순대 회사의 공지
# 글쓴이:  인디애나존스
# 날짜:  17:40
# 조회수:  11155
# 댓글수:  35
# 추천수:  71
# ---------------
# 23
# 분야:  유머게시판
# 제목:  이런 *신 같은 게 대통령이었으니 나라망신 제대로지.
# 글쓴이:  스타쉽드립퍼즈
# 날짜:  17:34
# 조회수:  7312
# 댓글수:  17
# 추천수:  85
# ---------------
# 24
# 분야:  유머게시판
# 제목:  견찰들이 부들댄다는 개봉 예정 영화 내용
# 글쓴이:  인디애나존스
# 날짜:  17:30
# 조회수:  7247
# 댓글수:  19
# 추천수:  112
# ---------------
# 25
# 분야:  교통사고/사건/블랙박스
# 제목:  보배드림 당일 가입한 한녀들의 특징
# 글쓴이:  인생행복하게살자
# 날짜:  17:28
# 조회수:  4858
# 댓글수:  15
# 추천수:  87
# ---------------
# 26
# 분야:  유머게시판
# 제목:  차기 대통령 근황
# 글쓴이:  베스트댓글러
# 날짜:  17:27
# 조회수:  12943
# 댓글수:  30
# 추천수:  167
# ---------------
# 27
# 분야:  유머게시판
# 제목:  문재인 대통령의 위대함
# 글쓴이:  바보멘
# 날짜:  17:20
# 조회수:  10538
# 댓글수:  60
# 추천수:  198
# ---------------
# 28
# 분야:  유머게시판
# 제목:  이건 정말 역대급 짤이네요 ㄷㄷㄷㄷ
# 글쓴이:  스톰트루퍼스
# 날짜:  17:19
# 조회수:  8174
# 댓글수:  14
# 추천수:  46
# ---------------
# 29
# 분야:  유머게시판
# 제목:  '아님 말고 팀'이 유게에 왔을 때 ㅡ
# 글쓴이:  U2Bono
# 날짜:  17:18
# 조회수:  5416
# 댓글수:  11
# 추천수:  69
# ---------------
# 30
# 분야:  유머게시판
# 제목:  집회 근황
# 글쓴이:  베스트댓글러
# 날짜:  17:18
# 조회수:  7632
# 댓글수:  29
# 추천수:  124

# %%
df=pd.DataFrame(result)
df
# Out:
#               분야                             제목       글쓴이     날짜    조회수 댓글수  \
# 0          유머게시판                오늘밤 열린공감tv 보세요~   복수는처절하게  18:52   2101   8
# 1          유머게시판                       개인소장용 사진     Quark  18:39   5395  19
# 2          유머게시판                  대가족 클라스.. jpg     푸른거북이  18:37   3193   7
# 3          유머게시판           "왜 이게 더럽게 무서운 거냐면" ㅡ    U2Bono  18:33   7052   8
# 4          유머게시판                         로봇학대??  몽키들의리틀보이  18:28   1764   9
# 5          유머게시판                   요즘 가장 무서운 사람    미스박닭똥집  18:20  11257  35
# 6          유머게시판                대통령 선거 2등이 누구죠?    미스박닭똥집  18:13   6843  17
# 7          유머게시판              난 이재명이 존나 싫다!!!!!   slineTT  18:12   1397  18
# 8          유머게시판                         이재명 페북   복수는처절하게  18:10   6400  17
# 9          유머게시판      《전우용 학자》이건 '로봇성' 문제인가요? ㅡ    U2Bono  18:05    839   5
# 10         유머게시판                    계급낮은 알바세끼들아     개같은남자  18:05   4943  39
# 11         유머게시판    헝가리 방문 중인 문 대통령이 제일 먼저 찾은 곳    윈스9192  17:59   9885  21
# 12         유머게시판                   '우리가 반격할 기회'    베스트댓글러  17:59   5740  14
# 13         유머게시판                투표를 똑바로 해야하는 이유     걸인28호  17:58   3295  11
# 14         유머게시판       이재명이 형수한테 욕했다고????패륜이라고?     Quark  17:57   6794  41
# 15         유머게시판                대통령의 한 걸음 한 걸음씩       바보멘  17:49   6489  15
# 16         유머게시판                   윤짜장 지지하는 기생충       동대장  17:47   5776  11
# 17         유머게시판                대장동 어이 없는거 4 가지     수색저격수  17:45   3856  17
# 18         유머게시판                화목하고 정다운 가족사진^^     Quark  17:44   4921  11
# 19         유머게시판         중국 "중국영화가 한국에서 1위 할 것"    스폰지밥뚱이  17:43  13718  59
# 20         유머게시판                    김빙삼옹 트윗 ㅎㄷㄷ     장여사남편  17:41   7109  11
# 21         유머게시판            연매출 400억원 순대 회사의 공지    인디애나존스  17:40  11155  35
# 22         유머게시판  이런 *신 같은 게 대통령이었으니 나라망신 제대로지.   스타쉽드립퍼즈  17:34   7312  17
# 23         유머게시판         견찰들이 부들댄다는 개봉 예정 영화 내용    인디애나존스  17:30   7247  19
# 24  교통사고/사건/블랙박스            보배드림 당일 가입한 한녀들의 특징  인생행복하게살자  17:28   4858  15
# 25         유머게시판                      차기 대통령 근황    베스트댓글러  17:27  12943  30
# 26         유머게시판                   문재인 대통령의 위대함       바보멘  17:20  10538  60
# 27         유머게시판            이건 정말 역대급 짤이네요 ㄷㄷㄷㄷ    스톰트루퍼스  17:19   8174  14
# 28         유머게시판          '아님 말고 팀'이 유게에 왔을 때 ㅡ    U2Bono  17:18   5416  11
# 29         유머게시판                          집회 근황    베스트댓글러  17:18   7632  29
#
#     추천수
# 0    50
# 1    64
# 2    23
# 3   108
# 4    44
# 5   157
# 6    85
# 7    27
# 8   188
# 9    30
# 10  116
# 11  232
# 12  145
# 13   84
# 14  173
# 15  103
# 16   87
# 17   74
# 18   66
# 19  189
# 20  200
# 21   71
# 22   85
# 23  112
# 24   87
# 25  167
# 26  198
# 27   46
# 28   69
# 29  124

# %%
df.to_excel('data/보배드림.xlsx')
