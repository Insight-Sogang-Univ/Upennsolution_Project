# %%
from bs4 import BeautifulSoup as bs
import requests as req
import pandas as pd

# %%
base_url='https://pann.nate.com/talk/c20001'
#headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.54 Safari/537.36"}

# %%
#페이지네이션

# %%
raw=req.get(base_url)
#soup=bs(raw.text, 'lxml')

# %%
soup=bs(raw.content, 'html.parser')

# %%
contents = soup.find_all('tr')   #,{'class':['li li_best2_pop1','li li_best2_pop0']}

# %%
del contents[0]

# %%
href=[]
for i in contents:
    url=i.find('td',{"class":"subject"}).find_all('a')[-1]['href']
    href.append('https://pann.nate.com'+url)

# %%
href
# Out:
# ['https://pann.nate.com/talk/363391562?page=1',
#  'https://pann.nate.com/talk/363391537?page=1',
#  'https://pann.nate.com/talk/363391472?page=1',
#  'https://pann.nate.com/talk/363391414?page=1',
#  'https://pann.nate.com/talk/363391365?page=1',
#  'https://pann.nate.com/talk/363391233?page=1',
#  'https://pann.nate.com/talk/363391134?page=1',
#  'https://pann.nate.com/talk/363391123?page=1',
#  'https://pann.nate.com/talk/363391013?page=1',
#  'https://pann.nate.com/talk/363390994?page=1',
#  'https://pann.nate.com/talk/363390990?page=1',
#  'https://pann.nate.com/talk/363390986?page=1',
#  'https://pann.nate.com/talk/363390971?page=1',
#  'https://pann.nate.com/talk/363390939?page=1',
#  'https://pann.nate.com/talk/363390868?page=1',
#  'https://pann.nate.com/talk/363390795?page=1',
#  'https://pann.nate.com/talk/363390791?page=1',
#  'https://pann.nate.com/talk/363390741?page=1',
#  'https://pann.nate.com/talk/363390703?page=1',
#  'https://pann.nate.com/talk/363390561?page=1',
#  'https://pann.nate.com/talk/363390527?page=1',
#  'https://pann.nate.com/talk/363390505?page=1',
#  'https://pann.nate.com/talk/363390216?page=1',
#  'https://pann.nate.com/talk/363390093?page=1',
#  'https://pann.nate.com/talk/363390089?page=1',
#  'https://pann.nate.com/talk/363390088?page=1',
#  'https://pann.nate.com/talk/363390053?page=1',
#  'https://pann.nate.com/talk/363389994?page=1',
#  'https://pann.nate.com/talk/363389875?page=1',
#  'https://pann.nate.com/talk/363389840?page=1']

# %%
cnt=1
for i in href:
    print('-'*15)
    print(cnt)
    cnt=cnt+1
    
    raw=req.get(i)
    soup=bs(raw.content, 'html.parser')    
    
    
    
    
    
    # 제목 추출
    title=soup.find('div',{"class":"post-tit-info"}).find('h4').text.strip()
    print("제목: ", title)
    
   
    
#     # 글쓴이 추출
#     writer_tag = i.find('td', class_='gall_writer ub-writer').find('span', class_='nickname')
#     if writer_tag is not None: # None 값이 있으므로 조건문을 통해 회피 
#         writer = writer_tag.text
#         print("글쓴이: ", writer)
        
#     else:
#         print("글쓴이: ", "없음")
    
#     # 유동이나 고닉이 아닌 글쓴이 옆에 있는 ip 추출
#     ip_tag = i.find('td', class_='gall_writer ub-writer').find('span', class_='ip')
#     if ip_tag is not None:  # None 값이 있으므로 조건문을 통해 회피 
#         ip = ip_tag.text
#         print("ip: ", ip)


    
#     inform = i.find_all('td')


    # 날짜 추출 
    date=soup.find('span',{"class":"date"}).text
    print("날짜: ",date)
    
    # 조회 수 추출

    views = soup.find('span',{"class":"count"}).text.replace('조회','')
    print("조회수: ", views)



    # 댓글 수
    comment=soup.find('span',{"class":"num"}).find('strong').text
    print("댓글수: ", comment)
    
    # 추천 수 추출
    recommend = soup.find('div', class_='btnbox up').find('span',{"class":"count"}).text
    print("추천수: ", recommend)
# Out:
# ---------------
# 1
# 제목:  [도둑잡아요] 대구 동구 차털이범 잡아요 도와주세요
# 날짜:  2021.11.02 10:18
# 조회수:  5
# 댓글수:  0
# 추천수:  0
# ---------------
# 2
# 제목:  미등기 토지 상속받는법 조언 구합니다
# 날짜:  2021.11.02 10:16
# 조회수:  3
# 댓글수:  0
# 추천수:  0
# ---------------
# 3
# 제목:  장 봐온 물건들 포장지 소독제로 다 닦으시는분?
# 날짜:  2021.11.02 10:08
# 조회수:  3
# 댓글수:  0
# 추천수:  0
# ---------------
# 4
# 제목:  20대엔 어디서 연애해야하나요
# 날짜:  2021.11.02 09:57
# 조회수:  10
# 댓글수:  1
# 추천수:  0
# ---------------
# 5
# 제목:  그림 피드백 해주세요
# 날짜:  2021.11.02 09:49
# 조회수:  6
# 댓글수:  1
# 추천수:  0
# ---------------
# 6
# 제목:  김선호 아직도 죽일듯이 까는 여성시대랑 트위터 진짜 무섭고 환멸 ;;;;
# 날짜:  2021.11.02 09:25
# 조회수:  37
# 댓글수:  0
# 추천수:  0
# ---------------
# 7
# 제목:  20대여성분들 친구들 생일 챙기시나요??(선물)
# 날짜:  2021.11.02 09:02
# 조회수:  7
# 댓글수:  0
# 추천수:  0
# ---------------
# 8
# 제목:  컨디션이 좋으면 좋은 태도가 나기 쉽고,
# 날짜:  2021.11.02 09:00
# 조회수:  4
# 댓글수:  0
# 추천수:  0
# ---------------
# 9
# 제목:  요즘 느끼는것
# 날짜:  2021.11.02 08:23
# 조회수:  11
# 댓글수:  0
# 추천수:  0
# ---------------
# 10
# 제목:  디스패치 김선호  킬링포인트
# 날짜:  2021.11.02 08:18
# 조회수:  403
# 댓글수:  1
# 추천수:  7
# ---------------
# 11
# 제목:  김선호 사건을 심리적 관점에서 본다면
# 날짜:  2021.11.02 08:16
# 조회수:  212
# 댓글수:  3
# 추천수:  0
# ---------------
# 12
# 제목:  육
# 날짜:  2021.11.02 08:13
# 조회수:  7
# 댓글수:  0
# 추천수:  0
# ---------------
# 13
# 제목:  밤새 오토바이타고 온 남편한테 밥시켜먹는게 아깝다며..
# 날짜:  2021.11.02 08:05
# 조회수:  11
