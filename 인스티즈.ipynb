# %%
from bs4 import BeautifulSoup as bs
import requests as req
import pandas as pd
import datetime
from datetime import timedelta

# %%
base_url='https://www.instiz.net/pt?page=1'
headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.54 Safari/537.36"}

# %%
d = datetime.datetime.now()
now = d.strftime('%X')

# %%
cnt=1
result=[]
for i in range(1,11):
    params={"page":i}
    raw=req.get(base_url,params=params, headers=headers)
    soup=bs(raw.content, 'html.parser')
    contents = soup.find_all('tr')
    del contents[:20]
    del contents[19:len(contents)]
    
    for i in contents:
        tmp={}
        print('-'*15)
        print(cnt)
        cnt=cnt+1


        # 제목 추출
        title=i.find('span',{"id":"subject"}).text.strip()
        print("제목: ", title)



        # 글쓴이 추출
        writer_tag = i.find('td', {"class":"minitext2 listnm"})
        if writer_tag is not None: # None 값이 있으므로 조건문을 통해 회피 
            writer = writer_tag.text

        else:
            writer = "없음"
        print("글쓴이: ", writer)

    #     # 유동이나 고닉이 아닌 글쓴이 옆에 있는 ip 추출
    #     ip_tag = i.find('td', class_='gall_writer ub-writer').find('span', class_='ip')
    #     if ip_tag is not None:  # None 값이 있으므로 조건문을 통해 회피 
    #         ip = ip_tag.text
    #         print("ip: ", ip)



        # 날짜 추출 
        date=i.find('td',{"class":"listno regdate"}).text
        if len(date)<=5:
            if len(date)<=4:
                date=d.strftime('%Y.%m.%d ')+'0'+date
            else:
                date=d.strftime('%Y.%m.%d ')+date
        else:
            date=d.strftime('%Y')+'.'+date[:5]
        print("날짜: ",date)


        # 조회 수 추출
        views = i.find_all('td', {"class":"listno"})[2].text
        print("조회수: ", views)


        # 댓글 수
        comment=i.find('a',{"id":"view_cmt"})
        if comment==None:
            comment=0
        else:
            comment=comment.text
        print("댓글수: ", comment)

        # 추천 수 추출
        recommend = i.find_all('td', {"class":"listno"})[3].text
        print("추천수: ", recommend)


        tmp['제목']=title
        tmp['글쓴이']=writer
        tmp['날짜']=date
        tmp['조회수']=views
        tmp['댓글수']=comment
        tmp['추천수']=recommend

        result.append(tmp)
# Out:
# ---------------
# 1
# 제목:  배고파요.. 연어초밥좀 주세요.jpg
# 글쓴이:  세븐틴 원 +
# 날짜:  2021.11.18 13:08
# 조회수:  409
# 댓글수:  1
# 추천수:  0
# ---------------
# 2
# 제목:  윤민섭 기자) 커즈, 에이밍 KT행 루머.. KT측은 노코멘트
# 글쓴이:  윤세원
# 날짜:  2021.11.18 13:02
# 조회수:  104
# 댓글수:  0
# 추천수:  0
# ---------------
# 3
# 제목:  원어스, 데뷔 1044일 만에 첫 1위 "꿈 같아..긍정적인 역사 써 내려..
# 글쓴이:  강쥐강아쥐
# 날짜:  2021.11.18 12:51
# 조회수:  2153
# 댓글수:  9
# 추천수:  2
# ---------------
# 4
# 제목:  초콜릿의 불편한 진실.jpg
# 글쓴이:  풀썬이동혁
# 날짜:  2021.11.18 12:39
# 조회수:  3631
# 댓글수:  3
# 추천수:  1
# ---------------
# 5
# 제목:  전효성 인스타 업뎃 .jpg
# 글쓴이:  녹차말차킬러
# 날짜:  2021.11.18 12:37
# 조회수:  2652
# 댓글수:  2
# 추천수:  0
# ---------------
# 6
# 제목:  스파이더맨 노웨이홈 2차 예고편 공개
# 글쓴이:  몹시호시
# 날짜:  2021.11.18 12:33
# 조회수:  414
# 댓글수:  0
# 추천수:  0
# ---------------
# 7
# 제목:  1년여 만에 갑자기 연락온 중고거래자.jpg
# 글쓴이:  ㄷH학수학능력
# 날짜:  2021.11.18 12:33
# 조회수:  5185
# 댓글수:  3
# 추천수:  0
# ---------------
# 8
# 제목:  '나 혼자 산다' 새 포스터, 헨리만 쏙 빠졌다? '갑론을박'
# 글쓴이:  지수
# 날짜:  2021.11.18 12:28
# 조회수:  7939
# 댓글수:  47
# 추천수:  4
# ---------------
# 9
# 제목:  두뇌 싸움하는 프로에서 처음 보는 유형의 전략
# 글쓴이:  .서로가 서로
# 날짜:  2021.11.18 12:22
# 조회수:  2317
# 댓글수:  1
# 추천수:  2
# ---------------
# 10
# 제목:  '새벽 행군' 군장병 5명 '음주 운전' 화물차에 치여
# 글쓴이:  일루전 커넥
# 날짜:  2021.11.18 12:20
# 조회수:  6064
# 댓글수:  16
# 추천수:  2
# ---------------
# 11
# 제목:  레트로 느낌 뿜뿜하는 하하하 굿즈
# 글쓴이:  뿌두구
# 날짜:  2021.11.18 12:18
# 조회수:  6148
# 댓글수:  10
# 추천수:  3
# ---------------
# 12
# 제목:  [Teaser] When Traditional Korean music me..
# 글쓴이:  몽몽댕
# 날짜:  2021.11.18 12:14
# 조회수:  14
# 댓글수:  0
# 추천수:  0
# ---------------
# 13
# 제목:  플로(FLO), 마마무 소속사 RBW와 공연 파트너십 계약 체결
# 글쓴이:  이리저리요리
# 날짜:  2021.11.18 12:10
# 조회수:  484
# 댓글수:  0
# 추천수:  0
# ---------------
# 14
# 제목:  이시영, 1억원 기부…"가정폭력으로 아픈 아이들 위해 결정"
# 글쓴이:  디귿
# 날짜:  2021.11.18 12:09
# 조회수:  838
# 댓글수:  3
# 추천수:  0
# ---------------
# 15
# 제목:  [넷플릭스] F1 : 본능의 질주(feat.가짜광기는가라)
# 글쓴이:  He
# 날짜:  2021.11.18 12:07
# 조회수:  381
# 댓글수:  0
# 추천수:  1
# ---------------
# 16
# 제목:  노웨이홈 삼스파 나온다는 증거.gif
# 글쓴이:  남준선배
# 날짜:  2021.11.18 12:07
# 조회수:  2778
# 댓글수:  0
# 추천수:  0
# ---------------
# 17
# 제목:  드라마 남녀주연배우들이 쉬는시간에 하는 짓......
# 글쓴이:  멍ㅇ멍이 소리
# 날짜:  2021.11.18 12:06
# 조회수:  8712
# 댓글수:  12
# 추천수:  8
# ---------------
# 18
# 제목:  꽃보다 남자 OST중에서 내가 좋아했던 곡은?
# 글쓴이:  널 사랑해 영
# 날짜:  2021.11.18 12:06
# 조회수:  734
# 댓글수:  4
# 추천수:  0
# ---------------
# 19
# 제목:  친구가 가지고 오면 신기했던 폰.JPG
# 글쓴이:  패딩조끼
# 날짜:  2021.11.18 12:05
# 조회수:  3286
# 댓글수:  0
# 추천수:  1
# ---------------
# 20
# 제목:  전업으로 전환할지 고민중인 주갤럼.jpg
# 글쓴이:  할리뱅입니더
# 날짜:  2021.11.18 12:03
# 조회수:  2163
# 댓글수:  0
# 추천수:  0
# ---------------
# 21
# 제목:  오디션 심사위원으로 1분 30초 무대 찢은 아이들 전소연
# 글쓴이:  닐라닐라
# 날짜:  2021.11.18 11:58
# 조회수:  1821
# 댓글수:  0
# 추천수:  0
# ---------------
# 22
# 제목:  BTS '아미' VS 임영웅 '영웅시대' MMA2021 톱10 1위 자리 ..
# 글쓴이:  김영란
# 날짜:  2021.11.18 11:51
# 조회수:  4260
# 댓글수:  3
# 추천수:  1
# ---------------
# 23
# 제목:  캐릭터 찰떡이라는 술꾼도시여자들 한선화
# 글쓴이:  스트로베리문
# 날짜:  2021.11.18 11:40
# 조회수:  5204
# 댓글수:  5
# 추천수:  1
# ---------------
# 24
# 제목:  남친이 "개 부자" 라서 넘 좋다는 여자.jpg
# 글쓴이:  미니온즈
# 날짜:  2021.11.18 11:28
# 조회수:  19233
# 댓글수:  61
# 추천수:  7
# ---------------
# 25
# 제목:  좋은 남친의 기준을 인터넷 여론으로 잡으면 안되는 이유
# 글쓴이:  He
# 날짜:  2021.11.18 11:27
# 조회수:  4631
# 댓글수:  2
# 추천수:  1
# ---------------
# 26
# 제목:  마늘 많이 먹으면 항암효과에 좋아요
# 글쓴이:  옹성우박우진
# 날짜:  2021.11.18 11:22
# 조회수:  3169
# 댓글수:  0
# 추천수:  0
# ---------------
# 27
# 제목:  찰떡아이스 신상 .JPG
# 글쓴이:  세정언니링
# 날짜:  2021.11.18 11:22
# 조회수:  10287
# 댓글수:  14
# 추천수:  7
# ---------------
# 28
# 제목:  이투스 강사진 아바타.jpg
# 글쓴이:  계같네
# 날짜:  2021.11.18 11:18
# 조회수:  2200
# 댓글수:  0
# 추천수:  0
# ---------------
# 29
# 제목:  전신라텍스 말 코스프레
# 글쓴이:  호롤로롤롤
# 날짜:  2021.11.18 11:11
# 조회수:  2499
# 댓글수:  0
# 추천수:  0
# ---------------
# 30
# 제목:  공사중인 미국국경 넘는 멕시코남자
# 글쓴이:  NUEST-W
# 날짜:  2021.11.18 11:10
# 조회수:  3083
# 댓글수:  0
# 추천수:  0
# ---------------
# 31
# 제목:  케이블 랩핑
# 글쓴이:  박뚱시
# 날짜:  2021.11.18 11:09
# 조회수:  753
# 댓글수:  0
# 추천수:  0
# ---------------
# 32
# 제목:  김승규의 볼컨트롤과 킥에서 시작된 한국의 공격전개.gif
# 글쓴이:  데이비드썸원
# 날짜:  2021.11.18 11:08
# 조회수:  302
# 댓글수:  0
# 추천수:  0
# ---------------
# 33
# 제목:  GLG 첫 걸그룹 하이키, 내년 1월5일 뜬다 [공식]
# 글쓴이:  슈슈슈슈슈슈
# 날짜:  2021.11.18 11:02
# 조회수:  1127
# 댓글수:  0
# 추천수:  0
# ---------------
# 34
# 제목:  월급이 더 들어와서 문자를 보냈더니 .jpg
# 글쓴이:  하니형
# 날짜:  2021.11.18 10:58
# 조회수:  17247
# 댓글수:  18
# 추천수:  6
# ---------------
# 35
# 제목:  미래 스포당한 친구
# 글쓴이:  세훈이를업어
# 날짜:  2021.11.18 10:56
# 조회수:  2452
# 댓글수:  0
# 추천수:  0
# ---------------
# 36
# 제목:  브랜드별 끝판왕 차종
# 글쓴이:  Tony Stark
# 날짜:  2021.11.18 10:56
# 조회수:  2266
# 댓글수:  1
# 추천수:  0
# ---------------
# 37
# 제목:  한국 로코영화 원탑이다 VS 아니다
# 글쓴이:  유기현 (25)
# 날짜:  2021.11.18 10:55
# 조회수:  1512
# 댓글수:  0
# 추천수:  0
# ---------------
# 38
# 제목:  햄버거 세트 사서 콜라만 마시는 이유
# 글쓴이:  어니부깅
# 날짜:  2021.11.18 10:55
# 조회수:  16902
# 댓글수:  40
# 추천수:  4
# ---------------
# 39
# 제목:  불과 얼마 전만 해도 개욕먹었던 감독
# 글쓴이:  한 편의 너
# 날짜:  2021.11.18 10:52
# 조회수:  2056
# 댓글수:  0
# 추천수:  0
# ---------------
# 40
# 제목:  들어갔다 나오는
# 글쓴이:  다시 태어날
# 날짜:  2021.11.18 10:51
# 조회수:  543
# 댓글수:  0
# 추천수:  0
# ---------------
# 41
# 제목:  마블 코믹스) 울버린과 웨펀 X 프로그램이란? (2) - 웨펀 X 프로그램..
# 글쓴이:  뭐야 너
# 날짜:  2021.11.18 10:49
# 조회수:  276
# 댓글수:  0
# 추천수:  0
# ---------------
# 42
# 제목:  마블 코믹스) 울버린과 웨펀 X 프로그램이란? (1) - 웨펀 플러스 프로..
# 글쓴이:  뭐야 너
# 날짜:  2021.11.18 10:48
# 조회수:  176
# 댓글수:  0
# 추천수:  0
# ---------------
# 43
# 제목:  스파이더맨 노 웨이 홈 2차 예고편
# 글쓴이:  몹시호시
# 날짜:  2021.11.18 10:41
# 조회수:  468
# 댓글수:  0
# 추천수:  0
# ---------------
# 44
# 제목:  잘 대줄것 같은 여자로 보이는게 고민인 여자
# 글쓴이:  박뚱시
# 날짜:  2021.11.18 10:37
# 조회수:  10322
# 댓글수:  42
# 추천수:  3
# ---------------
# 45
# 제목:  개승자 정성호 오징어게임 허성태
# 글쓴이:  바보같은그대
# 날짜:  2021.11.18 10:16
# 조회수:  1649
# 댓글수:  0
# 추천수:  0
# ---------------
# 46
# 제목:  스포) 스파이더맨 심령사진 유출
# 글쓴이:  용시대박
# 날짜:  2021.11.18 10:11
# 조회수:  4180
# 댓글수:  1
# 추천수:  1
# ---------------
# 47
# 제목:  발뮤다 스마트폰 실사.jpg
# 글쓴이:  JOSHUA95
# 날짜:  2021.11.18 10:11
# 조회수:  4339
# 댓글수:  2
# 추천수:  1
# ---------------
# 48
# 제목:  쇼미더럭키 한장 요약
# 글쓴이:  중 천러
# 날짜:  2021.11.18 10:09
# 조회수:  1078
# 댓글수:  0
# 추천수:  0
# ---------------
# 49
# 제목:  넷플릭스, 첫 가격인상…프리미엄 1만4500원→1만7000원
# 글쓴이:  누눈나난
# 날짜:  2021.11.18 10:00
# 조회수:  12823
# 댓글수:  39
# 추천수:  4
# ---------------
# 50
# 제목:  유독 호불호가 심하게 갈린다는 케이크.jpg
# 글쓴이:  녹차말차킬러
# 날짜:  2021.11.18 09:59
# 조회수:  14002
# 댓글수:  21
# 추천수:  1
# ---------------
# 51
# 제목:  펭수 머리에 초를 꽂기 싫었던 엄마.jpgif
# 글쓴이:  Twenty_Four
# 날짜:  2021.11.18 09:59
# 조회수:  21686
# 댓글수:  66
# 추천수:  14
# ---------------
# 52
# 제목:  뉴욕 타임스퀘어 전광판에 걸린 스테이씨.jpg
# 글쓴이:  녹차말차킬러
# 날짜:  2021.11.18 09:57
# 조회수:  2515
# 댓글수:  2
# 추천수:  0
# ---------------
# 53
# 제목:  서윗한 달팽이주인
# 글쓴이:  qksxks ghtjr
# 날짜:  2021.11.18 09:52
# 조회수:  3444
# 댓글수:  1
# 추천수:  0
# ---------------
# 54
# 제목:  은근히 이쁜 모델
# 글쓴이:  언행일치
# 날짜:  2021.11.18 09:47
# 조회수:  3332
# 댓글수:  0
# 추천수:  1
# ---------------
# 55
# 제목:  은근히 이뻤던 박봄 리즈시절 ㄷㄷ
# 글쓴이:  겟
# 날짜:  2021.11.18 09:45
# 조회수:  15729
# 댓글수:  16
# 추천수:  3
# ---------------
# 56
# 제목:  55 / 파묻히다
# 글쓴이:  윤세원
# 날짜:  2021.11.18 09:45
# 조회수:  295
# 댓글수:  0
# 추천수:  0
# ---------------
# 57
# 제목:  좀 너무 길지않냐는 반응의 드라마 교통사고 장면.gif
# 글쓴이:  NUEST-W
# 날짜:  2021.11.18 09:44
# 조회수:  21525
# 댓글수:  33
# 추천수:  4
# ---------------
# 58
# 제목:  귤 먹고 싶으니까 까달라는 딸.gif
# 글쓴이:  우물밖 여고
# 날짜:  2021.11.18 09:44
# 조회수:  10421
# 댓글수:  9
# 추천수:  3
# ---------------
# 59
# 제목:  현재 본인의 컴퓨터 본체 위치는?
# 글쓴이:  ㄷH학수학능력
# 날짜:  2021.11.18 09:41
# 조회수:  3870
# 댓글수:  15
# 추천수:  0
# ---------------
# 60
# 제목:  [앙ㅋ의이게임을아시나요?] - 네부카드네자르
# 글쓴이:  마유
# 날짜:  2021.11.18 09:40
# 조회수:  58
# 댓글수:  0
# 추천수:  0
# ---------------
# 61
# 제목:  [스파이더맨예고편] 투명인간에게 쳐맞는 리자드.gi
# 글쓴이:  색지
# 날짜:  2021.11.18 09:38
# 조회수:  818
# 댓글수:  1
# 추천수:  0
# ---------------
# 62
# 제목:  대학교 4학년 시험을 친 2학년의 최후.jpg
# 글쓴이:  벤츄리
# 날짜:  2021.11.18 09:30
# 조회수:  23202
# 댓글수:  129
# 추천수:  21
# ---------------
# 63
# 제목:  백의천사 서울대 병원 7년차 미모의 간호사..또 다른 반전 직업 ㄷㄷㄷ
# 글쓴이:  다시 태어날
# 날짜:  2021.11.18 09:26
# 조회수:  24608
# 댓글수:  26
# 추천수:  8
# ---------------
# 64
# 제목:  수능 하루 앞두고 계시를 받은 디씨인
# 글쓴이:  더보이즈 영
# 날짜:  2021.11.18 09:00
# 조회수:  7953
# 댓글수:  6
# 추천수:  0
# ---------------
# 65
# 제목:  역대급으로 ㅈ망인 2021년 고티(Game Of The Year) 라인업
# 글쓴이:  next
# 날짜:  2021.11.18 09:00
# 조회수:  2122
# 댓글수:  2
# 추천수:  0
# ---------------
# 66
# 제목:  MCU 스파이더맨 연출의 문제점
# 글쓴이:  보이프렌드 민
# 날짜:  2021.11.18 08:58
# 조회수:  3328
# 댓글수:  1
# 추천수:  0
# ---------------
# 67
# 제목:  동거인 흉기로 찌르고 아파트 아래로 떨어뜨려 살해..30대 체포
# 글쓴이:  슈비룹
# 날짜:  2021.11.18 08:57
# 조회수:  4869
# 댓글수:  5
# 추천수:  3
# ---------------
# 68
# 제목:  지난 4월말 ㅍ.ㅋ에 올라온 여친 강간글 결말.jpg
# 글쓴이:  자두야♡♡
# 날짜:  2021.11.18 08:48
# 조회수:  7930
# 댓글수:  5
# 추천수:  3
# ---------------
# 69
# 제목:  넷플릭스 역대 인기 순위.jpg
# 글쓴이:  알케이
# 날짜:  2021.11.18 08:41
# 조회수:  18293
# 댓글수:  38
# 추천수:  16
# ---------------
# 70
# 제목:  내향적인 사람이 마트 갔을 때.jpeg
# 글쓴이:  311342_return
# 날짜:  2021.11.18 08:36
# 조회수:  24345
# 댓글수:  32
# 추천수:  14
# ---------------
# 71
# 제목:  불고기피자 5행시 대상작.JPG
# 글쓴이:  시어머니블루
# 날짜:  2021.11.18 08:34
# 조회수:  7285
# 댓글수:  7
# 추천수:  6
# ---------------
# 72
# 제목:  토익학원에서 여자번호 따려다 망했다 ㅅㅂ
# 글쓴이:  백챠
# 날짜:  2021.11.18 08:33
# 조회수:  31131
# 댓글수:  55
# 추천수:  9
# ---------------
# 73
# 제목:  술도녀 정은지&한선화 길거리 싸움 씬 직캠
# 글쓴이:  Twenty_Four
# 날짜:  2021.11.18 08:29
# 조회수:  1851
# 댓글수:  1
# 추천수:  0
# ---------------
# 74
# 제목:  [청춘불패] 한선화 : 어머니 저 그냥 여기 시집오면 안돼요??
# 글쓴이:  녹차말차킬러
# 날짜:  2021.11.18 08:15
# 조회수:  21114
# 댓글수:  18
# 추천수:  4
# ---------------
# 75
# 제목:  어제자 스테이씨 공식 인스타 (+ 인스타스토리)
# 글쓴이:  녹차말차킬러
# 날짜:  2021.11.18 08:08
# 조회수:  2065
# 댓글수:  0
# 추천수:  0
# ---------------
# 76
# 제목:  구글, 폴더블폰 개발 철수.. 삼성과의 가격 경쟁력에서 밀린다 판단
# 글쓴이:  노츄캡짱
# 날짜:  2021.11.18 07:42
# 조회수:  5090
# 댓글수:  2
# 추천수:  0
# ---------------
# 77
# 제목:  선덕여왕 - 비담 jpg
# 글쓴이:  S.COUPS.
# 날짜:  2021.11.18 07:27
# 조회수:  1388
# 댓글수:  2
# 추천수:  0
# ---------------
# 78
# 제목:  [놀면뭐하니] 에서 100만원까지 거래된 음반으로 소개된 앨범
# 글쓴이:  토끼네
# 날짜:  2021.11.18 07:24
# 조회수:  6873
# 댓글수:  0
# 추천수:  3
# ---------------
# 79
# 제목:  를 시전하는 옆나라...news
# 글쓴이:  시어머니블루
# 날짜:  2021.11.18 07:16
# 조회수:  1802
# 댓글수:  1
# 추천수:  2
# ---------------
# 80
# 제목:  야사 잘못 올려서 7일 활정 풀린 기념 재업로드(그때 그 감동 다시 한번 ..
# 글쓴이:  마유
# 날짜:  2021.11.18 07:11
# 조회수:  1261
# 댓글수:  1
# 추천수:  0
# ---------------
# 81
# 제목:  美 여성 록싱어, 팬 얼굴에 소변 보는 '엽기 퍼포먼스'
# 글쓴이:  쇼콘!23
# 날짜:  2021.11.18 07:05
# 조회수:  2669
# 댓글수:  1
# 추천수:  0
# ---------------
# 82
# 제목:  진미채의 비밀.jpg
# 글쓴이:  윤정한 아내
# 날짜:  2021.11.18 07:03
# 조회수:  13135
# 댓글수:  4
# 추천수:  1
# ---------------
# 83
# 제목:  2000년대 중반 OST가 더 유명했던 게임.JPG
# 글쓴이:  굿데이_희진
# 날짜:  2021.11.18 07:03
# 조회수:  1114
# 댓글수:  1
# 추천수:  0
# ---------------
# 84
# 제목:  야 여친 완전운다 어케해야하냐; jpg
# 글쓴이:  마카롱꿀떡
# 날짜:  2021.11.18 07:02
# 조회수:  45159
# 댓글수:  91
# 추천수:  10
# ---------------
# 85
# 제목:  뭔가 이상함을 느끼는 경비원 .gif
# 글쓴이:  장미장미
# 날짜:  2021.11.18 06:59
# 조회수:  14641
# 댓글수:  8
# 추천수:  0
# ---------------
# 86
# 제목:  32세 직장인 식습관
# 글쓴이:  초코틴틴세븐
# 날짜:  2021.11.18 06:55
# 조회수:  22423
# 댓글수:  14
# 추천수:  5
# ---------------
# 87
# 제목:  남친한테 너랑 바람필일 없다고 전해라.JPG
# 글쓴이:  캐리와 장난감
# 날짜:  2021.11.18 06:11
# 조회수:  10699
# 댓글수:  1
# 추천수:  8
# ---------------
# 88
# 제목:  중식만 먹으면 생기는 소화불량의 진실.JPG
# 글쓴이:  패딩조끼
# 날짜:  2021.11.18 06:00
# 조회수:  28417
# 댓글수:  26
# 추천수:  3
# ---------------
# 89
# 제목:  EBS 위대한 수업) 왜 세상은 나빠지는가?"당신의 세계관을 뒤흔들 팩트 ..
# 글쓴이:  중 천러
# 날짜:  2021.11.18 05:48
# 조회수:  1643
# 댓글수:  1
# 추천수:  1
# ---------------
# 90
# 제목:  허리통증에 시달리는 직장인들을 위한 꿀팁!!
# 글쓴이:  더보이즈 상
# 날짜:  2021.11.18 05:45
# 조회수:  5945
# 댓글수:  0
# 추천수:  2
# ---------------
# 91
# 제목:  출시 이틀 남은 게임
# 글쓴이:  뭐야 너
# 날짜:  2021.11.18 05:34
# 조회수:  2454
# 댓글수:  1
# 추천수:  0
# ---------------
# 92
# 제목:  자기가 잘대줄거 같은 여자란 소리를 들은 사람의 고민.JPG
# 글쓴이:  녤피치
# 날짜:  2021.11.18 05:32
# 조회수:  47828
# 댓글수:  136
# 추천수:  11
# ---------------
# 93
# 제목:  냥아치 호냥이.jpg
# 글쓴이:  풀썬이동혁
# 날짜:  2021.11.18 05:32
# 조회수:  2540
# 댓글수:  2
# 추천수:  0
# ---------------
# 94
# 제목:  네이버 웹툰 근황 ㄷㄷ
# 글쓴이:  어니부깅
# 날짜:  2021.11.18 05:27
# 조회수:  15124
# 댓글수:  17
# 추천수:  8
# ---------------
# 95
# 제목:  토양 액상화
# 글쓴이:  환조승연애
# 날짜:  2021.11.18 05:24
# 조회수:  1669
# 댓글수:  2
# 추천수:  0
# ---------------
# 96
# 제목:  회사 직원 중에 머리 탈색하고 투톤한 사람 있는데
# 글쓴이:  308679_return
# 날짜:  2021.11.18 05:23
# 조회수:  32269
# 댓글수:  35
# 추천수:  8
# ---------------
# 97
# 제목:  NO버터 NO달걀 NO우유 베이글
# 글쓴이:  겟
# 날짜:  2021.11.18 04:25
# 조회수:  8144
# 댓글수:  1
# 추천수:  2
# ---------------
# 98
# 제목:  2연속 당첨.gif
# 글쓴이:  남준선배
# 날짜:  2021.11.18 04:22
# 조회수:  4731
# 댓글수:  1
# 추천수:  0
# ---------------
# 99
# 제목:  암튼 여친룩
# 글쓴이:  뇌잘린
# 날짜:  2021.11.18 04:14
# 조회수:  3840
# 댓글수:  1
# 추천수:  1
# ---------------
# 100
# 제목:  차로 하이마트를 박살낸 여대생.jpg
# 글쓴이:  +ordin
# 날짜:  2021.11.18 04:09
# 조회수:  5531
# 댓글수:  2
# 추천수:  0
# ---------------
# 101
# 제목:  롤) 한복 아리 바뀐 일러스트
# 글쓴이:  JOSHUA95
# 날짜:  2021.11.18 04:01
# 조회수:  18446
# 댓글수:  13
# 추천수:  6
# ---------------
# 102
# 제목:  상속 때문에 빚더미에 앉게된 아이들
# 글쓴이:  캐리와 장난감
# 날짜:  2021.11.18 04:00
# 조회수:  5249
# 댓글수:  1
# 추천수:  2
# ---------------
# 103
# 제목:  새끼때문에 놀란 메랑이
# 글쓴이:  꾸쭈꾸쭈
# 날짜:  2021.11.18 03:52
# 조회수:  325
# 댓글수:  1
# 추천수:  0
# ---------------
# 104
# 제목:  수능 도시락
# 글쓴이:  방탄소년단★
# 날짜:  2021.11.18 03:10
# 조회수:  3586
# 댓글수:  2
# 추천수:  1
# ---------------
# 105
# 제목:  "의외로 쉬워서 놀랐다"명성황후 시해 가담자 편지
# 글쓴이:  꾸쭈꾸쭈
# 날짜:  2021.11.18 02:54
# 조회수:  1916
# 댓글수:  1
# 추천수:  5
# ---------------
# 106
# 제목:  스태프 전원 실신.gif
# 글쓴이:  307559_return
# 날짜:  2021.11.18 02:54
# 조회수:  9221
# 댓글수:  6
# 추천수:  2
# ---------------
# 107
# 제목:  잠시 녹화중단 했던 kbs 방송.jpg
# 글쓴이:  She
# 날짜:  2021.11.18 02:43
# 조회수:  5369
# 댓글수:  1
# 추천수:  4
# ---------------
# 108
# 제목:  개그맨 황현희 근황...jpg
# 글쓴이:  유기현 (25)
# 날짜:  2021.11.18 02:32
# 조회수:  6390
# 댓글수:  3
# 추천수:  1
# ---------------
# 109
# 제목:  [스파이더맨] 앤드류 가필드,"전 이번 작품에 출연하지 않아요"
# 글쓴이:  임팩트FBI
# 날짜:  2021.11.18 02:30
# 조회수:  3511
# 댓글수:  2
# 추천수:  1
# ---------------
# 110
# 제목:  실시간 축협 세로드립 ㄷㄷㄷ
# 글쓴이:  qksxks ghtjr
# 날짜:  2021.11.18 02:29
# 조회수:  3833
# 댓글수:  3
# 추천수:  2
# ---------------
# 111
# 제목:  수능날00시에 버스파업 협상예정
# 글쓴이:  뇌잘린
# 날짜:  2021.11.18 02:26
# 조회수:  616
# 댓글수:  1
# 추천수:  0
# ---------------
# 112
# 제목:  현시각 축협 인스타 관리자의 미친센스.jpg
# 글쓴이:  ♡김태형♡
# 날짜:  2021.11.18 02:23
# 조회수:  3959
# 댓글수:  1
# 추천수:  0
# ---------------
# 113
# 제목:  이라크 VS 대한민국 3:0 승리 주요장면
# 글쓴이:  김낑깡
# 날짜:  2021.11.18 02:21
# 조회수:  257
# 댓글수:  1
# 추천수:  0
# ---------------
# 114
# 제목:  수지 12년간의 얼굴
# 글쓴이:  Busu031
# 날짜:  2021.11.18 02:10
# 조회수:  3602
# 댓글수:  3
# 추천수:  0
# ---------------
# 115
# 제목:  느슨한 웹툰계에 긴장감을 줄 신작
# 글쓴이:  어니부깅
# 날짜:  2021.11.18 02:03
# 조회수:  5033
# 댓글수:  2
# 추천수:  2
# ---------------
# 116
# 제목:  빈곤층, 중산층, 부유층을 나누는 기준.jpg
# 글쓴이:  이진기(30)
# 날짜:  2021.11.18 02:00
# 조회수:  3815
# 댓글수:  5
# 추천수:  2
# ---------------
# 117
# 제목:  홍콩 경찰 지지한 아이돌들.jpg
# 글쓴이:  무샤뮤샤
# 날짜:  2021.11.18 01:52
# 조회수:  1673
# 댓글수:  0
# 추천수:  1
# ---------------
# 118
# 제목:  2021년 최악의 시말서 각
# 글쓴이:  겟
# 날짜:  2021.11.18 01:39
# 조회수:  7780
# 댓글수:  9
# 추천수:  3
# ---------------
# 119
# 제목:  김민주가 원래 이렇게 이뻤나
# 글쓴이:  오징어게임 일
# 날짜:  2021.11.18 01:38
# 조회수:  2120
# 댓글수:  2
# 추천수:  0
# ---------------
# 120
# 제목:  신더가드 에인절스행
# 글쓴이:  유기현 (25)
# 날짜:  2021.11.18 01:38
# 조회수:  14
# 댓글수:  0
# 추천수:  0
# ---------------
# 121
# 제목:  방송 도중 팬에게 전화왔을때 정상수 대처.JPG
# 글쓴이:  세기말
# 날짜:  2021.11.18 01:35
# 조회수:  1756
# 댓글수:  1
# 추천수:  1
# ---------------
# 122
# 제목:  어깨라인이 상당하신 트위치 스트리머
# 글쓴이:  박뚱시
# 날짜:  2021.11.18 01:16
# 조회수:  2350
# 댓글수:  1
# 추천수:  0
# ---------------
# 123
# 제목:  어그로다 vs 찐이다
# 글쓴이:  풀썬이동혁
# 날짜:  2021.11.18 01:12
# 조회수:  1519
# 댓글수:  2
# 추천수:  0
# ---------------
# 124
# 제목:  졸업안시켜준 교수 죽인 대학원생
# 글쓴이:  남준이는왜이
# 날짜:  2021.11.18 01:09
# 조회수:  1894
# 댓글수:  1
# 추천수:  1
# ---------------
# 125
# 제목:  배달음식에 이물질이 나왔을때 대처법.JPG
# 글쓴이:  ♡김태형♡
# 날짜:  2021.11.18 01:04
# 조회수:  2471
# 댓글수:  0
# 추천수:  0
# ---------------
# 126
# 제목:  열라면 누가 맛있다 그랬니? .JPG
# 글쓴이:  Wannable(워너
# 날짜:  2021.11.18 01:04
# 조회수:  11790
# 댓글수:  17
# 추천수:  1
# ---------------
# 127
# 제목:  19세 이상만
# 글쓴이:  방탄소년단★
# 날짜:  2021.11.18 00:56
# 조회수:  918
# 댓글수:  0
# 추천수:  0
# ---------------
# 128
# 제목:  노웨이홈 삼파이더맨 출연이 99퍼인 이유.jpg
# 글쓴이:  뇌잘린
# 날짜:  2021.11.18 00:50
# 조회수:  4480
# 댓글수:  11
# 추천수:  1
# ---------------
# 129
# 제목:  이름은 모르는데 익숙한 새 .jpg
# 글쓴이:  Jeddd
# 날짜:  2021.11.18 00:48
# 조회수:  3061
# 댓글수:  2
# 추천수:  0
# ---------------
# 130
# 제목:  여성의 생물학적 노산 기준 나이.jpg
# 글쓴이:  오징어게임 일
# 날짜:  2021.11.18 00:44
# 조회수:  15060
# 댓글수:  47
# 추천수:  7
# ---------------
# 131
# 제목:  LG에서 출시한 역대급 매출이였다는 폰.JPG
# 글쓴이:  싯떼루네`ワ
# 날짜:  2021.11.18 00:39
# 조회수:  12253
# 댓글수:  22
# 추천수:  8
# ---------------
# 132
# 제목:  카더가든이 재해석해서 부른 크라잉넛의 명동콜링
# 글쓴이:  Vitro
# 날짜:  2021.11.18 00:25
# 조회수:  194
# 댓글수:  1
# 추천수:  1
# ---------------
# 133
# 제목:  미국 3대 시상식 AMAs 시상식에서 BTS가 할 무대
# 글쓴이:  행복한왕만두
# 날짜:  2021.11.18 00:21
# 조회수:  3942
# 댓글수:  12
# 추천수:  2
# ---------------
# 134
# 제목:  빠니보틀 : 곽튜브 성공의 1할은 내 덕이다
# 글쓴이:  헤에에이~
# 날짜:  2021.11.18 00:13
# 조회수:  6839
# 댓글수:  5
# 추천수:  4
# ---------------
# 135
# 제목:  발렌시아가 행사에 참석한 한소희, 모니카, 더보이즈 주연
# 글쓴이:  지수
# 날짜:  2021.11.18 00:08
# 조회수:  12667
# 댓글수:  38
# 추천수:  14
# ---------------
# 136
# 제목:  쓰니 기준 우리나라에서 화보 가장 잘찍는 남자배우
# 글쓴이:  Busu031
# 날짜:  2021.11.17
# 조회수:  3409
# 댓글수:  3
# 추천수:  0
# ---------------
# 137
# 제목:  귀여운 새끼멍뭉이
# 글쓴이:  임팩트FBI
# 날짜:  2021.11.17
# 조회수:  1343
# 댓글수:  1
# 추천수:  1
# ---------------
# 138
# 제목:  34살 먹고 첫 직장 생김...내 썰 좀 들어주라
# 글쓴이:  아야나미
# 날짜:  2021.11.17
# 조회수:  14798
# 댓글수:  42
# 추천수:  25
# ---------------
# 139
# 제목:  무스펙 서울대생의 취업후기 및 준비과정
# 글쓴이:  임팩트FBI
# 날짜:  2021.11.17
# 조회수:  17093
# 댓글수:  19
# 추천수:  7
# ---------------
# 140
# 제목:  야외야스로 몸살앓는 천혜의 경관....news
# 글쓴이:  다시 태어날
# 날짜:  2021.11.17
# 조회수:  3318
# 댓글수:  1
# 추천수:  0
# ---------------
# 141
# 제목:  개발자인줄 알았던 내가 눈떠보니 디자이너.jpg
# 글쓴이:  에자키히카루
# 날짜:  2021.11.17
# 조회수:  67017
# 댓글수:  199
# 추천수:  23
# ---------------
# 142
# 제목:  남편이 저 모르게 또 어린이집을 안보냈네요.jpgif
# 글쓴이:  토끼네
# 날짜:  2021.11.17
# 조회수:  7533
# 댓글수:  6
# 추천수:  3
# ---------------
# 143
# 제목:  스파이더맨 예고 내려갔었던 이유.gif
# 글쓴이:  싯떼루네`ワ
# 날짜:  2021.11.17
# 조회수:  5837
# 댓글수:  5
# 추천수:  1
# ---------------
# 144
# 제목:  요즘 해외 영화 수입 열심히 하는 소지섭
# 글쓴이:  '''
# 날짜:  2021.11.17
# 조회수:  2262
# 댓글수:  0
# 추천수:  1
# ---------------
# 145
# 제목:  바람핀 친엄마 vs 새엄마
# 글쓴이:  그녀의이름은
# 날짜:  2021.11.17
# 조회수:  3726
# 댓글수:  0
# 추천수:  3
# ---------------
# 146
# 제목:  벌새를 닮은 귀여운 벌레
# 글쓴이:  송희진
# 날짜:  2021.11.17
# 조회수:  877
# 댓글수:  1
# 추천수:  0
# ---------------
# 147
# 제목:  지능이 높을수록 성욕이 강하다.jpg
# 글쓴이:  311869_return
# 날짜:  2021.11.17
# 조회수:  13845
# 댓글수:  17
# 추천수:  1
# ---------------
# 148
# 제목:  초봉 6500만원·휴가 기간 무제한…그래도 '노는 직원' 없는 비결
# 글쓴이:  위례신다도시
# 날짜:  2021.11.17
# 조회수:  19386
# 댓글수:  26
# 추천수:  12
# ---------------
# 149
# 제목:  김재우 근황.jpg
# 글쓴이:  알케이
# 날짜:  2021.11.17
# 조회수:  2808
# 댓글수:  2
# 추천수:  1
# ---------------
# 150
# 제목:  프랑스 대박별 한국학&한국어 전공 경쟁률 현황 ㄷㄷㄷ jpg
# 글쓴이:  뇌잘린
# 날짜:  2021.11.17
# 조회수:  13297
# 댓글수:  28
# 추천수:  5
# ---------------
# 151
# 제목:  유튜브에서 킬링타임용으로 역주행중인 애니.JPG
# 글쓴이:  널 사랑해 영
# 날짜:  2021.11.17
# 조회수:  2914
# 댓글수:  1
# 추천수:  1
# ---------------
# 152
# 제목:  약쟁이 검거 완료
# 글쓴이:  ㄷH학수학능력
# 날짜:  2021.11.17
# 조회수:  2065
# 댓글수:  1
# 추천수:  0
# ---------------
# 153
# 제목:  사람들이 은근 모르는 레드벨벳 명곡
# 글쓴이:  세븐틴 원 +
# 날짜:  2021.11.17
# 조회수:  61361
# 댓글수:  140
# 추천수:  6
# ---------------
# 154
# 제목:  헌신짝돼서 차였는데 결혼한뒤 연락 온 전남친
# 글쓴이:  용시대박
# 날짜:  2021.11.17
# 조회수:  18824
# 댓글수:  18
# 추천수:  4
# ---------------
# 155
# 제목:  여친이랑 모텔 옴
# 글쓴이:  까까까
# 날짜:  2021.11.17
# 조회수:  14493
# 댓글수:  18
# 추천수:  1
# ---------------
# 156
# 제목:  스파이더맨 노웨이홈 쿠키 유출 논란...jpg
# 글쓴이:  게임을시작하
# 날짜:  2021.11.17
# 조회수:  3031
# 댓글수:  1
# 추천수:  0
# ---------------
# 157
# 제목:  현재 매탈남 유튜브 상황.JPG
# 글쓴이:  알케이
# 날짜:  2021.11.17
# 조회수:  5594
# 댓글수:  5
# 추천수:  2
# ---------------
# 158
# 제목:  [서울] 상습 체납자 만296명 공개...서울시 체납 1위는 중국인
# 글쓴이:  누눈나난
# 날짜:  2021.11.17
# 조회수:  8433
# 댓글수:  13
# 추천수:  3
# ---------------
# 159
# 제목:  일본 편의점 2년차 알바생 후기
# 글쓴이:  김상연
# 날짜:  2021.11.17
# 조회수:  17886
# 댓글수:  10
# 추천수:  3
# ---------------
# 160
# 제목:  일본에서 av배우 인식
# 글쓴이:  김상연
# 날짜:  2021.11.17
# 조회수:  14793
# 댓글수:  19
# 추천수:  5
# ---------------
# 161
# 제목:  탕수육 부먹
# 글쓴이:  한 편의 너
# 날짜:  2021.11.17
# 조회수:  772
# 댓글수:  1
# 추천수:  0
# ---------------
# 162
# 제목:  먹고싶은걸 먹으면 수명이 줄어드는 병...jpg
# 글쓴이:  디귿
# 날짜:  2021.11.17
# 조회수:  4076
# 댓글수:  1
# 추천수:  1
# ---------------
# 163
# 제목:  공대생이 체크남방만 입는다는 편견을 버려달라는 사람. jpg
# 글쓴이:  키토제닉
# 날짜:  2021.11.17
# 조회수:  7472
# 댓글수:  3
# 추천수:  0
# ---------------
# 164
# 제목:  집에서 나갈땐 다리가 6개인데, 돌아올땐 2개인 것은?
# 글쓴이:  qksxks ghtjr
# 날짜:  2021.11.17
# 조회수:  2039
# 댓글수:  1
# 추천수:  0
# ---------------
# 165
# 제목:  (혐오주의) 윤서인 "안중근은 대한민국 군인과 아무런 상관이 없다"
# 글쓴이:  미니온즈
# 날짜:  2021.11.17
# 조회수:  2145
# 댓글수:  3
# 추천수:  0
# ---------------
# 166
# 제목:  미친 다 어렵네
# 글쓴이:  다니엘_린데
# 날짜:  2021.11.17
# 조회수:  1170
# 댓글수:  0
# 추천수:  0
# ---------------
# 167
# 제목:  서장훈이 말하는 찐 남사친과 위장 남사친.jpg
# 글쓴이:  next
# 날짜:  2021.11.17
# 조회수:  41464
# 댓글수:  33
# 추천수:  16
# ---------------
# 168
# 제목:  과장이 지각한 신입을 불러 지적했는데
# 글쓴이:  션국이네 메르
# 날짜:  2021.11.17
# 조회수:  2020
# 댓글수:  1
# 추천수:  0
# ---------------
# 169
# 제목:  넥슨 최악의 업데이트 원탑은?.jpg
# 글쓴이:  천러러러
# 날짜:  2021.11.17
# 조회수:  2684
# 댓글수:  2
# 추천수:  0
# ---------------
# 170
# 제목:  대기업 14년 후기.jpg
# 글쓴이:  윤정한 아내
# 날짜:  2021.11.17
# 조회수:  30277
# 댓글수:  42
# 추천수:  23
# ---------------
# 171
# 제목:  아기들을 버리고 가는 엄마.jpg
# 글쓴이:  ㄷH학수학능력
# 날짜:  2021.11.17
# 조회수:  8368
# 댓글수:  6
# 추천수:  0
# ---------------
# 172
# 제목:  틴더 어플 쓴다고 온갖 악플 받은 여자유튜버.jpg
# 글쓴이:  캐리와 장난감
# 날짜:  2021.11.17
# 조회수:  25490
# 댓글수:  31
# 추천수:  11
# ---------------
# 173
# 제목:  넷플릭스 지옥 imdb 평가.....jpg
# 글쓴이:  S.COUPS.
# 날짜:  2021.11.17
# 조회수:  7704
# 댓글수:  2
# 추천수:  1
# ---------------
# 174
# 제목:  요즘 청소년 희망직업 1위 공무원 아님
# 글쓴이:  해르반창식
# 날짜:  2021.11.17
# 조회수:  28733
# 댓글수:  31
# 추천수:  14
# ---------------
# 175
# 제목:  강아지 산책중 동네 다른 강아지 목줄이 풀려있어서 깜짝 놀랐는데
# 글쓴이:  방탄전용날개
# 날짜:  2021.11.17
# 조회수:  10970
# 댓글수:  11
# 추천수:  3
# ---------------
# 176
# 제목:  식물갤의 전투력 ㄷㄷㄷ
# 글쓴이:  세정언니링
# 날짜:  2021.11.17
# 조회수:  2832
# 댓글수:  0
# 추천수:  2
# ---------------
# 177
# 제목:  섹시한 톰포드 신제품.jpg
# 글쓴이:  영은수
# 날짜:  2021.11.17
# 조회수:  4005
# 댓글수:  1
# 추천수:  1
# ---------------
# 178
# 제목:  1억에 대한 인식
# 글쓴이:  널 사랑해 영
# 날짜:  2021.11.17
# 조회수:  6021
# 댓글수:  4
# 추천수:  0
# ---------------
# 179
# 제목:  세상에서 가장 신기한 도형
# 글쓴이:  311869_return
# 날짜:  2021.11.17
# 조회수:  4564
# 댓글수:  6
# 추천수:  0
# ---------------
# 180
# 제목:  '김종국 약물' 주장한 유튜버, 전과 기록
# 글쓴이:  할리뱅입니더
# 날짜:  2021.11.17
# 조회수:  30096
# 댓글수:  32
# 추천수:  9
# ---------------
# 181
# 제목:  한때 유행하더니 요즘 아무도 안입는 옷
# 글쓴이:  '''
# 날짜:  2021.11.17
# 조회수:  119506
# 댓글수:  157
# 추천수:  20
# ---------------
# 182
# 제목:  무도 장면중 너무 웃겼던 장면
# 글쓴이:  방탄전용날개
# 날짜:  2021.11.17
# 조회수:  3007
# 댓글수:  3
# 추천수:  0
# ---------------
# 183
# 제목:  여자친구가 순수아리아인 혈통.JPG
# 글쓴이:  She
# 날짜:  2021.11.17
# 조회수:  38495
# 댓글수:  23
# 추천수:  12
# ---------------
# 184
# 제목:  자위대 식사.jpg
# 글쓴이:  더보이즈 상
# 날짜:  2021.11.17
# 조회수:  4374
# 댓글수:  1
# 추천수:  0
# ---------------
# 185
# 제목:  中, 가상사설망(VPN) 단속 강화…역대 최고 강력 규제
# 글쓴이:  몹시호시
# 날짜:  2021.11.17
# 조회수:  1557
# 댓글수:  2
# 추천수:  1
# ---------------
# 186
# 제목:  서로 좋아하면 섹스하는 세상
# 글쓴이:  JOSHUA95
# 날짜:  2021.11.17
# 조회수:  7373
# 댓글수:  8
# 추천수:  0
# ---------------
# 187
# 제목:  다꾸는 코르셋+유아퇴행 하는 행위이다
# 글쓴이:  꿍치따치
# 날짜:  2021.11.17
# 조회수:  3485
# 댓글수:  3
# 추천수:  0
# ---------------
# 188
# 제목:  식물갤의 품격
# 글쓴이:  보이프렌드 민
# 날짜:  2021.11.17
# 조회수:  2535
# 댓글수:  3
# 추천수:  2
# ---------------
# 189
# 제목:  하성운 6번째 미니앨범 'Electrified : Urban Nostalg..
# 글쓴이:  던던둔둔
# 날짜:  2021.11.17
# 조회수:  52
# 댓글수:  0
# 추천수:  0
# ---------------
# 190
# 제목:  현재 논란중인 편의점 옷 안에 손 넣고 강제 추행 사건
# 글쓴이:  깐부
# 날짜:  2021.11.17
# 조회수:  4560
# 댓글수:  2
# 추천수:  1

# %%
df=pd.DataFrame(result)
df
# Out:
#                                               제목       글쓴이                날짜  \
# 0                           배고파요.. 연어초밥좀 주세요.jpg   세븐틴 원 +  2021.11.18 13:08
# 1             윤민섭 기자) 커즈, 에이밍 KT행 루머.. KT측은 노코멘트       윤세원  2021.11.18 13:02
# 2    원어스, 데뷔 1044일 만에 첫 1위 "꿈 같아..긍정적인 역사 써 내려..     강쥐강아쥐  2021.11.18 12:51
# 3                                초콜릿의 불편한 진실.jpg     풀썬이동혁  2021.11.18 12:39
# 4                                전효성 인스타 업뎃 .jpg    녹차말차킬러  2021.11.18 12:37
# ..                                           ...       ...               ...
# 185                              서로 좋아하면 섹스하는 세상  JOSHUA95        2021.11.17
# 186                         다꾸는 코르셋+유아퇴행 하는 행위이다      꿍치따치        2021.11.17
# 187                                      식물갤의 품격   보이프렌드 민        2021.11.17
# 188  하성운 6번째 미니앨범 'Electrified : Urban Nostalg..      던던둔둔        2021.11.17
# 189               현재 논란중인 편의점 옷 안에 손 넣고 강제 추행 사건        깐부        2021.11.17
#
#       조회수 댓글수 추천수
# 0     409   1   0
# 1     104   0   0
# 2    2153   9   2
# 3    3631   3   1
# 4    2652   2   0
# ..    ...  ..  ..
# 185  7373   8   0
# 186  3485   3   0
# 187  2535   3   2
# 188    52   0   0
# 189  4560   2   1
#
# [190 rows x 6 columns]

# %%
df.to_excel('data/instiz_인티포털.xlsx')

# %%
# 전체 인기글

# %%
contents2=soup.select('#rank1to10 > div')
contents2.extend(soup.select('#rank11to20 > div'))

# %%
#전체 인기글
cnt=1
result2=[]
for i in contents2:
    tmp={}
    print('-'*15)
    print(cnt)
    
    #게시판 추출
    category=i.find('div', {"class":"minitext"}).text
    print("게시판: ", category)
    
    
    # 제목 추출
    title=i.find('a', {"id":("focus"+str(i))})
    
    print("제목: ", title)
    
   
    
#    # 글쓴이 추출
#    writer_tag = i.find('td', {"class":"minitext2 listnm"})
#    if writer_tag is not None: # None 값이 있으므로 조건문을 통해 회피 
#        writer = writer_tag.text
#      
#    else:
#        writer = "없음"
#    print("글쓴이: ", writer)
    
#     # 유동이나 고닉이 아닌 글쓴이 옆에 있는 ip 추출
#     ip_tag = i.find('td', class_='gall_writer ub-writer').find('span', class_='ip')
#     if ip_tag is not None:  # None 값이 있으므로 조건문을 통해 회피 
#         ip = ip_tag.text
#         print("ip: ", ip)



#    # 날짜 추출 
#    date=i.find('td',{"class":"listno regdate"}).text
#    print("날짜: ",date)
    
    
#    # 조회 수 추출
#    views = i.find_all('td', {"class":"listno"})[2].text
#    print("조회수: ", views)


    # 댓글 수
    comment=i.find('a',{"class":"cmt"})
    if comment==None:
        comment=0
    else:
        comment=comment.text
    print("댓글수: ", comment)
    
#    # 추천 수 추출
#    recommend = i.find_all('td', {"class":"listno"})[3].text
#    print("추천수: ", recommend)

    tmp['게시판']=category
    tmp['제목']=title
#    tmp['글쓴이']=writer
#    tmp['날짜']=date
#    tmp['조회수']=views
    tmp['댓글수']=comment
#    tmp['추천수']=recommend
    
    result2.append(tmp)
    
    cnt=cnt+1
# Out:
# ---------------
# 1
# 게시판:  익명잡담
# 제목:  None
# 댓글수:  32
# ---------------
# 2
# 게시판:  인티포털
# 제목:  None
# 댓글수:  10

# %%
df2=pd.DataFrame(result2)
df2
# Out:
#      게시판                                   제목 댓글수
# 0   인티포털                    임시완이 공개한 연애횟수.jpg  10
# 1   익명잡담  우리집 고삼이 바람 쐬고 온다고 하고 이 시간에 울면서 나갔..   6
# 2   익명잡담                    와씨 라면스프 먹는데 대.존.맛  12
# 3   인티포털            용산 아이맥스때문에 남친이랑 싸운 여자.jpg  49
# 4   익명잡담                     이틀에 한번 샤워하면 더러워?  39
# 5   인티포털                최근들어 정말 예쁘다는 생각이 드는 분  33
# 6   익명잡담                       하루에 6~7시간 씩 하는   5
# 7   인티포털                       미쳐버린 어느 웹소설 설정   6
# 8   인티포털          트위치 어느 여스트리머의 방송정지 사유.jpgif   4
# 9   익명잡담                  브라렛이랑 그냥 브라랑 뭐가달라??  11
# 10  익명잡담                   [연애중] 계란말이된 썰 푼다,,   2
# 11  인티포털                   요즘 sns에 미남들이 많은 이유  18
# 12  인티포털          삼성 핸드폰 테스트 엔지니어도 어쩔 수 없는 취향   1
# 13  익명잡담  나 쌍수 망한 걸까… 심각하게 재수술 고민 중인데 한번씩 봐..  23
# 14  인티포털                  KFC 선넘는 신메뉴 폰치밥.jpg  12
# 15  인티포털     환경호르몬 많이 나오는데 흐린눈 하는 사람 많은 것.jpg  42
# 16  익명잡담        어른들 말 중에 틀린말 하나 없다..를 느끼게해준 말   7
# 17  익명잡담                   나 네일아트 자랑해도 될까?(두근  14
# 18  인티포털                        다음날 숙취가 없다는 술  13
# 19  익명잡담               아빠가 대기업 임원인게 엄청 대단한거임?   8

# %%
df2.to_excel('data/instiz_전체인기글.xlsx')

# %%
# 인티포털 인기글

# %%
contents3=soup.select('#rank1to10_menu > div')
contents3.extend(soup.select('#rank11to20_menu > div'))

# %%
#전체 인기글
cnt=1
result3=[]
for i in contents3:
    tmp={}
    print('-'*15)
    print(cnt)
    
    
    # 제목 추출
    if cnt<11:
        title=i.select_one('#rank1to10_menu > div > div.rank_subject > a').text.strip()
    else:
        title=i.select_one('#rank11to20_menu > div > div.rank_subject > a').text.strip()
    print("제목: ", title)
    
   
    
#    # 글쓴이 추출
#    writer_tag = i.find('td', {"class":"minitext2 listnm"})
#    if writer_tag is not None: # None 값이 있으므로 조건문을 통해 회피 
#        writer = writer_tag.text
#      
#    else:
#        writer = "없음"
#    print("글쓴이: ", writer)
    
#     # 유동이나 고닉이 아닌 글쓴이 옆에 있는 ip 추출
#     ip_tag = i.find('td', class_='gall_writer ub-writer').find('span', class_='ip')
#     if ip_tag is not None:  # None 값이 있으므로 조건문을 통해 회피 
#         ip = ip_tag.text
#         print("ip: ", ip)



#    # 날짜 추출 
#    date=i.find('td',{"class":"listno regdate"}).text
#    print("날짜: ",date)
    
    
#    # 조회 수 추출
#    views = i.find_all('td', {"class":"listno"})[2].text
#    print("조회수: ", views)


    # 댓글 수
    comment=i.find('a',{"class":"cmt"})
    if comment==None:
        comment=0
    else:
        comment=comment.text
    print("댓글수: ", comment)
    
#    # 추천 수 추출
#    recommend = i.find_all('td', {"class":"listno"})[3].text
#    print("추천수: ", recommend)

    tmp['제목']=title
#    tmp['글쓴이']=writer
#    tmp['날짜']=date
#    tmp['조회수']=views
    tmp['댓글수']=comment
#    tmp['추천수']=recommend
    
    result3.append(tmp)
    
    cnt=cnt+1
# Out:
# ---------------
# 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-60e38bbd68d2> in <module>
#      10     # 제목 추출
#      11     if cnt<11:
# ---> 12         title=i.select_one('#rank1to10_menu > div > div.rank_subject > a').text.strip()
#      13     else:
#      14         title=i.select_one('#rank11to20_menu > div > div.rank_subject > a').text.strip()
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
df3=pd.DataFrame(result3)
df3
# Out:
#                                   제목 댓글수
# 0                  임시완이 공개한 연애횟수.jpg  10
# 1          용산 아이맥스때문에 남친이랑 싸운 여자.jpg  49
# 2              최근들어 정말 예쁘다는 생각이 드는 분  33
# 3                     미쳐버린 어느 웹소설 설정   6
# 4                 요즘 sns에 미남들이 많은 이유  18
# 5                      다음날 숙취가 없다는 술  13
# 6        트위치 어느 여스트리머의 방송정지 사유.jpgif   4
# 7   환경호르몬 많이 나오는데 흐린눈 하는 사람 많은 것.jpg  42
# 8        삼성 핸드폰 테스트 엔지니어도 어쩔 수 없는 취향   1
# 9                KFC 선넘는 신메뉴 폰치밥.jpg  12
# 10         4만원에 여친한테 정떨어지면 내가 이상한건가?   0
# 11           일반인이 아이돌 메이크업을 받았을때.jpg  42
# 12           연구원에게 발각되어 만짐당하는 팔라스고양이  14
# 13                       털관리 잘한 리트리버   2
# 14           파리에서 오징어게임 배우로 오해받는 유튜버  36
# 15                마블 최초로 토마토 썩은 이터널스  38
# 16                 할로윈때 뚱뚱해지는 서양다람쥐들  67
# 17                      사고치는 고양이.jpg   3
# 18                         서울 뷔페 3대장   0
# 19        영국 데일리메일 홈피에서 발견된 한류...jpg   0

# %%
df3.to_excel('data/instiz_인티포털인기글.xlsx')
