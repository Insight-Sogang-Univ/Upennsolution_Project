# %%
from bs4 import BeautifulSoup as bs
import requests as req
import pandas as pd

# %%
base_url='https://www.instiz.net/pt'
#headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.54 Safari/537.36"}

# %%
#페이지네이션

# %%
raw=req.get(base_url)
#soup=bs(raw.text, 'lxml')

# %%
soup=bs(raw.content, 'html.parser')

# %%
contents = soup.find_all('tr')   #,{'class':['li li_best2_pop1','li li_best2_pop0']}
del contents[:20]
del contents[19:len(contents)]

# %%
len(contents)
# Out:
# 19

# %%
cnt=1
result=[]
for i in contents:
    tmp={}
    print('-'*15)
    print(cnt)
    cnt=cnt+1
    

    # 제목 추출
    title=i.find('span',{"id":"subject"}).text.strip()
    print("제목: ", title)
    
   
    
    # 글쓴이 추출
    writer_tag = i.find('td', {"class":"minitext2 listnm"})
    if writer_tag is not None: # None 값이 있으므로 조건문을 통해 회피 
        writer = writer_tag.text
      
    else:
        writer = "없음"
    print("글쓴이: ", writer)
    
#     # 유동이나 고닉이 아닌 글쓴이 옆에 있는 ip 추출
#     ip_tag = i.find('td', class_='gall_writer ub-writer').find('span', class_='ip')
#     if ip_tag is not None:  # None 값이 있으므로 조건문을 통해 회피 
#         ip = ip_tag.text
#         print("ip: ", ip)



    # 날짜 추출 
    date=i.find('td',{"class":"listno regdate"}).text
    print("날짜: ",date)
    
    
    # 조회 수 추출
    views = i.find_all('td', {"class":"listno"})[2].text
    print("조회수: ", views)


    # 댓글 수
    comment=i.find('a',{"id":"view_cmt"})
    if comment==None:
        comment=0
    else:
        comment=comment.text
    print("댓글수: ", comment)
    
    # 추천 수 추출
    recommend = i.find_all('td', {"class":"listno"})[3].text
    print("추천수: ", recommend)

    
    tmp['제목']=title
    tmp['글쓴이']=writer
    tmp['날짜']=date
    tmp['조회수']=views
    tmp['댓글수']=comment
    tmp['추천수']=recommend
    
    result.append(tmp)
# Out:
# ---------------
# 1
# 제목:  영국언론 데일리메일에 나온 한국 연예인
# 글쓴이:  에자키히카루
# 날짜:  1:01
# 조회수:  2
# 댓글수:  0
# 추천수:  0
# ---------------
# 2
# 제목:  개그계가 힘들어진 이유
# 글쓴이:  옹뇸뇸뇸
# 날짜:  1:01
# 조회수:  1
# 댓글수:  0
# 추천수:  0
# ---------------
# 3
# 제목:  슈퍼스타 이정후의 9회 2사상황 역전타
# 글쓴이:  오이카와 토비
# 날짜:  0:56
# 조회수:  69
# 댓글수:  0
# 추천수:  0
# ---------------
# 4
# 제목:  일본 오키나와 수중화산 폭발로 댄 해변
# 글쓴이:  싯떼루네`ワ
# 날짜:  0:56
# 조회수:  246
# 댓글수:  0
# 추천수:  0
# ---------------
# 5
# 제목:  브이앱 하는 오마이걸 아린.gif
# 글쓴이:  아이오아이 김
# 날짜:  0:56
# 조회수:  267
# 댓글수:  0
# 추천수:  0
# ---------------
# 6
# 제목:  4만원에 여친한테 정떨어지면 내가 이상한건가?
# 글쓴이:  다시 태어날
# 날짜:  0:56
# 조회수:  465
# 댓글수:  0
# 추천수:  0
# ---------------
# 7
# 제목:  호스로 물마시는 코끼리
# 글쓴이:  .서로가 서로
# 날짜:  0:49
# 조회수:  365
# 댓글수:  0
# 추천수:  0
# ---------------
# 8
# 제목:  포르투갈 리스본 짤들
# 글쓴이:  멍ㅇ멍이 소리
# 날짜:  0:48
# 조회수:  201
# 댓글수:  0
# 추천수:  0
# ---------------
# 9
# 제목:  지상파 최초 [프리스타일-Y완전체Live] _211015
# 글쓴이:  He
# 날짜:  0:47
# 조회수:  316
# 댓글수:  0
# 추천수:  0
# ---------------
# 10
# 제목:  임시완이 공개한 연애횟수.jpg
# 글쓴이:  다시한번말씀
# 날짜:  0:39
# 조회수:  4226
# 댓글수:  11
# 추천수:  1
# ---------------
# 11
# 제목:  손웅정옹 에세이에 언급된 '그 사진'에 대한 비하인드.jpg
# 글쓴이:  패딩조끼
# 날짜:  0:39
# 조회수:  687
# 댓글수:  0
# 추천수:  0
# ---------------
# 12
# 제목:  오늘자 한문철티비 레전드
# 글쓴이:  이진기(30)
# 날짜:  0:39
# 조회수:  246
# 댓글수:  0
# 추천수:  0
# ---------------
# 13
# 제목:  스테이씨 윤세은 '색안경' 직캠 교차편집.twt
# 글쓴이:  녹차말차킬러
# 날짜:  0:38
# 조회수:  476
# 댓글수:  0
# 추천수:  0
# ---------------
# 14
# 제목:  서울 뷔페 3대장
# 글쓴이:  멍ㅇ멍이 소리
# 날짜:  0:37
# 조회수:  1444
# 댓글수:  0
# 추천수:  0
# ---------------
# 15
# 제목:  사고치는 고양이.jpg
# 글쓴이:  헤에에이~
# 날짜:  0:36
# 조회수:  1336
# 댓글수:  3
# 추천수:  2
# ---------------
# 16
# 제목:  영국 데일리메일 홈피에서 발견된 한류...jpg
# 글쓴이:  최민호(26)
# 날짜:  0:35
# 조회수:  1205
# 댓글수:  0
# 추천수:  0
# ---------------
# 17
# 제목:  LEC바이탈리티 영입 루머
# 글쓴이:  남준선배
# 날짜:  0:34
# 조회수:  45
# 댓글수:  0
# 추천수:  0
# ---------------
# 18
# 제목:  삼성 핸드폰 테스트 엔지니어도 어쩔 수 없는 취향
# 글쓴이:  다시한번말씀
# 날짜:  0:27
# 조회수:  2950
# 댓글수:  1
# 추천수:  1
# ---------------
# 19
# 제목:  털관리 잘한 리트리버
# 글쓴이:  Wannable(워너
# 날짜:  0:25
# 조회수:  2504
# 댓글수:  2
# 추천수:  0

# %%
df=pd.DataFrame(result)
df
# Out:
#                                    제목          글쓴이    날짜   조회수 댓글수 추천수
# 0               영국언론 데일리메일에 나온 한국 연예인       에자키히카루  1:01     2   0   0
# 1                        개그계가 힘들어진 이유         옹뇸뇸뇸  1:01     1   0   0
# 2               슈퍼스타 이정후의 9회 2사상황 역전타      오이카와 토비  0:56    69   0   0
# 3               일본 오키나와 수중화산 폭발로 댄 해변       싯떼루네`ワ  0:56   246   0   0
# 4                  브이앱 하는 오마이걸 아린.gif      아이오아이 김  0:56   267   0   0
# 5           4만원에 여친한테 정떨어지면 내가 이상한건가?       다시 태어날  0:56   465   0   0
# 6                        호스로 물마시는 코끼리      .서로가 서로  0:49   365   0   0
# 7                         포르투갈 리스본 짤들      멍ㅇ멍이 소리  0:48   201   0   0
# 8     지상파 최초 [프리스타일-Y완전체Live] _211015           He  0:47   316   0   0
# 9                   임시완이 공개한 연애횟수.jpg       다시한번말씀  0:39  4226  11   1
# 10  손웅정옹 에세이에 언급된 '그 사진'에 대한 비하인드.jpg         패딩조끼  0:39   687   0   0
# 11                      오늘자 한문철티비 레전드      이진기(30)  0:39   246   0   0
# 12         스테이씨 윤세은 '색안경' 직캠 교차편집.twt       녹차말차킬러  0:38   476   0   0
# 13                          서울 뷔페 3대장      멍ㅇ멍이 소리  0:37  1444   0   0
# 14                       사고치는 고양이.jpg        헤에에이~  0:36  1336   3   2
# 15         영국 데일리메일 홈피에서 발견된 한류...jpg      최민호(26)  0:35  1205   0   0
# 16                     LEC바이탈리티 영입 루머         남준선배  0:34    45   0   0
# 17        삼성 핸드폰 테스트 엔지니어도 어쩔 수 없는 취향       다시한번말씀  0:27  2950   1   1
# 18                        털관리 잘한 리트리버  Wannable(워너  0:25  2504   2   0

# %%
df.to_excel('data/instiz_인티포털.xlsx')

# %%
# 전체 인기글

# %%
contents2=soup.select('#rank1to10 > div')
contents2.extend(soup.select('#rank11to20 > div'))

# %%
#전체 인기글
cnt=1
result2=[]
for i in contents2:
    tmp={}
    print('-'*15)
    print(cnt)
    
    #게시판 추출
    category=i.find('div', {"class":"minitext"}).text
    print("게시판: ", category)
    
    
    # 제목 추출
    if cnt<11:
        title=i.select_one('#rank1to10 > div > div.rank_subject > a').text.strip()
    else:
        title=i.select_one('#rank11to20 > div > div.rank_subject > a').text.strip()
    print("제목: ", title)
    
   
    
#    # 글쓴이 추출
#    writer_tag = i.find('td', {"class":"minitext2 listnm"})
#    if writer_tag is not None: # None 값이 있으므로 조건문을 통해 회피 
#        writer = writer_tag.text
#      
#    else:
#        writer = "없음"
#    print("글쓴이: ", writer)
    
#     # 유동이나 고닉이 아닌 글쓴이 옆에 있는 ip 추출
#     ip_tag = i.find('td', class_='gall_writer ub-writer').find('span', class_='ip')
#     if ip_tag is not None:  # None 값이 있으므로 조건문을 통해 회피 
#         ip = ip_tag.text
#         print("ip: ", ip)



#    # 날짜 추출 
#    date=i.find('td',{"class":"listno regdate"}).text
#    print("날짜: ",date)
    
    
#    # 조회 수 추출
#    views = i.find_all('td', {"class":"listno"})[2].text
#    print("조회수: ", views)


    # 댓글 수
    comment=i.find('a',{"class":"cmt"})
    if comment==None:
        comment=0
    else:
        comment=comment.text
    print("댓글수: ", comment)
    
#    # 추천 수 추출
#    recommend = i.find_all('td', {"class":"listno"})[3].text
#    print("추천수: ", recommend)

    tmp['게시판']=category
    tmp['제목']=title
#    tmp['글쓴이']=writer
#    tmp['날짜']=date
#    tmp['조회수']=views
    tmp['댓글수']=comment
#    tmp['추천수']=recommend
    
    result2.append(tmp)
    
    cnt=cnt+1
# Out:
# ---------------
# 1
# 게시판:  인티포털
# 제목:  임시완이 공개한 연애횟수.jpg
# 댓글수:  10
# ---------------
# 2
# 게시판:  익명잡담
# 제목:  우리집 고삼이 바람 쐬고 온다고 하고 이 시간에 울면서 나갔..
# 댓글수:  6
# ---------------
# 3
# 게시판:  익명잡담
# 제목:  와씨 라면스프 먹는데 대.존.맛
# 댓글수:  12
# ---------------
# 4
# 게시판:  인티포털
# 제목:  용산 아이맥스때문에 남친이랑 싸운 여자.jpg
# 댓글수:  49
# ---------------
# 5
# 게시판:  익명잡담
# 제목:  이틀에 한번 샤워하면 더러워?
# 댓글수:  39
# ---------------
# 6
# 게시판:  인티포털
# 제목:  최근들어 정말 예쁘다는 생각이 드는 분
# 댓글수:  33
# ---------------
# 7
# 게시판:  익명잡담
# 제목:  하루에 6~7시간 씩 하는
# 댓글수:  5
# ---------------
# 8
# 게시판:  인티포털
# 제목:  미쳐버린 어느 웹소설 설정
# 댓글수:  6
# ---------------
# 9
# 게시판:  인티포털
# 제목:  트위치 어느 여스트리머의 방송정지 사유.jpgif
# 댓글수:  4
# ---------------
# 10
# 게시판:  익명잡담
# 제목:  브라렛이랑 그냥 브라랑 뭐가달라??
# 댓글수:  11
# ---------------
# 11
# 게시판:  익명잡담
# 제목:  [연애중] 계란말이된 썰 푼다,,
# 댓글수:  2
# ---------------
# 12
# 게시판:  인티포털
# 제목:  요즘 sns에 미남들이 많은 이유
# 댓글수:  18
# ---------------
# 13
# 게시판:  인티포털
# 제목:  삼성 핸드폰 테스트 엔지니어도 어쩔 수 없는 취향
# 댓글수:  1
# ---------------
# 14
# 게시판:  익명잡담
# 제목:  나 쌍수 망한 걸까… 심각하게 재수술 고민 중인데 한번씩 봐..
# 댓글수:  23
# ---------------
# 15
# 게시판:  인티포털
# 제목:  KFC 선넘는 신메뉴 폰치밥.jpg
# 댓글수:  12
# ---------------
# 16
# 게시판:  인티포털
# 제목:  환경호르몬 많이 나오는데 흐린눈 하는 사람 많은 것.jpg
# 댓글수:  42
# ---------------
# 17
# 게시판:  익명잡담
# 제목:  어른들 말 중에 틀린말 하나 없다..를 느끼게해준 말
# 댓글수:  7
# ---------------
# 18
# 게시판:  익명잡담
# 제목:  나 네일아트 자랑해도 될까?(두근
# 댓글수:  14
# ---------------
# 19
# 게시판:  인티포털
# 제목:  다음날 숙취가 없다는 술
# 댓글수:  13
# ---------------
# 20
# 게시판:  익명잡담
# 제목:  아빠가 대기업 임원인게 엄청 대단한거임?
# 댓글수:  8

# %%
df2=pd.DataFrame(result2)
df2
# Out:
#      게시판                                   제목 댓글수
# 0   인티포털                    임시완이 공개한 연애횟수.jpg  10
# 1   익명잡담  우리집 고삼이 바람 쐬고 온다고 하고 이 시간에 울면서 나갔..   6
# 2   익명잡담                    와씨 라면스프 먹는데 대.존.맛  12
# 3   인티포털            용산 아이맥스때문에 남친이랑 싸운 여자.jpg  49
# 4   익명잡담                     이틀에 한번 샤워하면 더러워?  39
# 5   인티포털                최근들어 정말 예쁘다는 생각이 드는 분  33
# 6   익명잡담                       하루에 6~7시간 씩 하는   5
# 7   인티포털                       미쳐버린 어느 웹소설 설정   6
# 8   인티포털          트위치 어느 여스트리머의 방송정지 사유.jpgif   4
# 9   익명잡담                  브라렛이랑 그냥 브라랑 뭐가달라??  11
# 10  익명잡담                   [연애중] 계란말이된 썰 푼다,,   2
# 11  인티포털                   요즘 sns에 미남들이 많은 이유  18
# 12  인티포털          삼성 핸드폰 테스트 엔지니어도 어쩔 수 없는 취향   1
# 13  익명잡담  나 쌍수 망한 걸까… 심각하게 재수술 고민 중인데 한번씩 봐..  23
# 14  인티포털                  KFC 선넘는 신메뉴 폰치밥.jpg  12
# 15  인티포털     환경호르몬 많이 나오는데 흐린눈 하는 사람 많은 것.jpg  42
# 16  익명잡담        어른들 말 중에 틀린말 하나 없다..를 느끼게해준 말   7
# 17  익명잡담                   나 네일아트 자랑해도 될까?(두근  14
# 18  인티포털                        다음날 숙취가 없다는 술  13
# 19  익명잡담               아빠가 대기업 임원인게 엄청 대단한거임?   8

# %%
df2.to_excel('data/instiz_전체인기글.xlsx')

# %%
# 인티포털 인기글

# %%
contents3=soup.select('#rank1to10_menu > div')
contents3.extend(soup.select('#rank11to20_menu > div'))

# %%
#전체 인기글
cnt=1
result3=[]
for i in contents3:
    tmp={}
    print('-'*15)
    print(cnt)
    
    
    # 제목 추출
    if cnt<11:
        title=i.select_one('#rank1to10_menu > div > div.rank_subject > a').text.strip()
    else:
        title=i.select_one('#rank11to20_menu > div > div.rank_subject > a').text.strip()
    print("제목: ", title)
    
   
    
#    # 글쓴이 추출
#    writer_tag = i.find('td', {"class":"minitext2 listnm"})
#    if writer_tag is not None: # None 값이 있으므로 조건문을 통해 회피 
#        writer = writer_tag.text
#      
#    else:
#        writer = "없음"
#    print("글쓴이: ", writer)
    
#     # 유동이나 고닉이 아닌 글쓴이 옆에 있는 ip 추출
#     ip_tag = i.find('td', class_='gall_writer ub-writer').find('span', class_='ip')
#     if ip_tag is not None:  # None 값이 있으므로 조건문을 통해 회피 
#         ip = ip_tag.text
#         print("ip: ", ip)



#    # 날짜 추출 
#    date=i.find('td',{"class":"listno regdate"}).text
#    print("날짜: ",date)
    
    
#    # 조회 수 추출
#    views = i.find_all('td', {"class":"listno"})[2].text
#    print("조회수: ", views)


    # 댓글 수
    comment=i.find('a',{"class":"cmt"})
    if comment==None:
        comment=0
    else:
        comment=comment.text
    print("댓글수: ", comment)
    
#    # 추천 수 추출
#    recommend = i.find_all('td', {"class":"listno"})[3].text
#    print("추천수: ", recommend)

    tmp['제목']=title
#    tmp['글쓴이']=writer
#    tmp['날짜']=date
#    tmp['조회수']=views
    tmp['댓글수']=comment
#    tmp['추천수']=recommend
    
    result3.append(tmp)
    
    cnt=cnt+1
# Out:
# ---------------
# 1
# 제목:  임시완이 공개한 연애횟수.jpg
# 댓글수:  10
# ---------------
# 2
# 제목:  용산 아이맥스때문에 남친이랑 싸운 여자.jpg
# 댓글수:  49
# ---------------
# 3
# 제목:  최근들어 정말 예쁘다는 생각이 드는 분
# 댓글수:  33
# ---------------
# 4
# 제목:  미쳐버린 어느 웹소설 설정
# 댓글수:  6
# ---------------
# 5
# 제목:  요즘 sns에 미남들이 많은 이유
# 댓글수:  18
# ---------------
# 6
# 제목:  다음날 숙취가 없다는 술
# 댓글수:  13
# ---------------
# 7
# 제목:  트위치 어느 여스트리머의 방송정지 사유.jpgif
# 댓글수:  4
# ---------------
# 8
# 제목:  환경호르몬 많이 나오는데 흐린눈 하는 사람 많은 것.jpg
# 댓글수:  42
# ---------------
# 9
# 제목:  삼성 핸드폰 테스트 엔지니어도 어쩔 수 없는 취향
# 댓글수:  1
# ---------------
# 10
# 제목:  KFC 선넘는 신메뉴 폰치밥.jpg
# 댓글수:  12
# ---------------
# 11
# 제목:  4만원에 여친한테 정떨어지면 내가 이상한건가?
# 댓글수:  0
# ---------------
# 12
# 제목:  일반인이 아이돌 메이크업을 받았을때.jpg
# 댓글수:  42
# ---------------
# 13
# 제목:  연구원에게 발각되어 만짐당하는 팔라스고양이
# 댓글수:  14
# ---------------
# 14
# 제목:  털관리 잘한 리트리버
# 댓글수:  2
# ---------------
# 15
# 제목:  파리에서 오징어게임 배우로 오해받는 유튜버
# 댓글수:  36
# ---------------
# 16
# 제목:  마블 최초로 토마토 썩은 이터널스
# 댓글수:  38
# ---------------
# 17
# 제목:  할로윈때 뚱뚱해지는 서양다람쥐들
# 댓글수:  67
# ---------------
# 18
# 제목:  사고치는 고양이.jpg
# 댓글수:  3
# ---------------
# 19
# 제목:  서울 뷔페 3대장
# 댓글수:  0
# ---------------
# 20
# 제목:  영국 데일리메일 홈피에서 발견된 한류...jpg
# 댓글수:  0

# %%
df3=pd.DataFrame(result3)
df3
# Out:
#                                   제목 댓글수
# 0                  임시완이 공개한 연애횟수.jpg  10
# 1          용산 아이맥스때문에 남친이랑 싸운 여자.jpg  49
# 2              최근들어 정말 예쁘다는 생각이 드는 분  33
# 3                     미쳐버린 어느 웹소설 설정   6
# 4                 요즘 sns에 미남들이 많은 이유  18
# 5                      다음날 숙취가 없다는 술  13
# 6        트위치 어느 여스트리머의 방송정지 사유.jpgif   4
# 7   환경호르몬 많이 나오는데 흐린눈 하는 사람 많은 것.jpg  42
# 8        삼성 핸드폰 테스트 엔지니어도 어쩔 수 없는 취향   1
# 9                KFC 선넘는 신메뉴 폰치밥.jpg  12
# 10         4만원에 여친한테 정떨어지면 내가 이상한건가?   0
# 11           일반인이 아이돌 메이크업을 받았을때.jpg  42
# 12           연구원에게 발각되어 만짐당하는 팔라스고양이  14
# 13                       털관리 잘한 리트리버   2
# 14           파리에서 오징어게임 배우로 오해받는 유튜버  36
# 15                마블 최초로 토마토 썩은 이터널스  38
# 16                 할로윈때 뚱뚱해지는 서양다람쥐들  67
# 17                      사고치는 고양이.jpg   3
# 18                         서울 뷔페 3대장   0
# 19        영국 데일리메일 홈피에서 발견된 한류...jpg   0

# %%
df3.to_excel('data/instiz_인티포털인기글.xlsx')
