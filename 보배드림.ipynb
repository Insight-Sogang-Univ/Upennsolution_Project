# %%
from bs4 import BeautifulSoup as bs
import requests as req
import pandas as pd
import datetime
from datetime import timedelta

# %%
base_url='https://www.bobaedream.co.kr/list?code=best&s_cate=&maker_no=&model_no=&or_gu=10&or_se=desc&s_selday=&pagescale=30&info3=&noticeShow=&s_select=&s_key=&level_no=&bestCode=&bestDays=&bestbbs=&vdate=&type=list&page=1'
headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.54 Safari/537.36"}

# %%
d = datetime.datetime.now()
now = d.strftime('%X')

# %%
cnt=1
result=[]
for i in range(1,11):
    params={"page":i}
    raw=req.get(base_url,params=params, headers=headers)
    soup=bs(raw.content, 'html.parser')
    contents = soup.find('tbody').find_all('tr')
    
    for i in contents:
        tmp={}
        print('-'*15)
        print(cnt)
        cnt=cnt+1

        # 게시판 추출
        category=i.find('td', {"class":"category"}).get('title')
        print("분야: ", category)

        # 제목 추출
        title=i.find('a',{"class":"bsubject"}).text.strip()
        print("제목: ", title)



        # 글쓴이 추출
        writer_tag = i.find('span', {"class":"author"})
        if writer_tag is not None: # None 값이 있으므로 조건문을 통해 회피 
            writer = writer_tag.get('title')

        else:
            writer = "없음"
        print("글쓴이: ", writer)

    #    # 유동이나 고닉이 아닌 글쓴이 옆에 있는 ip 추출
    #    ip_tag = i.find('td', class_='gall_writer ub-writer').find('span', class_='ip')
    #    if ip_tag is not None:  # None 값이 있으므로 조건문을 통해 회피 
    #        ip = ip_tag.text
    #        print("ip: ", ip)



        # 날짜 추출 
        date=i.find('td',{"class":"date"}).text
        if date.find(':')== -1:
            date=d.strftime('%Y')+'.'+date[:2]+'.'+date[3:]
        else:
            date=d.strftime('%Y.%m.%d ')+date            
        print("날짜: ",date)


        # 조회 수 추출
        views = i.find('td',{"class":"count"}).text
        print("조회수: ", views)


        # 댓글 수
        comment=i.find('span',{"class":"Comment"})
        if comment==None:
            comment=0
        else:
            comment=comment.find('strong', {"class":"totreply"}).text
        print("댓글수: ", comment)


        # 추천 수 추출
        recommend = i.find('td', {"class":"recomm"}).text
        print("추천수: ", recommend)

        tmp['분야']=category
        tmp['제목']=title
        tmp['글쓴이']=writer
        tmp['날짜']=date
        tmp['조회수']=views
        tmp['댓글수']=comment
        tmp['추천수']=recommend

        result.append(tmp)
# Out:
# ---------------
# 1
# 분야:  유머게시판
# 제목:  [택시개그]오늘 부터 타면 저럴겁니다!!!
# 글쓴이:  꿀잠드림
# 날짜:  2021.11.18 12:59
# 조회수:  1867
# 댓글수:  3
# 추천수:  44
# ---------------
# 2
# 분야:  유머게시판
# 제목:  문화 강국이 중요한 이유
# 글쓴이:  자객8
# 날짜:  2021.11.18 12:43
# 조회수:  3423
# 댓글수:  9
# 추천수:  48
# ---------------
# 3
# 분야:  유머게시판
# 제목:  현재 포털 메인에 없는 기사
# 글쓴이:  FormulaK
# 날짜:  2021.11.18 12:31
# 조회수:  10429
# 댓글수:  35
# 추천수:  200
# ---------------
# 4
# 분야:  유머게시판
# 제목:  창고에 요소수 8천 리터, 시가 6배 팔려다 덜미
# 글쓴이:  MEECL
# 날짜:  2021.11.18 12:08
# 조회수:  10786
# 댓글수:  28
# 추천수:  176
# ---------------
# 5
# 분야:  유머게시판
# 제목:  김건희의 상습적 허위이력, 윤석열 더 버틸수 없다.
# 글쓴이:  이장님오른팔
# 날짜:  2021.11.18 12:07
# 조회수:  10611
# 댓글수:  41
# 추천수:  195
# ---------------
# 6
# 분야:  유머게시판
# 제목:  LG 의인상 근황
# 글쓴이:  KKKANG
# 날짜:  2021.11.18 12:05
# 조회수:  14346
# 댓글수:  27
# 추천수:  174
# ---------------
# 7
# 분야:  유머게시판
# 제목:  최민희 의원 "외신이 본 이재명 후보는..."
# 글쓴이:  팰리오너
# 날짜:  2021.11.18 11:58
# 조회수:  11668
# 댓글수:  49
# 추천수:  260
# ---------------
# 8
# 분야:  유머게시판
# 제목:  중국.일본 '평화를 사랑하는 나라'
# 글쓴이:  ESSE
# 날짜:  2021.11.18 11:54
# 조회수:  7990
# 댓글수:  33
# 추천수:  142
# ---------------
# 9
# 분야:  자유게시판
# 제목:  시골 울엄마 오늘  방송합니다^^
# 글쓴이:  삽교형
# 날짜:  2021.11.18 11:52
# 조회수:  7033
# 댓글수:  39
# 추천수:  169
# ---------------
# 10
# 분야:  유머게시판
# 제목:  극혐주의 ) 우리 대천사는xx엘 보거라...
# 글쓴이:  배에다쌀께
# 날짜:  2021.11.18 11:48
# 조회수:  9419
# 댓글수:  24
# 추천수:  95
# ---------------
# 11
# 분야:  유머게시판
# 제목:  부러진 목발을 보며 울고 있는 노숙자
# 글쓴이:  장칼빈
# 날짜:  2021.11.18 11:42
# 조회수:  13039
# 댓글수:  34
# 추천수:  132
# ---------------
# 12
# 분야:  유머게시판
# 제목:  멘탈갑 편의점 점장님
# 글쓴이:  마음은콩밭에
# 날짜:  2021.11.18 11:40
# 조회수:  13556
# 댓글수:  24
# 추천수:  149
# ---------------
# 13
# 분야:  유머게시판
# 제목:  엘카미찡~~~~ 혹시 질투 하시는건가예?
# 글쓴이:  올
# 날짜:  2021.11.18 11:39
# 조회수:  2386
# 댓글수:  9
# 추천수:  36
# ---------------
# 14
# 분야:  유머게시판
# 제목:  네가 유게21년동안 정치글
# 글쓴이:  마즈까싸대기
# 날짜:  2021.11.18 11:37
# 조회수:  2916
# 댓글수:  11
# 추천수:  55
# ---------------
# 15
# 분야:  유머게시판
# 제목:  국민의힘 부럽네요 진짜
# 글쓴이:  Quark
# 날짜:  2021.11.18 11:35
# 조회수:  11515
# 댓글수:  54
# 추천수:  151
# ---------------
# 16
# 분야:  유머게시판
# 제목:  수능 민폐 2030여성들.jgp
# 글쓴이:  신원미상남성
# 날짜:  2021.11.18 11:33
# 조회수:  7485
# 댓글수:  13
# 추천수:  47
# ---------------
# 17
# 분야:  유머게시판
# 제목:  술값이 싼 이유가 있었구만~
# 글쓴이:  맑은먹구름
# 날짜:  2021.11.18 11:33
# 조회수:  13026
# 댓글수:  16
# 추천수:  138
# ---------------
# 18
# 분야:  자유게시판
# 제목:  오늘 또 한분의 영웅이 생을 마감하셨습니다
# 글쓴이:  와일드번치
# 날짜:  2021.11.18 11:31
# 조회수:  7995
# 댓글수:  22
# 추천수:  131
# ---------------
# 19
# 분야:  유머게시판
# 제목:  공평하게 하자...
# 글쓴이:  시아love
# 날짜:  2021.11.18 11:27
# 조회수:  10442
# 댓글수:  20
# 추천수:  212
# ---------------
# 20
# 분야:  유머게시판
# 제목:  올 으르신 이거 어디팔아요?
# 글쓴이:  6기최주동검사
# 날짜:  2021.11.18 11:24
# 조회수:  6215
# 댓글수:  20
# 추천수:  46
# ---------------
# 21
# 분야:  유머게시판
# 제목:  최강욱 대표, 윤석열 타골!!! ㅡ
# 글쓴이:  U2Bono
# 날짜:  2021.11.18 11:24
# 조회수:  11107
# 댓글수:  35
# 추천수:  149
# ---------------
# 22
# 분야:  유머게시판
# 제목:  정치글 존나 싫은데 하마디만 하자
# 글쓴이:  12시까지
# 날짜:  2021.11.18 11:20
# 조회수:  10296
# 댓글수:  47
# 추천수:  159
# ---------------
# 23
# 분야:  유머게시판
# 제목:  "가시지요" ㅡ
# 글쓴이:  U2Bono
# 날짜:  2021.11.18 11:20
# 조회수:  3270
# 댓글수:  5
# 추천수:  43
# ---------------
# 24
# 분야:  유머게시판
# 제목:  엘카미찡......혹시 동정인가예?
# 글쓴이:  올
# 날짜:  2021.11.18 11:15
# 조회수:  6475
# 댓글수:  15
# 추천수:  56
# ---------------
# 25
# 분야:  유머게시판
# 제목:  준석이 결국 꼬랑지 내렸네요 ㅋㅋㅋ
# 글쓴이:  이건아니라고봐
# 날짜:  2021.11.18 11:11
# 조회수:  8614
# 댓글수:  14
# 추천수:  63
# ---------------
# 26
# 분야:  유머게시판
# 제목:  《베삭재업》김빙삼옹의 좃선 타골! ㅡ
# 글쓴이:  U2Bono
# 날짜:  2021.11.18 11:08
# 조회수:  4886
# 댓글수:  7
# 추천수:  84
# ---------------
# 27
# 분야:  유머게시판
# 제목:  뇌피셜 끗판왕...엘카미찡은 또 보지 말입니다!
# 글쓴이:  올
# 날짜:  2021.11.18 11:07
# 조회수:  4570
# 댓글수:  22
# 추천수:  45
# ---------------
# 28
# 분야:  유머게시판
# 제목:  ● 유머) 즐겁게웃고가세요 ~ㅋㅋㅋ♡
# 글쓴이:  행복한카라이프
# 날짜:  2021.11.18 11:07
# 조회수:  8587
# 댓글수:  46
# 추천수:  174
# ---------------
# 29
# 분야:  유머게시판
# 제목:  이탄희 의원 글입니다 -우리가 언론이다!!!  [나의 소속 ..
# 글쓴이:  복수는처절하게
# 날짜:  2021.11.18 11:05
# 조회수:  3724
# 댓글수:  15
# 추천수:  96
# ---------------
# 30
# 분야:  유머게시판
# 제목:  현재 한국 문화의 위상 ㅡ
# 글쓴이:  U2Bono
# 날짜:  2021.11.18 10:55
# 조회수:  7213
# 댓글수:  9
# 추천수:  68
# ---------------
# 31
# 분야:  유머게시판
# 제목:  남자화장실 변기를 철거하는 이유.JPG [
# 글쓴이:  우룰
# 날짜:  2021.11.18 10:53
# 조회수:  20223
# 댓글수:  57
# 추천수:  149
# ---------------
# 32
# 분야:  유머게시판
# 제목:  34살먹고 첫직장생김 내 썰좀 들어주라
# 글쓴이:  ESSE
# 날짜:  2021.11.18 10:46
# 조회수:  17890
# 댓글수:  45
# 추천수:  225
# ---------------
# 33
# 분야:  유머게시판
# 제목:  항문왜란
# 글쓴이:  양보배
# 날짜:  2021.11.18 10:46
# 조회수:  13950
# 댓글수:  25
# 추천수:  164
# ---------------
# 34
# 분야:  유머게시판
# 제목:  엘카미찡~~~ [또 보지 말입니다~]
# 글쓴이:  올
# 날짜:  2021.11.18 10:42
# 조회수:  5615
# 댓글수:  22
# 추천수:  49
# ---------------
# 35
# 분야:  교통사고/사건/블랙박스
# 제목:  [펑복] 교통사고 참 답답하네요..
# 글쓴이:  방향지지등
# 날짜:  2021.11.18 10:37
# 조회수:  1178
# 댓글수:  17
# 추천수:  21
# ---------------
# 36
# 분야:  유머게시판
# 제목:  ● 유머) 즐겁게 웃고가세요~♡ (동물편)
# 글쓴이:  행복한카라이프
# 날짜:  2021.11.18 10:37
# 조회수:  8241
# 댓글수:  40
# 추천수:  146
# ---------------
# 37
# 분야:  유머게시판
# 제목:  전우용님 페북
# 글쓴이:  gjao
# 날짜:  2021.11.18 10:37
# 조회수:  1159
# 댓글수:  3
# 추천수:  25
# ---------------
# 38
# 분야:  유머게시판
# 제목:  직우차선에서 안비킨다고 임산부에게 폭언
# 글쓴이:  ESSE
# 날짜:  2021.11.18 10:35
# 조회수:  6973
# 댓글수:  52
# 추천수:  127
# ---------------
# 39
# 분야:  유머게시판
# 제목:  국짐 지지자 대표적인 특징 TOP5
# 글쓴이:  개구리입쏙독새
# 날짜:  2021.11.18 10:32
# 조회수:  3438
# 댓글수:  15
# 추천수:  68
# ---------------
# 40
# 분야:  유머게시판
# 제목:  《박건웅 화백》'조국사태의 진실' ㅡ
# 글쓴이:  U2Bono
# 날짜:  2021.11.18 10:31
# 조회수:  2260
# 댓글수:  10
# 추천수:  55
# ---------------
# 41
# 분야:  유머게시판
# 제목:  오늘자 김어준 생각
# 글쓴이:  gjao
# 날짜:  2021.11.18 10:29
# 조회수:  1619
# 댓글수:  2
# 추천수:  31
# ---------------
# 42
# 분야:  유머게시판
# 제목:  ● 유머) 즐겁게 웃고가세요~♡  (해외편)
# 글쓴이:  행복한카라이프
# 날짜:  2021.11.18 10:27
# 조회수:  6416
# 댓글수:  42
# 추천수:  94
# ---------------
# 43
# 분야:  유머게시판
# 제목:  취객이 던진 돌에 오토바이 배달 청년 사망
# 글쓴이:  진짜싼아이
# 날짜:  2021.11.18 10:21
# 조회수:  4439
# 댓글수:  8
# 추천수:  41
# ---------------
# 44
# 분야:  유머게시판
# 제목:  병원 직원이 체포된 이유.jpg
# 글쓴이:  공격젖
# 날짜:  2021.11.18 10:15
# 조회수:  7054
# 댓글수:  13
# 추천수:  31
# ---------------
# 45
# 분야:  유머게시판
# 제목:  미카엘이 보배에 오는 이유
# 글쓴이:  맑은먹구름
# 날짜:  2021.11.18 10:11
# 조회수:  9903
# 댓글수:  35
# 추천수:  119
# ---------------
# 46
# 분야:  유머게시판
# 제목:  왜 여경 체력 가지고만 그러세요
# 글쓴이:  영화에서처럼
# 날짜:  2021.11.18 10:04
# 조회수:  9390
# 댓글수:  15
# 추천수:  60
# ---------------
# 47
# 분야:  유머게시판
# 제목:  곽상도 근황 ㅋㅋㅋㅋㅋ
# 글쓴이:  붓다페스트
# 날짜:  2021.11.18 09:32
# 조회수:  3202
# 댓글수:  8
# 추천수:  38
# ---------------
# 48
# 분야:  교통사고/사건/블랙박스
# 제목:  우리나라 도로에 0차선이 있나보네요....?
# 글쓴이:  글렌피딕
# 날짜:  2021.11.18 09:31
# 조회수:  7257
# 댓글수:  89
# 추천수:  72
# ---------------
# 49
# 분야:  유머게시판
# 제목:  기레기들이 가장 신뢰하는 언론사
# 글쓴이:  남의떡
# 날짜:  2021.11.18 09:19
# 조회수:  1201
# 댓글수:  8
# 추천수:  20
# ---------------
# 50
# 분야:  유머게시판
# 제목:  여성전용 키스방 알바썰
# 글쓴이:  공격젖
# 날짜:  2021.11.18 08:57
# 조회수:  28513
# 댓글수:  36
# 추천수:  181
# ---------------
# 51
# 분야:  국산차게시판
# 제목:  임무 완수했습니다!
# 글쓴이:  진산이의혁명이
# 날짜:  2021.11.18 08:18
# 조회수:  13148
# 댓글수:  27
# 추천수:  201
# ---------------
# 52
# 분야:  교통사고/사건/블랙박스
# 제목:  [펑복]  생명의 위협을 당했습니다
# 글쓴이:  인생은불법
# 날짜:  2021.11.18 08:10
# 조회수:  11999
# 댓글수:  32
# 추천수:  81
# ---------------
# 53
# 분야:  교통사고/사건/블랙박스
# 제목:  [펑복] 접촉사고났습니다
# 글쓴이:  인생은불법
# 날짜:  2021.11.18 08:10
# 조회수:  6500
# 댓글수:  45
# 추천수:  61
# ---------------
# 54
# 분야:  유머게시판
# 제목:  갑질쩌는 사장님
# 글쓴이:  걸인28호
# 날짜:  2021.11.18 08:05
# 조회수:  9660
# 댓글수:  4
# 추천수:  86
# ---------------
# 55
# 분야:  유머게시판
# 제목:  신고정신이 투철한 여경
# 글쓴이:  걸인28호
# 날짜:  2021.11.18 07:57
# 조회수:  6176
# 댓글수:  28
# 추천수:  54
# ---------------
# 56
# 분야:  유머게시판
# 제목:  영(아닌)부인납신다.(부정탈까 제목 바꿈)
# 글쓴이:  꽃미남용
# 날짜:  2021.11.18 07:36
# 조회수:  14444
# 댓글수:  40
# 추천수:  185
# ---------------
# 57
# 분야:  자유게시판
# 제목:  15년 도시락의 마지막을 만들고  수능 시험장 보내고 왔네요
# 글쓴이:  푸니샤니와
# 날짜:  2021.11.18 07:32
# 조회수:  9808
# 댓글수:  62
# 추천수:  385
# ---------------
# 58
# 분야:  유머게시판
# 제목:  [충격] 윤석열 쩍벌은 습관이 아니었따!!!!
# 글쓴이:  더운여름날
# 날짜:  2021.11.18 07:20
# 조회수:  27173
# 댓글수:  58
# 추천수:  371
# ---------------
# 59
# 분야:  자유게시판
# 제목:  %%베스트감사합니다%% 막내 아들자랑요~~~초6입니다
# 글쓴이:  경산옥곡
# 날짜:  2021.11.18 07:05
# 조회수:  4491
# 댓글수:  48
# 추천수:  87
# ---------------
# 60
# 분야:  유머게시판
# 제목:  34살 먹고 첫 직장 생긴 디씨인
# 글쓴이:  누가넘버쑤리랫
# 날짜:  2021.11.18 06:40
# 조회수:  6203
# 댓글수:  5
# 추천수:  27
# ---------------
# 61
# 분야:  유머게시판
# 제목:  미성년자 고삐리 사기꾼 민사로 조지기
# 글쓴이:  울지않는새
# 날짜:  2021.11.18 06:14
# 조회수:  37011
# 댓글수:  77
# 추천수:  483
# ---------------
# 62
# 분야:  유머게시판
# 제목:  왕릉뷰 아파트 기사 댓글
# 글쓴이:  울지않는새
# 날짜:  2021.11.18 05:45
# 조회수:  7786
# 댓글수:  10
# 추천수:  84
# ---------------
# 63
# 분야:  유머게시판
# 제목:  홍준표 근황
# 글쓴이:  스프트니크
# 날짜:  2021.11.18 04:57
# 조회수:  13953
# 댓글수:  8
# 추천수:  163
# ---------------
# 64
# 분야:  자동차사진/동영상
# 제목:  2021 현대 세븐컨셉트
# 글쓴이:  718746
# 날짜:  2021.11.18 03:23
# 조회수:  8201
# 댓글수:  13
# 추천수:  40
# ---------------
# 65
# 분야:  국산차게시판
# 제목:  현대 아이오닉7 컨셉트 월드프리미어 공개
# 글쓴이:  718746
# 날짜:  2021.11.18 03:12
# 조회수:  13481
# 댓글수:  41
# 추천수:  37
# ---------------
# 66
# 분야:  유머게시판
# 제목:  K-여경 근황
# 글쓴이:  에리카엘리슨
# 날짜:  2021.11.18 01:34
# 조회수:  48587
# 댓글수:  132
# 추천수:  707
# ---------------
# 67
# 분야:  유머게시판
# 제목:  국짐 지지자와 민주 지지자들의 차이
# 글쓴이:  MEECL
# 날짜:  2021.11.18 01:20
# 조회수:  15427
# 댓글수:  55
# 추천수:  219
# ---------------
# 68
# 분야:  유머게시판
# 제목:  친일파의 이름이나 얼굴이라도 알아두자
# 글쓴이:  스폰지밥뚱이
# 날짜:  2021.11.18 01:02
# 조회수:  13175
# 댓글수:  50
# 추천수:  302
# ---------------
# 69
# 분야:  유머게시판
# 제목:  여경을 왜 뽑는건지
# 글쓴이:  0zll
# 날짜:  2021.11.18 00:39
# 조회수:  19236
# 댓글수:  50
# 추천수:  211
# ---------------
# 70
# 분야:  유머게시판
# 제목:  눈물이 납니다. 진심 대한민국 국민인개
# 글쓴이:  시발놈아
# 날짜:  2021.11.18 00:37
# 조회수:  39411
# 댓글수:  61
# 추천수:  714
# ---------------
# 71
# 분야:  교통사고/사건/블랙박스
# 제목:  출구 지나친상태에서 차선 급변경
# 글쓴이:  두햐
# 날짜:  2021.11.18 00:27
# 조회수:  5897
# 댓글수:  25
# 추천수:  71
# ---------------
# 72
# 분야:  자유게시판
# 제목:  대구식당 중학생일당보복 난동사건 공론화 부탁합니다.
# 글쓴이:  노매너처리하자
# 날짜:  2021.11.18 00:11
# 조회수:  4994
# 댓글수:  55
# 추천수:  134
# ---------------
# 73
# 분야:  유머게시판
# 제목:  경찰 앞에서 흉기 난동...여경은 지원요청
# 글쓴이:  윈스9192
# 날짜:  2021.11.17
# 조회수:  26338
# 댓글수:  110
# 추천수:  597
# ---------------
# 74
# 분야:  유머게시판
# 제목:  내가 사장이면 누구를 직원으로 뽑겠습니까
# 글쓴이:  송파배짱이
# 날짜:  2021.11.17
# 조회수:  16634
# 댓글수:  14
# 추천수:  175
# ---------------
# 75
# 분야:  유머게시판
# 제목:  여경 논란 가볍게 생각하시나요?
# 글쓴이:  직영매체
# 날짜:  2021.11.17
# 조회수:  60120
# 댓글수:  186
# 추천수:  1055
# ---------------
# 76
# 분야:  교통사고/사건/블랙박스
# 제목:  ㅋㅋ살다 이런 시발 오토바이는 첨봅니다
# 글쓴이:  아프리카몰라요
# 날짜:  2021.11.17
# 조회수:  7328
# 댓글수:  9
# 추천수:  89
# ---------------
# 77
# 분야:  유머게시판
# 제목:  여경 덕분에 목숨 건진 가족
# 글쓴이:  Parcferme
# 날짜:  2021.11.17
# 조회수:  31339
# 댓글수:  67
# 추천수:  329
# ---------------
# 78
# 분야:  유머게시판
# 제목:  ● 유머) 쓸데없이 멋있는~♡
# 글쓴이:  행복한카라이프
# 날짜:  2021.11.17
# 조회수:  27966
# 댓글수:  56
# 추천수:  320
# ---------------
# 79
# 분야:  트럭/버스/중기
# 제목:  오늘자 개통.....
# 글쓴이:  안중
# 날짜:  2021.11.17
# 조회수:  5132
# 댓글수:  6
# 추천수:  31
# ---------------
# 80
# 분야:  유머게시판
# 제목:  와이프가 차려준 생일상 ㄷㄷ .jpg
# 글쓴이:  월악산조용필
# 날짜:  2021.11.17
# 조회수:  78879
# 댓글수:  215
# 추천수:  740
# ---------------
# 81
# 분야:  유머게시판
# 제목:  ● 유머) 동물 시리즈~ㅋㅋㅋ♡
# 글쓴이:  행복한카라이프
# 날짜:  2021.11.17
# 조회수:  21601
# 댓글수:  58
# 추천수:  371
# ---------------
# 82
# 분야:  자동차사진/동영상
# 제목:  2023 캐딜락 리릭 럭셔리
# 글쓴이:  SVO7
# 날짜:  2021.11.17
# 조회수:  3586
# 댓글수:  7
# 추천수:  34
# ---------------
# 83
# 분야:  시승기/배틀/목격담
# 제목:  2020 K9 3.8깡통 2000km시승기
# 글쓴이:  진청색스팅어
# 날짜:  2021.11.17
# 조회수:  7134
# 댓글수:  13
# 추천수:  46
# ---------------
# 84
# 분야:  교통사고/사건/블랙박스
# 제목:  어찌 이곳을 주차장이라 생각할 수 있을까
# 글쓴이:  그때즈음
# 날짜:  2021.11.17
# 조회수:  5740
# 댓글수:  16
# 추천수:  74
# ---------------
# 85
# 분야:  유머게시판
# 제목:  윤석열 참담한 수준 ㄷㄷㄷㄷ
# 글쓴이:  송파배짱이
# 날짜:  2021.11.17
# 조회수:  74359
# 댓글수:  131
# 추천수:  908
# ---------------
# 86
# 분야:  유머게시판
# 제목:  김건희 공범 중 최소 3명과 관계를 맺고 있었다는 이야기네.
# 글쓴이:  이름만찍사
# 날짜:  2021.11.17
# 조회수:  19093
# 댓글수:  28
# 추천수:  260
# ---------------
# 87
# 분야:  유머게시판
# 제목:  자전거 경기중 선수의 사고 순발력
# 글쓴이:  화끈한청바지
# 날짜:  2021.11.17
# 조회수:  5949
# 댓글수:  5
# 추천수:  25
# ---------------
# 88
# 분야:  국산차게시판
# 제목:  이거 뭐여?
# 글쓴이:  창문열고팔걸치기
# 날짜:  2021.11.17
# 조회수:  4457
# 댓글수:  29
# 추천수:  35
# ---------------
# 89
# 분야:  교통사고/사건/블랙박스
# 제목:  악질 딸배새끼
# 글쓴이:  떡더큼
# 날짜:  2021.11.17
# 조회수:  3123
# 댓글수:  1
# 추천수:  78
# ---------------
# 90
# 분야:  국산차게시판
# 제목:  쉐보레 SSR
# 글쓴이:  porsche964
# 날짜:  2021.11.17
# 조회수:  5097
# 댓글수:  5
# 추천수:  42
# ---------------------------------------------------------------------------
# SSLEOFError                               Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     410
# --> 411         self.sock = ssl_wrap_socket(
#     412             sock=conn,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     427     if send_sni:
# --> 428         ssl_sock = _ssl_wrap_socket_impl(
#     429             sock, context, tls_in_tls, server_hostname=server_hostname
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     471     if server_hostname:
# --> 472         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     473     else:
#
# C:\ProgramData\Anaconda3\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# C:\ProgramData\Anaconda3\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#
# C:\ProgramData\Anaconda3\lib\ssl.py in do_handshake(self, block)
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#
# SSLEOFError: EOF occurred in violation of protocol (_ssl.c:1125)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='www.bobaedream.co.kr', port=443): Max retries exceeded with url: /list?code=best&s_cate=&maker_no=&model_no=&or_gu=10&or_se=desc&s_selday=&pagescale=30&info3=&noticeShow=&s_select=&s_key=&level_no=&bestCode=&bestDays=&bestbbs=&vdate=&type=list&page=1&page=4 (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1125)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-29-505b650a59aa> in <module>
#       3 for i in range(1,11):
#       4     params={"page":i}
# ----> 5     raw=req.get(base_url,params=params, headers=headers)
#       6     soup=bs(raw.content, 'html.parser')
#       7     contents = soup.find('tbody').find_all('tr')
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     512             if isinstance(e.reason, _SSLError):
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#     516             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='www.bobaedream.co.kr', port=443): Max retries exceeded with url: /list?code=best&s_cate=&maker_no=&model_no=&or_gu=10&or_se=desc&s_selday=&pagescale=30&info3=&noticeShow=&s_select=&s_key=&level_no=&bestCode=&bestDays=&bestbbs=&vdate=&type=list&page=1&page=4 (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1125)')))

# %%
df=pd.DataFrame(result)
df
# Out:
#               분야                                 제목         글쓴이  \
# 0          유머게시판            [택시개그]오늘 부터 타면 저럴겁니다!!!        꿀잠드림
# 1          유머게시판                      문화 강국이 중요한 이유         자객8
# 2          유머게시판                    현재 포털 메인에 없는 기사    FormulaK
# 3          유머게시판        창고에 요소수 8천 리터, 시가 6배 팔려다 덜미       MEECL
# 4          유머게시판       김건희의 상습적 허위이력, 윤석열 더 버틸수 없다.      이장님오른팔
# ..           ...                                ...         ...
# 85         유머게시판  김건희 공범 중 최소 3명과 관계를 맺고 있었다는 이야기네.       이름만찍사
# 86         유머게시판                 자전거 경기중 선수의 사고 순발력      화끈한청바지
# 87        국산차게시판                             이거 뭐여?    창문열고팔걸치기
# 88  교통사고/사건/블랙박스                            악질 딸배새끼         떡더큼
# 89        국산차게시판                            쉐보레 SSR  porsche964
#
#                   날짜    조회수 댓글수  추천수
# 0   2021.11.18 12:59   1867   3   44
# 1   2021.11.18 12:43   3423   9   48
# 2   2021.11.18 12:31  10429  35  200
# 3   2021.11.18 12:08  10786  28  176
# 4   2021.11.18 12:07  10611  41  195
# ..               ...    ...  ..  ...
# 85        2021.11.17  19093  28  260
# 86        2021.11.17   5949   5   25
# 87        2021.11.17   4457  29   35
# 88        2021.11.17   3123   1   78
# 89        2021.11.17   5097   5   42
#
# [90 rows x 7 columns]

# %%
df.to_excel('data/보배드림.xlsx')
