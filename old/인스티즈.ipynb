# %%
from bs4 import BeautifulSoup as bs
import requests as req
import pandas as pd
import datetime
from datetime import timedelta

# %%
base_url='https://www.instiz.net/pt?page=1'
headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.54 Safari/537.36"}

# %%
d = datetime.datetime.now()
now = d.strftime('%X')

# %%
cnt=1
result=[]
for i in range(1,11):
    params={"page":i}
    raw=req.get(base_url,params=params, headers=headers)
    soup=bs(raw.content, 'html.parser')
    contents = soup.find_all('tr')
    del contents[:20]
    del contents[19:len(contents)]
    
    for i in contents:
        tmp={}
        print('-'*15)
        print(cnt)
        cnt=cnt+1


        # 제목 추출
        title=i.find('span',{"id":"subject"}).text.strip()
        print("제목: ", title)



        # 글쓴이 추출
        writer_tag = i.find('td', {"class":"minitext2 listnm"})
        if writer_tag is not None: # None 값이 있으므로 조건문을 통해 회피 
            writer = writer_tag.text

        else:
            writer = "없음"
        print("글쓴이: ", writer)

    #     # 유동이나 고닉이 아닌 글쓴이 옆에 있는 ip 추출
    #     ip_tag = i.find('td', class_='gall_writer ub-writer').find('span', class_='ip')
    #     if ip_tag is not None:  # None 값이 있으므로 조건문을 통해 회피 
    #         ip = ip_tag.text
    #         print("ip: ", ip)



        # 날짜 추출 
        date=i.find('td',{"class":"listno regdate"}).text
        if len(date)<=5:
            if len(date)<=4:
                date=d.strftime('%Y.%m.%d ')+'0'+date
            else:
                date=d.strftime('%Y.%m.%d ')+date
        else:
            date=d.strftime('%Y')+'.'+date[:5]
        print("날짜: ",date)


        # 조회 수 추출
        views = i.find_all('td', {"class":"listno"})[2].text
        print("조회수: ", views)


        # 댓글 수
        comment=i.find('a',{"id":"view_cmt"})
        if comment==None:
            comment=0
        else:
            comment=comment.text
        print("댓글수: ", comment)

        # 추천 수 추출
        recommend = i.find_all('td', {"class":"listno"})[3].text
        print("추천수: ", recommend)


        tmp['제목']=title
        tmp['글쓴이']=writer
        tmp['날짜']=date
        tmp['조회수']=views
        tmp['댓글수']=comment
        tmp['추천수']=recommend

        result.append(tmp)
# Out:
# ---------------
# 1
# 제목:  김종국 데뷔 26년만에 악플고소 선처없다
# 글쓴이:  내기분냥냥
# 날짜:  2021.11.18 20:32
# 조회수:  336
# 댓글수:  0
# 추천수:  0
# ---------------
# 2
# 제목:  남녀 키스후 반응 차이 ㅋㅋㅋㅋㅋㅋㅋ
# 글쓴이:  던던둔둔
# 날짜:  2021.11.18 20:31
# 조회수:  823
# 댓글수:  0
# 추천수:  0
# ---------------
# 3
# 제목:  AZ, 모더나 접종 중단한답니다.. 그런데 맞은사람은 어떻게 되는거죠?
# 글쓴이:  해르반창식
# 날짜:  2021.11.18 20:28
# 조회수:  1807
# 댓글수:  0
# 추천수:  0
# ---------------
# 4
# 제목:  법잘알이 미성년자 사기꾼 상대하는 법
# 글쓴이:  311344_return
# 날짜:  2021.11.18 20:27
# 조회수:  795
# 댓글수:  0
# 추천수:  0
# ---------------
# 5
# 제목:  자취생에게 가습기란
# 글쓴이:  S.COUPS.
# 날짜:  2021.11.18 20:26
# 조회수:  1072
# 댓글수:  0
# 추천수:  0
# ---------------
# 6
# 제목:  수능 끝났다. 서성한 중 추천받는다
# 글쓴이:  김낑깡
# 날짜:  2021.11.18 20:26
# 조회수:  1024
# 댓글수:  0
# 추천수:  0
# ---------------
# 7
# 제목:  최초로 평균키 174cm 찍은 01년생.jpg
# 글쓴이:  NCT 지 성
# 날짜:  2021.11.18 20:25
# 조회수:  1028
# 댓글수:  0
# 추천수:  0
# ---------------
# 8
# 제목:  남친 납골당에서 남친 친구랑 키스했어...pann
# 글쓴이:  아이오아이 김
# 날짜:  2021.11.18 20:24
# 조회수:  1133
# 댓글수:  0
# 추천수:  0
# ---------------
# 9
# 제목:  난이도 미친 오늘자 수능 수학 15번
# 글쓴이:  색지
# 날짜:  2021.11.18 20:24
# 조회수:  532
# 댓글수:  0
# 추천수:  0
# ---------------
# 10
# 제목:  갤럭시 Z 플립3 5G 노티드 에디션
# 글쓴이:  알케이
# 날짜:  2021.11.18 20:24
# 조회수:  733
# 댓글수:  0
# 추천수:  0
# ---------------
# 11
# 제목:  요즘 애들은 모르는 컴퓨터 용품
# 글쓴이:  토끼네
# 날짜:  2021.11.18 20:22
# 조회수:  552
# 댓글수:  0
# 추천수:  0
# ---------------
# 12
# 제목:  27만원에 인생을 판 고딩
# 글쓴이:  Bring back to
# 날짜:  2021.11.18 20:21
# 조회수:  3091
# 댓글수:  6
# 추천수:  1
# ---------------
# 13
# 제목:  이걸 어떻게 라이브로 부를까 궁금한 윤하 이번 앨범 수록곡(feat.오르트..
# 글쓴이:  옹성우박우진
# 날짜:  2021.11.18 20:21
# 조회수:  212
# 댓글수:  1
# 추천수:  0
# ---------------
# 14
# 제목:  쿠팡 33%할인중!! 언능 사세요😍
# 글쓴이:  방탄전용날개
# 날짜:  2021.11.18 20:15
# 조회수:  979
# 댓글수:  1
# 추천수:  0
# ---------------
# 15
# 제목:  19일 컴백 예고한 하성운 두번째 티저
# 글쓴이:  bbqqqq
# 날짜:  2021.11.18 20:09
# 조회수:  82
# 댓글수:  0
# 추천수:  1
# ---------------
# 16
# 제목:  부스터샷 맞아야 '백신패스'…'접종완료' 정의 바뀐다
# 글쓴이:  종길
# 날짜:  2021.11.18 20:05
# 조회수:  7385
# 댓글수:  44
# 추천수:  4
# ---------------
# 17
# 제목:  웰시코기 궁디
# 글쓴이:  천러러러
# 날짜:  2021.11.18 20:05
# 조회수:  987
# 댓글수:  0
# 추천수:  0
# ---------------
# 18
# 제목:  차돌박이 된장찌개
# 글쓴이:  원 + 원
# 날짜:  2021.11.18 20:00
# 조회수:  941
# 댓글수:  1
# 추천수:  0
# ---------------
# 19
# 제목:  우마무스메 한국 공식 유튭의 첫 동영상
# 글쓴이:  션국이네 메르
# 날짜:  2021.11.18 19:56
# 조회수:  473
# 댓글수:  0
# 추천수:  0
# ---------------
# 20
# 제목:  2년 반 전에 갑자기 잠수탄 친구한테 연락왔다..
# 글쓴이:  더보이즈 이주
# 날짜:  2021.11.18 19:51
# 조회수:  7983
# 댓글수:  38
# 추천수:  3
# ---------------
# 21
# 제목:  엄마의 목숨을 구한 갓시코기
# 글쓴이:  마유
# 날짜:  2021.11.18 19:50
# 조회수:  2176
# 댓글수:  2
# 추천수:  2
# ---------------
# 22
# 제목:  많이 나아진 식탐견.gif
# 글쓴이:  게임을시작하
# 날짜:  2021.11.18 19:50
# 조회수:  2231
# 댓글수:  9
# 추천수:  0
# ---------------
# 23
# 제목:  디시에서 시키는 대로 했더니 인생이 바뀐 디시인
# 글쓴이:  311344_return
# 날짜:  2021.11.18 19:48
# 조회수:  1799
# 댓글수:  0
# 추천수:  0
# ---------------
# 24
# 제목:  조선인들은 빵처럼 구워지는 걸 좋아한다
# 글쓴이:  벤츄리
# 날짜:  2021.11.18 19:37
# 조회수:  7334
# 댓글수:  19
# 추천수:  4
# ---------------
# 25
# 제목:  드래곤볼 최고이자 가장 현실적인 캐릭터
# 글쓴이:  애드링
# 날짜:  2021.11.18 19:35
# 조회수:  1733
# 댓글수:  3
# 추천수:  0
# ---------------
# 26
# 제목:  강형욱도 놀랄만한 입질 있는 강아지 훈련법.gif
# 글쓴이:  호롤로롤롤
# 날짜:  2021.11.18 19:35
# 조회수:  5398
# 댓글수:  14
# 추천수:  2
# ---------------
# 27
# 제목:  열도의 톰과 제리 굿즈 근황
# 글쓴이:  Side to Side
# 날짜:  2021.11.18 19:34
# 조회수:  2401
# 댓글수:  1
# 추천수:  0
# ---------------
# 28
# 제목:  부장님 가정을 망가뜨린 것 같다..
# 글쓴이:  우물밖 여고
# 날짜:  2021.11.18 19:33
# 조회수:  12013
# 댓글수:  19
# 추천수:  17
# ---------------
# 29
# 제목:  헬장에 레깅스녀랑 단둘이 있을때 쓸수있는 꿀팁.jpg
# 글쓴이:  영은수
# 날짜:  2021.11.18 19:33
# 조회수:  6825
# 댓글수:  15
# 추천수:  1
# ---------------
# 30
# 제목:  쁘걸 단발좌 노출(?)에 대한 꼬북좌의 의견
# 글쓴이:  겟
# 날짜:  2021.11.18 19:33
# 조회수:  3875
# 댓글수:  0
# 추천수:  0
# ---------------
# 31
# 제목:  블라인드 한전 여직원의 군경력인정에 대한 생각
# 글쓴이:  깐부
# 날짜:  2021.11.18 19:31
# 조회수:  1067
# 댓글수:  0
# 추천수:  0
# ---------------
# 32
# 제목:  요즘 10대 남자 메이크업.jpg
# 글쓴이:  굿데이_희진
# 날짜:  2021.11.18 19:30
# 조회수:  2574
# 댓글수:  2
# 추천수:  0
# ---------------
# 33
# 제목:  아들 온라인 강의용으로 컴퓨터 맞춘 사람.jpg
# 글쓴이:  임팩트FBI
# 날짜:  2021.11.18 19:30
# 조회수:  1279
# 댓글수:  0
# 추천수:  0
# ---------------
# 34
# 제목:  "여경 뽑을수록 피해 보는건 국민.. 경찰, 페미코인 그만"
# 글쓴이:  깐부
# 날짜:  2021.11.18 19:26
# 조회수:  2091
# 댓글수:  8
# 추천수:  2
# ---------------
# 35
# 제목:  중고거래하다 갑자기 칼로 찌르는 사람
# 글쓴이:  NUEST-W
# 날짜:  2021.11.18 19:25
# 조회수:  8520
# 댓글수:  11
# 추천수:  4
# ---------------
# 36
# 제목:  삼성 홍단장"이학주 트레이드 시간 걸리지만 추진할 것”
# 글쓴이:  배진영(a.k.a발
# 날짜:  2021.11.18 19:20
# 조회수:  234
# 댓글수:  0
# 추천수:  0
# ---------------
# 37
# 제목:  얘 도대체 왜이럼.gif
# 글쓴이:  옹성우박우진
# 날짜:  2021.11.18 19:14
# 조회수:  2061
# 댓글수:  2
# 추천수:  0
# ---------------
# 38
# 제목:  최근 인스타와 틱톡 점령한 노래
# 글쓴이:  지수
# 날짜:  2021.11.18 19:09
# 조회수:  2432
# 댓글수:  2
# 추천수:  0
# ---------------
# 39
# 제목:  트와이스 팬들, 박명수 SNS에 "사과 안하면 계속 공격"…왜?
# 글쓴이:  붐붐붐붐
# 날짜:  2021.11.18 19:05
# 조회수:  14198
# 댓글수:  40
# 추천수:  4
# ---------------
# 40
# 제목:  수학1등급 '이과생'이 95.5% '싹쓸이'국어 1등급 80%, 영어 1등..
# 글쓴이:  Busu031
# 날짜:  2021.11.18 19:00
# 조회수:  12991
# 댓글수:  42
# 추천수:  5
# ---------------
# 41
# 제목:  파스타 면 보다가 열받은 침착맨
# 글쓴이:  더보이즈 상
# 날짜:  2021.11.18 18:59
# 조회수:  6406
# 댓글수:  6
# 추천수:  3
# ---------------
# 42
# 제목:  테일러 스위프트: 늘 먹던 그 맛에 정성을 추가
# 글쓴이:  최민호(26)
# 날짜:  2021.11.18 18:59
# 조회수:  701
# 댓글수:  0
# 추천수:  0
# ---------------
# 43
# 제목:  이젠 별로 놀랍지도 않은 커리의 딥쓰리들..
# 글쓴이:  따온
# 날짜:  2021.11.18 18:57
# 조회수:  776
# 댓글수:  0
# 추천수:  0
# ---------------
# 44
# 제목:  4글자로 세상에서 가장무서운말을 지어봐
# 글쓴이:  김낑깡
# 날짜:  2021.11.18 18:57
# 조회수:  2356
# 댓글수:  7
# 추천수:  0
# ---------------
# 45
# 제목:  캡틴아메리카 레전드.gif
# 글쓴이:  Vitro
# 날짜:  2021.11.18 18:55
# 조회수:  2010
# 댓글수:  3
# 추천수:  0
# ---------------
# 46
# 제목:  쓰다듬을 원하는 고양이 .gif
# 글쓴이:  한 편의 너
# 날짜:  2021.11.18 18:44
# 조회수:  5001
# 댓글수:  12
# 추천수:  8
# ---------------
# 47
# 제목:  여친이 화장실갈때 노트북을 덮고 간 이유...jpg
# 글쓴이:  윤세원
# 날짜:  2021.11.18 18:43
# 조회수:  4310
# 댓글수:  2
# 추천수:  0
# ---------------
# 48
# 제목:  캡틴 아메리카 레전드.gif
# 글쓴이:  Vitro
# 날짜:  2021.11.18 18:42
# 조회수:  1807
# 댓글수:  1
# 추천수:  0
# ---------------
# 49
# 제목:  옛날 메이플스토리 추억의 희귀템들 - 1
# 글쓴이:  WANNA ONE 하
# 날짜:  2021.11.18 18:42
# 조회수:  1186
# 댓글수:  1
# 추천수:  2
# ---------------
# 50
# 제목:  10억이 있으면 쿠팡에서 살 수 있는 것
# 글쓴이:  더보이즈 이주
# 날짜:  2021.11.18 18:42
# 조회수:  2847
# 댓글수:  3
# 추천수:  0
# ---------------
# 51
# 제목:  이제동 승부욕.gif
# 글쓴이:  멍ㅇ멍이 소리
# 날짜:  2021.11.18 18:42
# 조회수:  371
# 댓글수:  0
# 추천수:  0
# ---------------
# 52
# 제목:  잘못 온 택배 제가 가져도 문제 없나요?
# 글쓴이:  마카롱꿀떡
# 날짜:  2021.11.18 18:40
# 조회수:  7178
# 댓글수:  24
# 추천수:  3
# ---------------
# 53
# 제목:  차기 특수전용 기관단총 사업에서 SNT모티브를 제꼈던 다신기공 근황
# 글쓴이:  유기현 (25)
# 날짜:  2021.11.18 18:39
# 조회수:  160
# 댓글수:  0
# 추천수:  1
# ---------------
# 54
# 제목:  하아... 우리 부장...
# 글쓴이:  無地태
# 날짜:  2021.11.18 18:37
# 조회수:  903
# 댓글수:  0
# 추천수:  0
# ---------------
# 55
# 제목:  실시간 ㅈ된 디씨수붕이.jpg
# 글쓴이:  He
# 날짜:  2021.11.18 18:34
# 조회수:  6572
# 댓글수:  5
# 추천수:  0
# ---------------
# 56
# 제목:  있지 류진이 롤모델인 여돌의 커버 댄스
# 글쓴이:  버가버가부
# 날짜:  2021.11.18 18:29
# 조회수:  11568
# 댓글수:  18
# 추천수:  0
# ---------------
# 57
# 제목:  사귀기 전에 키스해도 괜찮다는 박세리.jpg
# 글쓴이:  나천재
# 날짜:  2021.11.18 18:23
# 조회수:  2660
# 댓글수:  2
# 추천수:  0
# ---------------
# 58
# 제목:  김건모 성폭행 수사 무혐의 결론
# 글쓴이:  ~~
# 날짜:  2021.11.18 18:21
# 조회수:  1430
# 댓글수:  0
# 추천수:  1
# ---------------
# 59
# 제목:  한국인 정서상 실존하기 힘든 카페 진상류 甲
# 글쓴이:  산타세레나
# 날짜:  2021.11.18 18:15
# 조회수:  20108
# 댓글수:  17
# 추천수:  20
# ---------------
# 60
# 제목:  ㄹㅇ 멋있음 그 자체라는 방과후 설렘 담임 선공개 영상
# 글쓴이:  버가버가부
# 날짜:  2021.11.18 18:14
# 조회수:  3906
# 댓글수:  4
# 추천수:  0
# ---------------
# 61
# 제목:  대식가 히밥에게 식비 50만원을 주었다
# 글쓴이:  나천재
# 날짜:  2021.11.18 18:08
# 조회수:  12237
# 댓글수:  9
# 추천수:  6
# ---------------
# 62
# 제목:  [MV] BIG Naughty(서동현) - STAB (feat. eaJ) ..
# 글쓴이:  바보같은그대
# 날짜:  2021.11.18 18:06
# 조회수:  94
# 댓글수:  0
# 추천수:  0
# ---------------
# 63
# 제목:  형들 시키는대로 했더니 인생이 바뀐거 같음
# 글쓴이:  에자키히카루
# 날짜:  2021.11.18 17:58
# 조회수:  3178
# 댓글수:  5
# 추천수:  0
# ---------------
# 64
# 제목:  논란중인 결혼식 사진
# 글쓴이:  next
# 날짜:  2021.11.18 17:53
# 조회수:  23253
# 댓글수:  29
# 추천수:  7
# ---------------
# 65
# 제목:  아이가 사망했을때 가장 힘들다는 일
# 글쓴이:  Bring back to
# 날짜:  2021.11.18 17:52
# 조회수:  22390
# 댓글수:  38
# 추천수:  40
# ---------------
# 66
# 제목:  낚시 명당을 아는 고양이.gif
# 글쓴이:  성우야♡
# 날짜:  2021.11.18 17:51
# 조회수:  3343
# 댓글수:  5
# 추천수:  1
# ---------------
# 67
# 제목:  45층에서 의자던짐..jpgif
# 글쓴이:  Wannable(워너
# 날짜:  2021.11.18 17:51
# 조회수:  2704
# 댓글수:  3
# 추천수:  0
# ---------------
# 68
# 제목:  래퍼로써 누가 위인가? vs
# 글쓴이:  +ordin
# 날짜:  2021.11.18 17:51
# 조회수:  1356
# 댓글수:  4
# 추천수:  0
# ---------------
# 69
# 제목:  코쟁이들 한자 쓰는 방법
# 글쓴이:  더보이즈 이주
# 날짜:  2021.11.18 17:48
# 조회수:  9462
# 댓글수:  19
# 추천수:  0
# ---------------
# 70
# 제목:  마마 신인상 후보 오른 그룹.jpg
# 글쓴이:  꾸루뀨
# 날짜:  2021.11.18 17:43
# 조회수:  764
# 댓글수:  0
# 추천수:  1
# ---------------
# 71
# 제목:  'that'이 연속 5번 쓰인 문장
# 글쓴이:  djekxn
# 날짜:  2021.11.18 17:42
# 조회수:  17746
# 댓글수:  37
# 추천수:  3
# ---------------
# 72
# 제목:  금연 포스터 우수상
# 글쓴이:  김낑깡
# 날짜:  2021.11.18 17:38
# 조회수:  2844
# 댓글수:  3
# 추천수:  2
# ---------------
# 73
# 제목:  왓챠 아메리칸 뮤직 어워드 단독 중계 근황
# 글쓴이:  비끼
# 날짜:  2021.11.18 17:27
# 조회수:  1610
# 댓글수:  0
# 추천수:  1
# ---------------
# 74
# 제목:  어제 박명수 트와이스 라디오 전문.txt
# 글쓴이:  벤츄리
# 날짜:  2021.11.18 17:25
# 조회수:  11361
# 댓글수:  24
# 추천수:  2
# ---------------
# 75
# 제목:  수능시험장까지 따라온 아이돌 팬들
# 글쓴이:  깐부
# 날짜:  2021.11.18 17:22
# 조회수:  2266
# 댓글수:  0
# 추천수:  0
# ---------------
# 76
# 제목:  샤워를 즐기는 치와와 ㄷㄷ.gif
# 글쓴이:  언행일치
# 날짜:  2021.11.18 17:18
# 조회수:  5270
# 댓글수:  12
# 추천수:  4
# ---------------
# 77
# 제목:  간지나는 재장전 짤.gif
# 글쓴이:  뭐야 너
# 날짜:  2021.11.18 17:15
# 조회수:  2347
# 댓글수:  1
# 추천수:  0
# ---------------
# 78
# 제목:  술 마시고 노래 배틀하는 SF9 (절미네민박2)
# 글쓴이:  시츄안닮았어
# 날짜:  2021.11.18 17:13
# 조회수:  396
# 댓글수:  0
# 추천수:  0
# ---------------
# 79
# 제목:  45층에서 의자 던지는 여자ㄷㄷ
# 글쓴이:  청량섹시 김태
# 날짜:  2021.11.18 17:07
# 조회수:  4474
# 댓글수:  5
# 추천수:  1
# ---------------
# 80
# 제목:  외국 살았던 사람들만 아는 한국의 문제점
# 글쓴이:  311342_return
# 날짜:  2021.11.18 17:00
# 조회수:  36534
# 댓글수:  185
# 추천수:  12
# ---------------
# 81
# 제목:  가슴이 유난히 컸던 여후배.jpg
# 글쓴이:  최민호(26)
# 날짜:  2021.11.18 17:00
# 조회수:  19535
# 댓글수:  35
# 추천수:  5
# ---------------
# 82
# 제목:  일본의 한류 유행
# 글쓴이:  우물밖 여고
# 날짜:  2021.11.18 17:00
# 조회수:  9993
# 댓글수:  7
# 추천수:  0
# ---------------
# 83
# 제목:  뿌링클 볶음면 출시.JPG
# 글쓴이:  아이오아이 김
# 날짜:  2021.11.18 17:00
# 조회수:  22777
# 댓글수:  32
# 추천수:  4
# ---------------
# 84
# 제목:  유튜브에서 킬링타임용으로 역주행중인 애니.JPG
# 글쓴이:  토끼네
# 날짜:  2021.11.18 16:58
# 조회수:  4350
# 댓글수:  0
# 추천수:  1
# ---------------
# 85
# 제목:  편의점서 남성 맨가슴 만진 20대女…강제추행죄 '벌금 100만원'
# 글쓴이:  널 사랑해 영
# 날짜:  2021.11.18 16:53
# 조회수:  10485
# 댓글수:  40
# 추천수:  3
# ---------------
# 86
# 제목:  수능 긴급상황 대비체험.jpg
# 글쓴이:  멍ㅇ멍이 소리
# 날짜:  2021.11.18 16:51
# 조회수:  4361
# 댓글수:  6
# 추천수:  0
# ---------------
# 87
# 제목:  지하철 '불법촬영범' 잡고보니… "휴대전화에 여성 사진 1만 장"
# 글쓴이:  곰젤링
# 날짜:  2021.11.18 16:47
# 조회수:  3041
# 댓글수:  7
# 추천수:  2
# ---------------
# 88
# 제목:  물개 밥 뺏어 먹은 갈매기의 최후
# 글쓴이:  성우야♡
# 날짜:  2021.11.18 16:46
# 조회수:  4735
# 댓글수:  4
# 추천수:  0
# ---------------
# 89
# 제목:  수능날 파업하는게 똑똑한 이유
# 글쓴이:  호롤로롤롤
# 날짜:  2021.11.18 16:43
# 조회수:  29410
# 댓글수:  8
# 추천수:  9
# ---------------
# 90
# 제목:  여돌이 게임캐릭터로 변해가는 과정...gif
# 글쓴이:  슈슈슈슈슈슈
# 날짜:  2021.11.18 16:35
# 조회수:  2649
# 댓글수:  1
# 추천수:  0
# ---------------
# 91
# 제목:  방송중 본인 커리어 자랑하는 연예인들
# 글쓴이:  즐겨즐겨
# 날짜:  2021.11.18 16:27
# 조회수:  3774
# 댓글수:  0
# 추천수:  1
# ---------------
# 92
# 제목:  [단독] 양현석 전 YG 대표, 서울 홍대 상가 174억 원에 매각
# 글쓴이:  지수
# 날짜:  2021.11.18 16:24
# 조회수:  6623
# 댓글수:  1
# 추천수:  1
# ---------------
# 93
# 제목:  방송가에 흔하지 않은 명품 여성 MC...jpg
# 글쓴이:  꾸루뀨
# 날짜:  2021.11.18 16:24
# 조회수:  20084
# 댓글수:  30
# 추천수:  22
# ---------------
# 94
# 제목:  여자 역사 선생님의 팩폭에 뿔난 그녀들
# 글쓴이:  깐부
# 날짜:  2021.11.18 16:16
# 조회수:  14277
# 댓글수:  40
# 추천수:  3
# ---------------
# 95
# 제목:  김옥빈 전남친 얘기 들은 신동엽의 반응
# 글쓴이:  세훈이를업어
# 날짜:  2021.11.18 16:11
# 조회수:  4007
# 댓글수:  2
# 추천수:  1
# ---------------
# 96
# 제목:  90년대 인터넷을 대했던 자세
# 글쓴이:  게임을시작하
# 날짜:  2021.11.18 16:10
# 조회수:  3619
# 댓글수:  1
# 추천수:  1
# ---------------
# 97
# 제목:  [단독] "판사님, 시X 진짜"욕설..한서희, 필로폰 투약 '징역 1년6월..
# 글쓴이:  세상에 잘생긴
# 날짜:  2021.11.18 16:06
# 조회수:  5377
# 댓글수:  4
# 추천수:  0
# ---------------
# 98
# 제목:  2000년대 초반 국내 씹어먹었던 연예인.JPG
# 글쓴이:  NCT 지 성
# 날짜:  2021.11.18 16:06
# 조회수:  5044
# 댓글수:  5
# 추천수:  3
# ---------------
# 99
# 제목:  헤어지자는 여친 찌르고 고층 베란다 밖으로 던진 30대 남성 체포
# 글쓴이:  방'탄소'년단
# 날짜:  2021.11.18 15:57
# 조회수:  3904
# 댓글수:  4
# 추천수:  0
# ---------------
# 100
# 제목:  '군 복무' 엑소 백현, 유튜브 활동에 쏟아진 비난…SM "영상 삭제"
# 글쓴이:  다비나
# 날짜:  2021.11.18 15:47
# 조회수:  52441
# 댓글수:  231
# 추천수:  25
# ---------------
# 101
# 제목:  '고디바 SHOW' 강운·서혜윤·차유·황인해, 각양각색 이력 공개
# 글쓴이:  태정태세
# 날짜:  2021.11.18 15:46
# 조회수:  700
# 댓글수:  0
# 추천수:  0
# ---------------
# 102
# 제목:  남자친구 납골당에서 남친 친구랑 키스했어
# 글쓴이:  솔의눈아침햇
# 날짜:  2021.11.18 15:44
# 조회수:  4560
# 댓글수:  3
# 추천수:  0
# ---------------
# 103
# 제목:  FDA에서 화이자 관련정보공개를 2076년까지 막아달라고 연방정부에 요청
# 글쓴이:  방구석천재
# 날짜:  2021.11.18 15:42
# 조회수:  11243
# 댓글수:  31
# 추천수:  5
# ---------------
# 104
# 제목:  [단독] 원더걸스 선예, '엄마는 아이돌'로 복귀..세 딸 엄마의 아이돌 ..
# 글쓴이:  지수
# 날짜:  2021.11.18 15:41
# 조회수:  21070
# 댓글수:  50
# 추천수:  12
# ---------------
# 105
# 제목:  수능 1등급을 맞기 위해 수련한 수갤러 썰 ㄷㄷ......JPG
# 글쓴이:  She
# 날짜:  2021.11.18 15:40
# 조회수:  8312
# 댓글수:  5
# 추천수:  0
# ---------------
# 106
# 제목:  스파이더맨 : 노웨이홈 때문에 개빡친 일본인들
# 글쓴이:  언행일치
# 날짜:  2021.11.18 15:35
# 조회수:  39277
# 댓글수:  97
# 추천수:  21
# ---------------
# 107
# 제목:  [신서유기] 손말이고기.gif
# 글쓴이:  양꼬치 떨어져
# 날짜:  2021.11.18 15:32
# 조회수:  1333
# 댓글수:  1
# 추천수:  0
# ---------------
# 108
# 제목:  소련여자의 평정심을 잃게한 무자비한 악플
# 글쓴이:  더보이즈 이주
# 날짜:  2021.11.18 15:19
# 조회수:  9808
# 댓글수:  10
# 추천수:  2
# ---------------
# 109
# 제목:  연락 잘안하는 여친어때요?
# 글쓴이:  세훈이를업어
# 날짜:  2021.11.18 15:17
# 조회수:  5129
# 댓글수:  2
# 추천수:  0
# ---------------
# 110
# 제목:  온라인에서 알게된사람 실제로 만난적 있다vs없다
# 글쓴이:  토끼네
# 날짜:  2021.11.18 15:00
# 조회수:  5414
# 댓글수:  23
# 추천수:  0
# ---------------
# 111
# 제목:  이별 통보한 여친 찌르고 고층 베란다 밖으로 던진 30대 체포
# 글쓴이:  벤츄리
# 날짜:  2021.11.18 14:59
# 조회수:  9760
# 댓글수:  17
# 추천수:  5
# ---------------
# 112
# 제목:  멤버 각각 다 춤선 미쳤다는 남돌
# 글쓴이:  이리저리요리
# 날짜:  2021.11.18 14:55
# 조회수:  1936
# 댓글수:  2
# 추천수:  0
# ---------------
# 113
# 제목:  프란치스코 교황의 연설
# 글쓴이:  디귿
# 날짜:  2021.11.18 14:55
# 조회수:  1375
# 댓글수:  1
# 추천수:  0
# ---------------
# 114
# 제목:  교촌치킨, 제품 가격 평균 8.1% 인상…허니콤보 1만8천원→2만원
# 글쓴이:  지수
# 날짜:  2021.11.18 14:48
# 조회수:  43260
# 댓글수:  132
# 추천수:  10
# ---------------
# 115
# 제목:  베이징 동계올림픽때 남초커뮤를 달굴 피겨선수
# 글쓴이:  동공실종남
# 날짜:  2021.11.18 14:41
# 조회수:  5646
# 댓글수:  3
# 추천수:  0
# ---------------
# 116
# 제목:  어떤 쉽덕 게임 광고 예상.jpg
# 글쓴이:  패딩조끼
# 날짜:  2021.11.18 14:38
# 조회수:  3154
# 댓글수:  5
# 추천수:  1
# ---------------
# 117
# 제목:  [킹스맨:퍼스트에이전트] 레거시 예고편
# 글쓴이:  백챠
# 날짜:  2021.11.18 14:38
# 조회수:  509
# 댓글수:  1
# 추천수:  0
# ---------------
# 118
# 제목:  남자친구 납골당에서 남친 친구랑 키스했어
# 글쓴이:  신짱구,
# 날짜:  2021.11.18 14:34
# 조회수:  5495
# 댓글수:  3
# 추천수:  0
# ---------------
# 119
# 제목:  신문윤리위 최다 제재 언론사는 조선일보
# 글쓴이:  자두야♡♡
# 날짜:  2021.11.18 14:29
# 조회수:  410
# 댓글수:  0
# 추천수:  1
# ---------------
# 120
# 제목:  보고 있으면 후련해지는 사이다짤
# 글쓴이:  Laniakea
# 날짜:  2021.11.18 14:24
# 조회수:  11744
# 댓글수:  31
# 추천수:  1
# ---------------
# 121
# 제목:  "위법 아니지만 오해 방지”…백현, 군복무 중 유튜브 영상 내렸다
# 글쓴이:  지수
# 날짜:  2021.11.18 14:21
# 조회수:  37366
# 댓글수:  85
# 추천수:  5
# ---------------
# 122
# 제목:  싼 옷을 많이 사지말고 비싼 옷 한 벌을 사라고!
# 글쓴이:  누눈나난
# 날짜:  2021.11.18 14:18
# 조회수:  56357
# 댓글수:  118
# 추천수:  28
# ---------------
# 123
# 제목:  칼부림 현장에서 시민 두고 도망간 경찰
# 글쓴이:  영국닭집
# 날짜:  2021.11.18 14:13
# 조회수:  54480
# 댓글수:  134
# 추천수:  26
# ---------------
# 124
# 제목:  김밥에 밥 대신 계란이 들어가면............jpg
# 글쓴이:  녹차말차킬러
# 날짜:  2021.11.18 14:12
# 조회수:  19533
# 댓글수:  34
# 추천수:  2
# ---------------
# 125
# 제목:  세상에서 가장 이상한 동물.jpg
# 글쓴이:  존 스미스
# 날짜:  2021.11.18 14:08
# 조회수:  10741
# 댓글수:  15
# 추천수:  7
# ---------------
# 126
# 제목:  [단독] 김선호, 12월3일 '슬픈열대' 첫 공식일정 참석
# 글쓴이:  지수
# 날짜:  2021.11.18 14:06
# 조회수:  18086
# 댓글수:  36
# 추천수:  20
# ---------------
# 127
# 제목:  수험생 165명, 경찰차 탄 사연? "잘못 들어선 시험장, 수험표·시계 깜빡..
# 글쓴이:  벤츄리
# 날짜:  2021.11.18 13:50
# 조회수:  9005
# 댓글수:  8
# 추천수:  1
# ---------------
# 128
# 제목:  디씨에서 시키는대로해서 인생이 바뀜
# 글쓴이:  ~~
# 날짜:  2021.11.18 13:49
# 조회수:  4487
# 댓글수:  2
# 추천수:  2
# ---------------
# 129
# 제목:  (혐오주의) 공포의 고양이
# 글쓴이:  마유
# 날짜:  2021.11.18 13:48
# 조회수:  12876
# 댓글수:  31
# 추천수:  1
# ---------------
# 130
# 제목:  수녀 코스프레한 조신한 수련수련
# 글쓴이:  토끼네
# 날짜:  2021.11.18 13:44
# 조회수:  4812
# 댓글수:  5
# 추천수:  1
# ---------------
# 131
# 제목:  어린이들에게 존댓말을 하게 된 계기.jpg
# 글쓴이:  더보이즈 영
# 날짜:  2021.11.18 13:44
# 조회수:  12380
# 댓글수:  6
# 추천수:  3
# ---------------
# 132
# 제목:  인생의 쓴맛을 느낀 꼬꼬마
# 글쓴이:  Laniakea
# 날짜:  2021.11.18 13:34
# 조회수:  730
# 댓글수:  0
# 추천수:  0
# ---------------
# 133
# 제목:  지방탄수화물소년단백질 닉값하는 휴가 4일간의 방탄 식단 기록 .jpg
# 글쓴이:  딸기꽃
# 날짜:  2021.11.18 13:27
# 조회수:  10390
# 댓글수:  25
# 추천수:  22
# ---------------
# 134
# 제목:  25년차 가수가 콘서트에서 펑펑 운 이유...jpg
# 글쓴이:  초코치킨
# 날짜:  2021.11.18 13:27
# 조회수:  4034
# 댓글수:  0
# 추천수:  1
# ---------------
# 135
# 제목:  박명수, '음원 부진' 트와이스에 난처한 질문…"멜론에서 몇 위냐"
# 글쓴이:  지수
# 날짜:  2021.11.18 13:25
# 조회수:  65276
# 댓글수:  142
# 추천수:  20
# ---------------
# 136
# 제목:  왠지 설득당하는 냉장고 없이 살자는 예비신랑.jpg
# 글쓴이:  호롤로롤롤
# 날짜:  2021.11.18 13:25
# 조회수:  83793
# 댓글수:  345
# 추천수:  30
# ---------------
# 137
# 제목:  임신한 아내 음식부탁 난이도 레전드.jpg
# 글쓴이:  멍ㅇ멍이 소리
# 날짜:  2021.11.18 13:18
# 조회수:  28816
# 댓글수:  17
# 추천수:  4
# ---------------
# 138
# 제목:  스포? 스파이더맨 노 웨이 홈 편집 오류
# 글쓴이:  박뚱시
# 날짜:  2021.11.18 13:17
# 조회수:  2428
# 댓글수:  1
# 추천수:  0
# ---------------
# 139
# 제목:  김옥빈 전남친 얘기 들은 신동엽의 반응 ㅋㅋㅋ
# 글쓴이:  세훈이를업어
# 날짜:  2021.11.18 13:16
# 조회수:  2807
# 댓글수:  1
# 추천수:  1
# ---------------
# 140
# 제목:  빌런이 된 이유가 이해 됐던 마블 영화 빌런들.jpg
# 글쓴이:  +ordin
# 날짜:  2021.11.18 13:16
# 조회수:  6910
# 댓글수:  5
# 추천수:  0
# ---------------
# 141
# 제목:  배고파요.. 연어초밥좀 주세요.jpg
# 글쓴이:  세븐틴 원 +
# 날짜:  2021.11.18 13:08
# 조회수:  13424
# 댓글수:  29
# 추천수:  3
# ---------------
# 142
# 제목:  원어스, 데뷔 1044일 만에 첫 1위 "꿈 같아..긍정적인 역사 써 내려..
# 글쓴이:  강쥐강아쥐
# 날짜:  2021.11.18 12:51
# 조회수:  7245
# 댓글수:  20
# 추천수:  6
# ---------------
# 143
# 제목:  초콜릿의 불편한 진실.jpg
# 글쓴이:  풀썬이동혁
# 날짜:  2021.11.18 12:39
# 조회수:  10455
# 댓글수:  7
# 추천수:  4
# ---------------
# 144
# 제목:  전효성 인스타 업뎃 .jpg
# 글쓴이:  녹차말차킬러
# 날짜:  2021.11.18 12:37
# 조회수:  4926
# 댓글수:  2
# 추천수:  0
# ---------------
# 145
# 제목:  1년여 만에 갑자기 연락온 중고거래자.jpg
# 글쓴이:  ㄷH학수학능력
# 날짜:  2021.11.18 12:33
# 조회수:  12544
# 댓글수:  7
# 추천수:  2
# ---------------
# 146
# 제목:  '나 혼자 산다' 새 포스터, 헨리만 쏙 빠졌다? '갑론을박'
# 글쓴이:  지수
# 날짜:  2021.11.18 12:28
# 조회수:  76539
# 댓글수:  164
# 추천수:  16
# ---------------
# 147
# 제목:  두뇌 싸움하는 프로에서 처음 보는 유형의 전략
# 글쓴이:  .서로가 서로
# 날짜:  2021.11.18 12:22
# 조회수:  3279
# 댓글수:  1
# 추천수:  2
# ---------------
# 148
# 제목:  '새벽 행군' 군장병 5명 '음주 운전' 화물차에 치여
# 글쓴이:  일루전 커넥
# 날짜:  2021.11.18 12:20
# 조회수:  18788
# 댓글수:  32
# 추천수:  4
# ---------------
# 149
# 제목:  레트로 느낌 뿜뿜하는 하하하 굿즈
# 글쓴이:  뿌두구
# 날짜:  2021.11.18 12:18
# 조회수:  14201
# 댓글수:  20
# 추천수:  8
# ---------------
# 150
# 제목:  [Teaser] When Traditional Korean music me..
# 글쓴이:  몽몽댕
# 날짜:  2021.11.18 12:14
# 조회수:  16
# 댓글수:  0
# 추천수:  0
# ---------------
# 151
# 제목:  플로(FLO), 마마무 소속사 RBW와 공연 파트너십 계약 체결
# 글쓴이:  이리저리요리
# 날짜:  2021.11.18 12:10
# 조회수:  570
# 댓글수:  0
# 추천수:  0
# ---------------
# 152
# 제목:  이시영, 1억원 기부…"가정폭력으로 아픈 아이들 위해 결정"
# 글쓴이:  디귿
# 날짜:  2021.11.18 12:09
# 조회수:  856
# 댓글수:  3
# 추천수:  0
# ---------------
# 153
# 제목:  드라마 남녀주연배우들이 쉬는시간에 하는 짓......
# 글쓴이:  멍ㅇ멍이 소리
# 날짜:  2021.11.18 12:06
# 조회수:  34445
# 댓글수:  40
# 추천수:  20
# ---------------
# 154
# 제목:  꽃보다 남자 OST중에서 내가 좋아했던 곡은?
# 글쓴이:  널 사랑해 영
# 날짜:  2021.11.18 12:06
# 조회수:  828
# 댓글수:  4
# 추천수:  0
# ---------------
# 155
# 제목:  오디션 심사위원으로 1분 30초 무대 찢은 아이들 전소연
# 글쓴이:  닐라닐라
# 날짜:  2021.11.18 11:58
# 조회수:  2510
# 댓글수:  0
# 추천수:  0
# ---------------
# 156
# 제목:  BTS '아미' VS 임영웅 '영웅시대' MMA2021 톱10 1위 자리 ..
# 글쓴이:  김영란
# 날짜:  2021.11.18 11:51
# 조회수:  4912
# 댓글수:  3
# 추천수:  2
# ---------------
# 157
# 제목:  캐릭터 찰떡이라는 술꾼도시여자들 한선화
# 글쓴이:  스트로베리문
# 날짜:  2021.11.18 11:40
# 조회수:  6180
# 댓글수:  5
# 추천수:  1
# ---------------
# 158
# 제목:  남친이 "개 부자" 라서 넘 좋다는 여자.jpg
# 글쓴이:  미니온즈
# 날짜:  2021.11.18 11:28
# 조회수:  80345
# 댓글수:  107
# 추천수:  12
# ---------------
# 159
# 제목:  좋은 남친의 기준을 인터넷 여론으로 잡으면 안되는 이유
# 글쓴이:  He
# 날짜:  2021.11.18 11:27
# 조회수:  5760
# 댓글수:  2
# 추천수:  1
# ---------------
# 160
# 제목:  마늘 많이 먹으면 항암효과에 좋아요
# 글쓴이:  옹성우박우진
# 날짜:  2021.11.18 11:22
# 조회수:  3739
# 댓글수:  1
# 추천수:  0
# ---------------
# 161
# 제목:  찰떡아이스 신상 .JPG
# 글쓴이:  세정언니링
# 날짜:  2021.11.18 11:22
# 조회수:  15516
# 댓글수:  15
# 추천수:  9
# ---------------
# 162
# 제목:  이투스 강사진 아바타.jpg
# 글쓴이:  계같네
# 날짜:  2021.11.18 11:18
# 조회수:  2421
# 댓글수:  0
# 추천수:  6
# ---------------
# 163
# 제목:  GLG 첫 걸그룹 하이키, 내년 1월5일 뜬다 [공식]
# 글쓴이:  슈슈슈슈슈슈
# 날짜:  2021.11.18 11:02
# 조회수:  1293
# 댓글수:  0
# 추천수:  3
# ---------------
# 164
# 제목:  월급이 더 들어와서 문자를 보냈더니 .jpg
# 글쓴이:  하니형
# 날짜:  2021.11.18 10:58
# 조회수:  28819
# 댓글수:  21
# 추천수:  17
# ---------------
# 165
# 제목:  브랜드별 끝판왕 차종
# 글쓴이:  Tony Stark
# 날짜:  2021.11.18 10:56
# 조회수:  2581
# 댓글수:  1
# 추천수:  0
# ---------------
# 166
# 제목:  햄버거 세트 사서 콜라만 마시는 이유
# 글쓴이:  어니부깅
# 날짜:  2021.11.18 10:55
# 조회수:  74749
# 댓글수:  115
# 추천수:  7
# ---------------
# 167
# 제목:  잘 대줄것 같은 여자로 보이는게 고민인 여자
# 글쓴이:  박뚱시
# 날짜:  2021.11.18 10:37
# 조회수:  27878
# 댓글수:  53
# 추천수:  3
# ---------------
# 168
# 제목:  개승자 정성호 오징어게임 허성태
# 글쓴이:  바보같은그대
# 날짜:  2021.11.18 10:16
# 조회수:  2100
# 댓글수:  0
# 추천수:  0
# ---------------
# 169
# 제목:  스포) 스파이더맨 심령사진 유출
# 글쓴이:  용시대박
# 날짜:  2021.11.18 10:11
# 조회수:  4405
# 댓글수:  1
# 추천수:  1
# ---------------
# 170
# 제목:  발뮤다 스마트폰 실사.jpg
# 글쓴이:  JOSHUA95
# 날짜:  2021.11.18 10:11
# 조회수:  5133
# 댓글수:  2
# 추천수:  1
# ---------------
# 171
# 제목:  넷플릭스, 첫 가격인상…프리미엄 1만4500원→1만7000원
# 글쓴이:  누눈나난
# 날짜:  2021.11.18 10:00
# 조회수:  16527
# 댓글수:  41
# 추천수:  5
# ---------------
# 172
# 제목:  유독 호불호가 심하게 갈린다는 케이크.jpg
# 글쓴이:  녹차말차킬러
# 날짜:  2021.11.18 09:59
# 조회수:  17642
# 댓글수:  21
# 추천수:  1
# ---------------
# 173
# 제목:  펭수 머리에 초를 꽂기 싫었던 엄마.jpgif
# 글쓴이:  Twenty_Four
# 날짜:  2021.11.18 09:59
# 조회수:  57350
# 댓글수:  94
# 추천수:  20
# ---------------
# 174
# 제목:  뉴욕 타임스퀘어 전광판에 걸린 스테이씨.jpg
# 글쓴이:  녹차말차킬러
# 날짜:  2021.11.18 09:57
# 조회수:  2835
# 댓글수:  2
# 추천수:  0
# ---------------
# 175
# 제목:  서윗한 달팽이주인
# 글쓴이:  qksxks ghtjr
# 날짜:  2021.11.18 09:52
# 조회수:  3707
# 댓글수:  1
# 추천수:  0
# ---------------
# 176
# 제목:  은근히 이뻤던 박봄 리즈시절 ㄷㄷ
# 글쓴이:  겟
# 날짜:  2021.11.18 09:45
# 조회수:  18751
# 댓글수:  16
# 추천수:  4
# ---------------
# 177
# 제목:  좀 너무 길지않냐는 반응의 드라마 교통사고 장면.gif
# 글쓴이:  NUEST-W
# 날짜:  2021.11.18 09:44
# 조회수:  34485
# 댓글수:  35
# 추천수:  7
# ---------------
# 178
# 제목:  귤 먹고 싶으니까 까달라는 딸.gif
# 글쓴이:  우물밖 여고
# 날짜:  2021.11.18 09:44
# 조회수:  15138
# 댓글수:  14
# 추천수:  4
# ---------------
# 179
# 제목:  현재 본인의 컴퓨터 본체 위치는?
# 글쓴이:  ㄷH학수학능력
# 날짜:  2021.11.18 09:41
# 조회수:  4966
# 댓글수:  15
# 추천수:  0
# ---------------
# 180
# 제목:  [스파이더맨예고편] 투명인간에게 쳐맞는 리자드.gi
# 글쓴이:  색지
# 날짜:  2021.11.18 09:38
# 조회수:  963
# 댓글수:  1
# 추천수:  0
# ---------------
# 181
# 제목:  대학교 4학년 시험을 친 2학년의 최후.jpg
# 글쓴이:  벤츄리
# 날짜:  2021.11.18 09:30
# 조회수:  66543
# 댓글수:  203
# 추천수:  34
# ---------------
# 182
# 제목:  백의천사 서울대 병원 7년차 미모의 간호사..또 다른 반전 직업 ㄷㄷㄷ
# 글쓴이:  다시 태어날
# 날짜:  2021.11.18 09:26
# 조회수:  34759
# 댓글수:  30
# 추천수:  10
# ---------------
# 183
# 제목:  수능 하루 앞두고 계시를 받은 디씨인
# 글쓴이:  더보이즈 영
# 날짜:  2021.11.18 09:00
# 조회수:  8859
# 댓글수:  6
# 추천수:  0
# ---------------
# 184
# 제목:  역대급으로 ㅈ망인 2021년 고티(Game Of The Year) 라인업
# 글쓴이:  next
# 날짜:  2021.11.18 09:00
# 조회수:  2414
# 댓글수:  2
# 추천수:  0
# ---------------
# 185
# 제목:  MCU 스파이더맨 연출의 문제점
# 글쓴이:  보이프렌드 민
# 날짜:  2021.11.18 08:58
# 조회수:  3595
# 댓글수:  1
# 추천수:  0
# ---------------
# 186
# 제목:  동거인 흉기로 찌르고 아파트 아래로 떨어뜨려 살해..30대 체포
# 글쓴이:  슈비룹
# 날짜:  2021.11.18 08:57
# 조회수:  5223
# 댓글수:  5
# 추천수:  3
# ---------------
# 187
# 제목:  지난 4월말 ㅍ.ㅋ에 올라온 여친 강간글 결말.jpg
# 글쓴이:  자두야♡♡
# 날짜:  2021.11.18 08:48
# 조회수:  9853
# 댓글수:  5
# 추천수:  4
# ---------------
# 188
# 제목:  넷플릭스 역대 인기 순위.jpg
# 글쓴이:  알케이
# 날짜:  2021.11.18 08:41
# 조회수:  24977
# 댓글수:  40
# 추천수:  21
# ---------------
# 189
# 제목:  내향적인 사람이 마트 갔을 때.jpeg
# 글쓴이:  311342_return
# 날짜:  2021.11.18 08:36
# 조회수:  37161
# 댓글수:  41
# 추천수:  19
# ---------------
# 190
# 제목:  불고기피자 5행시 대상작.JPG
# 글쓴이:  시어머니블루
# 날짜:  2021.11.18 08:34
# 조회수:  8746
# 댓글수:  7
# 추천수:  6

# %%
df=pd.DataFrame(result)
df
# Out:
#                                           제목            글쓴이                날짜  \
# 0                     김종국 데뷔 26년만에 악플고소 선처없다          내기분냥냥  2021.11.18 20:32
# 1                       남녀 키스후 반응 차이 ㅋㅋㅋㅋㅋㅋㅋ           던던둔둔  2021.11.18 20:31
# 2    AZ, 모더나 접종 중단한답니다.. 그런데 맞은사람은 어떻게 되는거죠?          해르반창식  2021.11.18 20:28
# 3                       법잘알이 미성년자 사기꾼 상대하는 법  311344_return  2021.11.18 20:27
# 4                                 자취생에게 가습기란       S.COUPS.  2021.11.18 20:26
# ..                                       ...            ...               ...
# 185      동거인 흉기로 찌르고 아파트 아래로 떨어뜨려 살해..30대 체포            슈비룹  2021.11.18 08:57
# 186            지난 4월말 ㅍ.ㅋ에 올라온 여친 강간글 결말.jpg          자두야♡♡  2021.11.18 08:48
# 187                        넷플릭스 역대 인기 순위.jpg            알케이  2021.11.18 08:41
# 188                    내향적인 사람이 마트 갔을 때.jpeg  311342_return  2021.11.18 08:36
# 189                        불고기피자 5행시 대상작.JPG         시어머니블루  2021.11.18 08:34
#
#        조회수 댓글수 추천수
# 0      336   0   0
# 1      823   0   0
# 2     1807   0   0
# 3      795   0   0
# 4     1072   0   0
# ..     ...  ..  ..
# 185   5223   5   3
# 186   9853   5   4
# 187  24977  40  21
# 188  37161  41  19
# 189   8746   7   6
#
# [190 rows x 6 columns]

# %%
df.to_excel('data/instiz_인티포털_수능2.xlsx')

# %%
#익명잡담
base_url2='https://www.instiz.net/name?page=1&category=1'
#headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.54 Safari/537.36"}
cnt=1
result2=[]
for i in range(1,11):
    params={"page":i}
    raw=req.get(base_url2,params=params)
    soup=bs(raw.content, 'html.parser')
    contents2 = soup.find_all('tr')
    del contents2[:20]
    del contents2[19:len(contents2)]
    
    for i in contents2:
        tmp={}
        print('-'*15)
        print(cnt)
        cnt=cnt+1


        # 제목 추출
        title=i.find('span',{"id":"subject"}).text.strip()
        print("제목: ", title)



        # 글쓴이 추출
        writer_tag = i.find('td', {"class":"minitext2 listnm"})
        if writer_tag is not None: # None 값이 있으므로 조건문을 통해 회피 
            writer = writer_tag.text

        else:
            writer = "없음"
        print("글쓴이: ", writer)

    #     # 유동이나 고닉이 아닌 글쓴이 옆에 있는 ip 추출
    #     ip_tag = i.find('td', class_='gall_writer ub-writer').find('span', class_='ip')
    #     if ip_tag is not None:  # None 값이 있으므로 조건문을 통해 회피 
    #         ip = ip_tag.text
    #         print("ip: ", ip)



        # 날짜 추출 
        date=i.find('td',{"class":"listno regdate"}).text
        if len(date)<=5:
            if len(date)<=4:
                date=d.strftime('%Y.%m.%d ')+'0'+date
            else:
                date=d.strftime('%Y.%m.%d ')+date
        else:
            date=d.strftime('%Y')+'.'+date[:5]
        print("날짜: ",date)


        # 조회 수 추출
        views = i.find_all('td', {"class":"listno"})[2].text
        print("조회수: ", views)


        # 댓글 수
        comment=i.find('a',{"id":"view_cmt"})
        if comment==None:
            comment=0
        else:
            comment=comment.text
        print("댓글수: ", comment)

        # 추천 수 추출
        recommend = i.find_all('td', {"class":"listno"})[3].text
        print("추천수: ", recommend)


        tmp['제목']=title
        tmp['글쓴이']=writer
        tmp['날짜']=date
        tmp['조회수']=views
        tmp['댓글수']=comment
        tmp['추천수']=recommend

        result2.append(tmp)
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# ---------------
# 1
# 제목:  남자 키 170이면 작은거야 보통인거야?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:50
# 조회수:  1
# 댓글수:  0
# 추천수:  0
# ---------------
# 2
# 제목:  졸업작품 선물로 조말론 핸드워시랑 핸드크림 사서 주면 별로야???
# 글쓴이:  없음
# 날짜:  2021.11.18 20:50
# 조회수:  1
# 댓글수:  0
# 추천수:  0
# ---------------
# 3
# 제목:  간호 교직이수 몇학년때 성적 봐?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:50
# 조회수:  1
# 댓글수:  0
# 추천수:  0
# ---------------
# 4
# 제목:  과탐 역대급 점수 받음
# 글쓴이:  없음
# 날짜:  2021.11.18 20:50
# 조회수:  1
# 댓글수:  0
# 추천수:  0
# ---------------
# 5
# 제목:  무선 충전 무쳣다....
# 글쓴이:  없음
# 날짜:  2021.11.18 20:50
# 조회수:  1
# 댓글수:  0
# 추천수:  0
# ---------------
# 6
# 제목:  솔직히 이젠 롱패딩 유행템 아니지 않어??
# 글쓴이:  없음
# 날짜:  2021.11.18 20:50
# 조회수:  1
# 댓글수:  0
# 추천수:  0
# ---------------
# 7
# 제목:  아이씨 갑질 사건 자꾸 생각나네
# 글쓴이:  없음
# 날짜:  2021.11.18 20:50
# 조회수:  1
# 댓글수:  0
# 추천수:  0
# ---------------
# 8
# 제목:  아 길고양이 발정긴가 시끄러 죽겠네
# 글쓴이:  없음
# 날짜:  2021.11.18 20:50
# 조회수:  1
# 댓글수:  0
# 추천수:  0
# ---------------
# 9
# 제목:  이거 후드웜업 무슨색 살까 골라줘!!!!!! (2년만에 첫 외투 쇼핑이라 아주 신남요
# 글쓴이:  없음
# 날짜:  2021.11.18 20:50
# 조회수:  1
# 댓글수:  0
# 추천수:  0
# ---------------
# 10
# 제목:  알바 6개월 이상 한다하고 5개월만 해도돼?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:50
# 조회수:  1
# 댓글수:  0
# 추천수:  0
# ---------------
# 11
# 제목:  공부안한 생윤이랑
# 글쓴이:  없음
# 날짜:  2021.11.18 20:50
# 조회수:  1
# 댓글수:  0
# 추천수:  0
# ---------------
# 12
# 제목:  ㅋㅋ...수능 끝났으니까 헤어지재
# 글쓴이:  없음
# 날짜:  2021.11.18 20:50
# 조회수:  2
# 댓글수:  0
# 추천수:  0
# ---------------
# 13
# 제목:  엥..자살하고싶다..수험생 아님
# 글쓴이:  없음
# 날짜:  2021.11.18 20:50
# 조회수:  2
# 댓글수:  0
# 추천수:  0
# ---------------
# 14
# 제목:  스킨로션 어디꺼써?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:50
# 조회수:  3
# 댓글수:  0
# 추천수:  0
# ---------------
# 15
# 제목:  애인한테 맞았어 어떻게 하면 좋지
# 글쓴이:  없음
# 날짜:  2021.11.18 20:50
# 조회수:  4
# 댓글수:  0
# 추천수:  0
# ---------------
# 16
# 제목:  오늘 선바 썸네일 필승이다
# 글쓴이:  없음
# 날짜:  2021.11.18 20:50
# 조회수:  4
# 댓글수:  0
# 추천수:  0
# ---------------
# 17
# 제목:  다들 겨울코트 어디서 사니 ...
# 글쓴이:  없음
# 날짜:  2021.11.18 20:50
# 조회수:  4
# 댓글수:  0
# 추천수:  0
# ---------------
# 18
# 제목:  내일 시골가면 100% 수능,대학 얘기 하겠지?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:49
# 조회수:  6
# 댓글수:  0
# 추천수:  0
# ---------------
# 19
# 제목:  40 후기 하나도 없는 코트삼
# 글쓴이:  없음
# 날짜:  2021.11.18 20:49
# 조회수:  7
# 댓글수:  0
# 추천수:  0
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# ---------------
# 20
# 제목:  이과 12122면 어디 정도 갈수있음?? 보통
# 글쓴이:  없음
# 날짜:  2021.11.18 20:49
# 조회수:  9
# 댓글수:  0
# 추천수:  0
# ---------------
# 21
# 제목:  마블에서 왜 인기있는지 이해안가는 캐릭터
# 글쓴이:  없음
# 날짜:  2021.11.18 20:49
# 조회수:  8
# 댓글수:  0
# 추천수:  0
# ---------------
# 22
# 제목:  에어팟 쿠팡에서 사면 다 짭이야??
# 글쓴이:  없음
# 날짜:  2021.11.18 20:49
# 조회수:  6
# 댓글수:  0
# 추천수:  0
# ---------------
# 23
# 제목:  노력 안했으면 점수 안나오는게 당연한건데 왤케 죽고싶지
# 글쓴이:  없음
# 날짜:  2021.11.18 20:49
# 조회수:  7
# 댓글수:  1
# 추천수:  0
# ---------------
# 24
# 제목:  수능 망쳤는데 잘되는 경우는 뭐가있을까??
# 글쓴이:  없음
# 날짜:  2021.11.18 20:49
# 조회수:  16
# 댓글수:  1
# 추천수:  0
# ---------------
# 25
# 제목:  퍼자켓 or 퍼코트 있는 익들!!!!! 궁금한거있어!!!
# 글쓴이:  없음
# 날짜:  2021.11.18 20:49
# 조회수:  6
# 댓글수:  0
# 추천수:  0
# ---------------
# 26
# 제목:  치킨 뭐먹지
# 글쓴이:  없음
# 날짜:  2021.11.18 20:49
# 조회수:  4
# 댓글수:  0
# 추천수:  0
# ---------------
# 27
# 제목:  국어 2컷 제발 올라가지마라제발
# 글쓴이:  없음
# 날짜:  2021.11.18 20:49
# 조회수:  6
# 댓글수:  0
# 추천수:  0
# ---------------
# 28
# 제목:  영어 듣기에서 틀리는 빡머가뤼가 있다아?!??!?!?#
# 글쓴이:  없음
# 날짜:  2021.11.18 20:49
# 조회수:  10
# 댓글수:  0
# 추천수:  0
# ---------------
# 29
# 제목:  지방전문대간호에서 지거국 간호로 반수하는거
# 글쓴이:  없음
# 날짜:  2021.11.18 20:49
# 조회수:  13
# 댓글수:  2
# 추천수:  0
# ---------------
# 30
# 제목:  나 사문 도표 다 맞았는데
# 글쓴이:  없음
# 날짜:  2021.11.18 20:49
# 조회수:  8
# 댓글수:  0
# 추천수:  0
# ---------------
# 31
# 제목:  우리 사장님 짜증난다ㅋㅋㅋㅋㅋ
# 글쓴이:  없음
# 날짜:  2021.11.18 20:49
# 조회수:  5
# 댓글수:  0
# 추천수:  0
# ---------------
# 32
# 제목:  주변에 최저 다 맞춰놓고 논술 6광탈한 사람들 많니..?ㅠㅠ
# 글쓴이:  없음
# 날짜:  2021.11.18 20:49
# 조회수:  13
# 댓글수:  0
# 추천수:  0
# ---------------
# 33
# 제목:  과거의 독재생이 우울해 하고있을 수험생에게 적는 뻘글
# 글쓴이:  없음
# 날짜:  2021.11.18 20:49
# 조회수:  19
# 댓글수:  0
# 추천수:  0
# ---------------
# 34
# 제목:  동사세사 둘다 만점뜸
# 글쓴이:  없음
# 날짜:  2021.11.18 20:49
# 조회수:  12
# 댓글수:  2
# 추천수:  0
# ---------------
# 35
# 제목:  수능 채점 다 햇는데 이 점수면 어디 학교까지 가능할까?????
# 글쓴이:  없음
# 날짜:  2021.11.18 20:49
# 조회수:  18
# 댓글수:  1
# 추천수:  0
# ---------------
# 36
# 제목:  짝사랑하면 사람이 왤케 추하고 한심해짐?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:49
# 조회수:  10
# 댓글수:  0
# 추천수:  0
# ---------------
# 37
# 제목:  나 요즘에 하는 일마다 다 망해서 무기력한데
# 글쓴이:  없음
# 날짜:  2021.11.18 20:49
# 조회수:  4
# 댓글수:  0
# 추천수:  0
# ---------------
# 38
# 제목:  클리오 아이새도우 가루날림 없어? 쓰기괜차찮아?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:49
# 조회수:  4
# 댓글수:  0
# 추천수:  0
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# ---------------
# 39
# 제목:  이번에 입시 개망한 재수생 어떡해
# 글쓴이:  없음
# 날짜:  2021.11.18 20:49
# 조회수:  19
# 댓글수:  1
# 추천수:  0
# ---------------
# 40
# 제목:  애들아! 나 수능 잘 봤어!
# 글쓴이:  없음
# 날짜:  2021.11.18 20:49
# 조회수:  38
# 댓글수:  0
# 추천수:  0
# ---------------
# 41
# 제목:  숏패딩이 따듯할까? 뽀글이가 따뜻할까?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:49
# 조회수:  12
# 댓글수:  1
# 추천수:  0
# ---------------
# 42
# 제목:  윤사 어려웠어??
# 글쓴이:  없음
# 날짜:  2021.11.18 20:48
# 조회수:  10
# 댓글수:  0
# 추천수:  0
# ---------------
# 43
# 제목:  야 15111 실화니???
# 글쓴이:  없음
# 날짜:  2021.11.18 20:48
# 조회수:  61
# 댓글수:  1
# 추천수:  0
# ---------------
# 44
# 제목:  세지 개망했어 난이도 무슨일
# 글쓴이:  없음
# 날짜:  2021.11.18 20:48
# 조회수:  17
# 댓글수:  2
# 추천수:  0
# ---------------
# 45
# 제목:  이번에 망친 삼수생은 어떡하냐 ㄹㅇ
# 글쓴이:  없음
# 날짜:  2021.11.18 20:48
# 조회수:  53
# 댓글수:  3
# 추천수:  0
# ---------------
# 46
# 제목:  예비합격했으면
# 글쓴이:  없음
# 날짜:  2021.11.18 20:48
# 조회수:  4
# 댓글수:  0
# 추천수:  0
# ---------------
# 47
# 제목:  동사 2등급 컷 몇점일까???
# 글쓴이:  없음
# 날짜:  2021.11.18 20:48
# 조회수:  4
# 댓글수:  0
# 추천수:  0
# ---------------
# 48
# 제목:  화학 본 사람
# 글쓴이:  없음
# 날짜:  2021.11.18 20:48
# 조회수:  15
# 댓글수:  2
# 추천수:  0
# ---------------
# 49
# 제목:  반수했는데 1년 해서 얻은 교훈 단 하나 뿐임
# 글쓴이:  없음
# 날짜:  2021.11.18 20:48
# 조회수:  20
# 댓글수:  0
# 추천수:  0
# ---------------
# 50
# 제목:  키워드 알림처럼 키워드 차단 기능도 있으면 좋겠다
# 글쓴이:  없음
# 날짜:  2021.11.18 20:48
# 조회수:  5
# 댓글수:  0
# 추천수:  0
# ---------------
# 51
# 제목:  최근에 우울했는데 엄마,아빠랑 싸웠어...
# 글쓴이:  없음
# 날짜:  2021.11.18 20:48
# 조회수:  7
# 댓글수:  0
# 추천수:  0
# ---------------
# 52
# 제목:  국어 2컷 더 올라가겠지ㅠ
# 글쓴이:  없음
# 날짜:  2021.11.18 20:48
# 조회수:  20
# 댓글수:  1
# 추천수:  0
# ---------------
# 53
# 제목:  지구 왜? 다들 어디서 틀린거야
# 글쓴이:  없음
# 날짜:  2021.11.18 20:48
# 조회수:  18
# 댓글수:  4
# 추천수:  0
# ---------------
# 54
# 제목:  이거 프사하는거 오바야?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:48
# 조회수:  36
# 댓글수:  5
# 추천수:  0
# ---------------
# 55
# 제목:  진짜 성비는 반반이 제일 좋고 문제 안일어남..
# 글쓴이:  없음
# 날짜:  2021.11.18 20:48
# 조회수:  6
# 댓글수:  1
# 추천수:  0
# ---------------
# 56
# 제목:  재종 종합반 반수반 독재 다 다녀봤는데 궁물받음
# 글쓴이:  없음
# 날짜:  2021.11.18 20:48
# 조회수:  18
# 댓글수:  6
# 추천수:  0
# ---------------
# 57
# 제목:  04년생 사촌동생이 자퇴하고 싶어하는데
# 글쓴이:  없음
# 날짜:  2021.11.18 20:48
# 조회수:  15
# 댓글수:  7
# 추천수:  0
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# ---------------
# 58
# 제목:  회사면접 자꾸 떨어지는데 계약직이라도 들어가야되나
# 글쓴이:  없음
# 날짜:  2021.11.18 20:48
# 조회수:  6
# 댓글수:  0
# 추천수:  0
# ---------------
# 59
# 제목:  내년에 정시 확대되면 n수생 신입생 많아질까?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:48
# 조회수:  16
# 댓글수:  1
# 추천수:  0
# ---------------
# 60
# 제목:  와 수능 대박남 서성한중에 골라주라 ㅋㅋㅋㅋ
# 글쓴이:  없음
# 날짜:  2021.11.18 20:48
# 조회수:  56
# 댓글수:  3
# 추천수:  0
# ---------------
# 61
# 제목:  팀플 조원들한테 이렇게 말해도 되나?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:48
# 조회수:  7
# 댓글수:  0
# 추천수:  0
# ---------------
# 62
# 제목:  다들 건강관리잘해…
# 글쓴이:  없음
# 날짜:  2021.11.18 20:48
# 조회수:  6
# 댓글수:  0
# 추천수:  0
# ---------------
# 63
# 제목:  겨울에 감기 잘 걸리고 몸에 한기 돌때 많은 익들
# 글쓴이:  없음
# 날짜:  2021.11.18 20:47
# 조회수:  6
# 댓글수:  1
# 추천수:  0
# ---------------
# 64
# 제목:  04인데 좀 걱정된다
# 글쓴이:  없음
# 날짜:  2021.11.18 20:47
# 조회수:  11
# 댓글수:  1
# 추천수:  0
# ---------------
# 65
# 제목:  ❤️❤️수능끝난고삼오늘하루끝내주게마무리할거추천좀❤️❤️
# 글쓴이:  없음
# 날짜:  2021.11.18 20:47
# 조회수:  10
# 댓글수:  0
# 추천수:  0
# ---------------
# 66
# 제목:  20대초중반에
# 글쓴이:  없음
# 날짜:  2021.11.18 20:47
# 조회수:  8
# 댓글수:  2
# 추천수:  0
# ---------------
# 67
# 제목:  고구마 피자 맛있는 곳 추천해죠!!!!
# 글쓴이:  없음
# 날짜:  2021.11.18 20:47
# 조회수:  6
# 댓글수:  2
# 추천수:  0
# ---------------
# 68
# 제목:  사회복지 전공인 사람...
# 글쓴이:  없음
# 날짜:  2021.11.18 20:47
# 조회수:  5
# 댓글수:  7
# 추천수:  0
# ---------------
# 69
# 제목:  반려동물들 무지개다리 건널때 구석가서 죽는거 있잖아
# 글쓴이:  없음
# 날짜:  2021.11.18 20:47
# 조회수:  16
# 댓글수:  1
# 추천수:  0
# ---------------
# 70
# 제목:  재수 투지폰 사는건 괜찮지?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:47
# 조회수:  10
# 댓글수:  0
# 추천수:  0
# ---------------
# 71
# 제목:  모더나 2차까지 접종 완료한 익인들
# 글쓴이:  없음
# 날짜:  2021.11.18 20:47
# 조회수:  15
# 댓글수:  0
# 추천수:  0
# ---------------
# 72
# 제목:  아 얘들아 생윤 41점이면 몇 등급 나올 거 같냐…
# 글쓴이:  없음
# 날짜:  2021.11.18 20:47
# 조회수:  31
# 댓글수:  4
# 추천수:  0
# ---------------
# 73
# 제목:  3년만에 폰바꾸는데 아이폰13미니 vs 갤럭시z플립3
# 글쓴이:  없음
# 날짜:  2021.11.18 20:47
# 조회수:  7
# 댓글수:  0
# 추천수:  0
# ---------------
# 74
# 제목:  와 세상에서 제일 맛있는 데운피자 먹었다
# 글쓴이:  없음
# 날짜:  2021.11.18 20:47
# 조회수:  7
# 댓글수:  2
# 추천수:  0
# ---------------
# 75
# 제목:  한지 14점이면 6등급이야 7등급이야
# 글쓴이:  없음
# 날짜:  2021.11.18 20:47
# 조회수:  12
# 댓글수:  0
# 추천수:  0
# ---------------
# 76
# 제목:  고3인데 너무 슬퍼 진짜로
# 글쓴이:  없음
# 날짜:  2021.11.18 20:47
# 조회수:  33
# 댓글수:  1
# 추천수:  0
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# ---------------
# 77
# 제목:  고3인데 너무 슬퍼 진짜로
# 글쓴이:  없음
# 날짜:  2021.11.18 20:47
# 조회수:  33
# 댓글수:  1
# 추천수:  0
# ---------------
# 78
# 제목:  촉인인데 교환할 사람 있엉?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:47
# 조회수:  6
# 댓글수:  0
# 추천수:  0
# ---------------
# 79
# 제목:  33323에서 55354 실화냐
# 글쓴이:  없음
# 날짜:  2021.11.18 20:47
# 조회수:  19
# 댓글수:  0
# 추천수:  0
# ---------------
# 80
# 제목:  나 약간 여캠 비제이상(?) 이 예뻐보여서 부러워…
# 글쓴이:  없음
# 날짜:  2021.11.18 20:47
# 조회수:  17
# 댓글수:  0
# 추천수:  0
# ---------------
# 81
# 제목:  근데 수능 진짜 다 보면 개허무하지 않아?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:47
# 조회수:  23
# 댓글수:  5
# 추천수:  0
# ---------------
# 82
# 제목:  반수가 진짜 좋다
# 글쓴이:  없음
# 날짜:  2021.11.18 20:47
# 조회수:  27
# 댓글수:  0
# 추천수:  0
# ---------------
# 83
# 제목:  왜 수능이 다가 아니라하는거야?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:47
# 조회수:  26
# 댓글수:  5
# 추천수:  0
# ---------------
# 84
# 제목:  윤사 본 사람
# 글쓴이:  없음
# 날짜:  2021.11.18 20:47
# 조회수:  5
# 댓글수:  0
# 추천수:  0
# ---------------
# 85
# 제목:  그래서 지구는 잘못뜬거맞지??
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  26
# 댓글수:  2
# 추천수:  0
# ---------------
# 86
# 제목:  지1 채점한 사람? 어때?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  34
# 댓글수:  11
# 추천수:  0
# ---------------
# 87
# 제목:  그냥 아무 대학이나 가
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  21
# 댓글수:  0
# 추천수:  0
# ---------------
# 88
# 제목:  옷을 샀는데 너무 만족감이 큰데
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  7
# 댓글수:  4
# 추천수:  0
# ---------------
# 89
# 제목:  이과 21243 어디감???ㅌㅋㅋ
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  13
# 댓글수:  1
# 추천수:  0
# ---------------
# 90
# 제목:  국어 39점 수학25점 영어37점 맞음
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  24
# 댓글수:  0
# 추천수:  0
# ---------------
# 91
# 제목:  이번 수능 한국사 어땠어?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  20
# 댓글수:  5
# 추천수:  0
# ---------------
# 92
# 제목:  아니...엔제리너스는 디저트며 빵이며 하나같이 다 개큼
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  9
# 댓글수:  2
# 추천수:  0
# ---------------
# 93
# 제목:  원래 모고 푸는 동안에 엄청 배고팠는데
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  5
# 댓글수:  0
# 추천수:  0
# ---------------
# 94
# 제목:  네이버플러스 가족 쓰는사람들
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  6
# 댓글수:  0
# 추천수:  0
# ---------------
# 95
# 제목:  짜잔 이거봐라
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  8
# 댓글수:  0
# 추천수:  0
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# ---------------
# 96
# 제목:  짜잔 이거봐라
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  8
# 댓글수:  0
# 추천수:  0
# ---------------
# 97
# 제목:  난 뭘 해도 과탐이 극복이 안 됨
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  12
# 댓글수:  0
# 추천수:  0
# ---------------
# 98
# 제목:  생명 33…… 10일의 전사 참패했다
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  24
# 댓글수:  1
# 추천수:  0
# ---------------
# 99
# 제목:  고삼 동생 바로 논술 돌리는거 에바?ㅋㅋ
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  36
# 댓글수:  7
# 추천수:  0
# ---------------
# 100
# 제목:  재수생 내일 정신과가야되는데 너무귀찮다
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  8
# 댓글수:  0
# 추천수:  0
# ---------------
# 101
# 제목:  뭐야 나 생명 다맞고 지구 반타작남
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  17
# 댓글수:  2
# 추천수:  0
# ---------------
# 102
# 제목:  entp들 좋아하는 사람한테 11 뚝딱 vs 22 불도저
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  18
# 댓글수:  2
# 추천수:  0
# ---------------
# 103
# 제목:  얼굴형은 이쁜데 입 좀 옹졸하고 코 평범이면 마기꾼까진 아니지...?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  13
# 댓글수:  2
# 추천수:  0
# ---------------
# 104
# 제목:  보조제를 먹은 이후로 난 똥쟁이가 돼었다,,
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  4
# 댓글수:  0
# 추천수:  0
# ---------------
# 105
# 제목:  22살인데 취업한 친구들 너무 부럽다
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  13
# 댓글수:  0
# 추천수:  0
# ---------------
# 106
# 제목:  애초에 신체검사를 왜 남경여경 기준이 다르지?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  16
# 댓글수:  1
# 추천수:  0
# ---------------
# 107
# 제목:  내일 얇은 맨투맨에 뽀글이 가능???
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  3
# 댓글수:  0
# 추천수:  0
# ---------------
# 108
# 제목:  얘들아..너네도 남동생하고 같이 길 걸으면 어색함???
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  13
# 댓글수:  3
# 추천수:  0
# ---------------
# 109
# 제목:  아이폰 업데이트 15 아직 안했는데
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  11
# 댓글수:  0
# 추천수:  0
# ---------------
# 110
# 제목:  아 지학 4번 틀렸는데 왜 틀렸는지 모르겠어
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  20
# 댓글수:  2
# 추천수:  0
# ---------------
# 111
# 제목:  국어 6등급..
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  23
# 댓글수:  0
# 추천수:  0
# ---------------
# 112
# 제목:  택배 반품신청햇는데 내가 집에 없을 때 오시면 어떡해?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  8
# 댓글수:  0
# 추천수:  0
# ---------------
# 113
# 제목:  친구만나면 에너지충전이아니라 방전되는데
# 글쓴이:  없음
# 날짜:  2021.11.18 20:46
# 조회수:  8
# 댓글수:  0
# 추천수:  0
# ---------------
# 114
# 제목:  문과에서 재수는 이과 왔는데 수학보다 국어가 발목잡아...
# 글쓴이:  없음
# 날짜:  2021.11.18 20:45
# 조회수:  12
# 댓글수:  1
# 추천수:  0
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# ---------------
# 115
# 제목:  얘들아 하루 폭식하면 얼굴 달라져?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:45
# 조회수:  6
# 댓글수:  0
# 추천수:  0
# ---------------
# 116
# 제목:  사문 17번에 왜 1번이지..?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:45
# 조회수:  25
# 댓글수:  4
# 추천수:  0
# ---------------
# 117
# 제목:  나 일주일 중에 7일 다 공부하는데 너무 힘듦 ...
# 글쓴이:  없음
# 날짜:  2021.11.18 20:45
# 조회수:  13
# 댓글수:  1
# 추천수:  0
# ---------------
# 118
# 제목:  47→26 미쳤네
# 글쓴이:  없음
# 날짜:  2021.11.18 20:45
# 조회수:  98
# 댓글수:  13
# 추천수:  0
# ---------------
# 119
# 제목:  나 모더나 1차 이미 맞았는데 그럼 어떻게 해?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:45
# 조회수:  17
# 댓글수:  2
# 추천수:  0
# ---------------
# 120
# 제목:  오늘 수능봤는데 사흘동안 잠 못잘것 같아..
# 글쓴이:  없음
# 날짜:  2021.11.18 20:45
# 조회수:  42
# 댓글수:  0
# 추천수:  0
# ---------------
# 121
# 제목:  확통68인데 3나오긴 힘들겠지..?ㅠㅠㅠㅠ
# 글쓴이:  없음
# 날짜:  2021.11.18 20:45
# 조회수:  6
# 댓글수:  0
# 추천수:  0
# ---------------
# 122
# 제목:  야광 숏패딩 어때?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:45
# 조회수:  6
# 댓글수:  0
# 추천수:  0
# ---------------
# 123
# 제목:  사탐 하나만 보는 대학 없나
# 글쓴이:  없음
# 날짜:  2021.11.18 20:45
# 조회수:  8
# 댓글수:  0
# 추천수:  0
# ---------------
# 124
# 제목:  사문 37인데 5등급은 안나오겠지? 진심?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:45
# 조회수:  18
# 댓글수:  1
# 추천수:  0
# ---------------
# 125
# 제목:  재수하면 최대로 망해도 현상유지인줄 알았는데
# 글쓴이:  없음
# 날짜:  2021.11.18 20:45
# 조회수:  19
# 댓글수:  1
# 추천수:  0
# ---------------
# 126
# 제목:  와 유튭에서 신기한거 봄
# 글쓴이:  없음
# 날짜:  2021.11.18 20:45
# 조회수:  6
# 댓글수:  0
# 추천수:  0
# ---------------
# 127
# 제목:  아니 ㅋㅋ 앞에 가던 할아버지 기침이랑 재채기할 때 마스크 내림
# 글쓴이:  없음
# 날짜:  2021.11.18 20:45
# 조회수:  10
# 댓글수:  0
# 추천수:  0
# ---------------
# 128
# 제목:  재벌이여도 돈이 좋은걸까,,?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:45
# 조회수:  9
# 댓글수:  0
# 추천수:  0
# ---------------
# 129
# 제목:  그나마 믿을만한 백신은 화이자밖에 없다는건가?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:45
# 조회수:  14
# 댓글수:  0
# 추천수:  0
# ---------------
# 130
# 제목:  한진택배 진짜 개느리다
# 글쓴이:  없음
# 날짜:  2021.11.18 20:45
# 조회수:  4
# 댓글수:  0
# 추천수:  0
# ---------------
# 131
# 제목:  무슨 자판기 음료처럼 광고가 돼있네
# 글쓴이:  없음
# 날짜:  2021.11.18 20:45
# 조회수:  25
# 댓글수:  0
# 추천수:  0
# ---------------
# 132
# 제목:  과외 그만 둘 건데 뭐라고 말하고 그만 두지..? ㅠㅠ 이 말 하구 한 번 더 과외 해야돼...
# 글쓴이:  없음
# 날짜:  2021.11.18 20:44
# 조회수:  14
# 댓글수:  1
# 추천수:  0
# ---------------
# 133
# 제목:  와 나 지구 6점 맞았어
# 글쓴이:  없음
# 날짜:  2021.11.18 20:44
# 조회수:  79
# 댓글수:  2
# 추천수:  0
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# ---------------
# 134
# 제목:  생윤 사문 40점 3등급 될까
# 글쓴이:  없음
# 날짜:  2021.11.18 20:44
# 조회수:  25
# 댓글수:  1
# 추천수:  0
# ---------------
# 135
# 제목:  ㅋㅋㅋㅋㅋㅋㅋ아니 잘 본게 없네
# 글쓴이:  없음
# 날짜:  2021.11.18 20:44
# 조회수:  9
# 댓글수:  0
# 추천수:  0
# ---------------
# 136
# 제목:  국어 84 잘본거야?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:44
# 조회수:  29
# 댓글수:  3
# 추천수:  0
# ---------------
# 137
# 제목:  수능 끝나니까 그냥 너무 졸리다...요새 딱히 무리도 안했는데
# 글쓴이:  없음
# 날짜:  2021.11.18 20:44
# 조회수:  10
# 댓글수:  3
# 추천수:  0
# ---------------
# 138
# 제목:  ❤️‍🔥❤️‍🔥❤️‍🔥숏패딩골라줘!!!!!!!!❤️‍🔥❤️‍🔥️‍
# 글쓴이:  없음
# 날짜:  2021.11.18 20:44
# 조회수:  145
# 댓글수:  16
# 추천수:  0
# ---------------
# 139
# 제목:  배고파서 쓰러질거같아.............
# 글쓴이:  없음
# 날짜:  2021.11.18 20:44
# 조회수:  5
# 댓글수:  0
# 추천수:  0
# ---------------
# 140
# 제목:  탐구 등급컷 9시야??
# 글쓴이:  없음
# 날짜:  2021.11.18 20:44
# 조회수:  20
# 댓글수:  0
# 추천수:  0
# ---------------
# 141
# 제목:  메가 터짐?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:44
# 조회수:  14
# 댓글수:  1
# 추천수:  0
# ---------------
# 142
# 제목:  입맛없을때 뭐시켜목을까
# 글쓴이:  없음
# 날짜:  2021.11.18 20:44
# 조회수:  8
# 댓글수:  3
# 추천수:  0
# ---------------
# 143
# 제목:  남익들 씻고 드라이기로 머리 말려?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:44
# 조회수:  19
# 댓글수:  1
# 추천수:  0
# ---------------
# 144
# 제목:  평가원이 n수생한테 하고 싶은 말 이거 ㄹㅇ인듯
# 글쓴이:  없음
# 날짜:  2021.11.18 20:44
# 조회수:  257
# 댓글수:  5
# 추천수:  0
# ---------------
# 145
# 제목:  87 96 1 47 45인데 어디까지될까..
# 글쓴이:  없음
# 날짜:  2021.11.18 20:44
# 조회수:  20
# 댓글수:  0
# 추천수:  0
# ---------------
# 146
# 제목:  알바 이력서
# 글쓴이:  없음
# 날짜:  2021.11.18 20:44
# 조회수:  6
# 댓글수:  0
# 추천수:  0
# ---------------
# 147
# 제목:  연세대 원주캠 252431로 가능?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:44
# 조회수:  17
# 댓글수:  3
# 추천수:  0
# ---------------
# 148
# 제목:  자켓 뭐 사는 게 좋을깜? 갸격은 비슷해
# 글쓴이:  없음
# 날짜:  2021.11.18 20:44
# 조회수:  10
# 댓글수:  1
# 추천수:  0
# ---------------
# 149
# 제목:  20대 초반둥들중 애인 심하게 잡고사는 익들 왜 잡고사는거야?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:44
# 조회수:  42
# 댓글수:  2
# 추천수:  0
# ---------------
# 150
# 제목:  응원이될지는 모르겠는데 그게전부는아니더라고
# 글쓴이:  없음
# 날짜:  2021.11.18 20:44
# 조회수:  11
# 댓글수:  0
# 추천수:  0
# ---------------
# 151
# 제목:  썸남 반수
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  15
# 댓글수:  1
# 추천수:  0
# ---------------
# 152
# 제목:  연애하면 할수록 계산적인 사람 돼?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  26
# 댓글수:  2
# 추천수:  0
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# ---------------
# 153
# 제목:  재수 왜 하는거지?????
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  106
# 댓글수:  10
# 추천수:  0
# ---------------
# 154
# 제목:  재수개망했는데 삼수못할듯
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  21
# 댓글수:  0
# 추천수:  0
# ---------------
# 155
# 제목:  애인이랑 헤어졌다가 다시 만났다가 오늘 다시 헤어질 판
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  7
# 댓글수:  0
# 추천수:  0
# ---------------
# 156
# 제목:  나는 그냥 평생 망한 인생으로 살 운명인가봄
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  14
# 댓글수:  0
# 추천수:  0
# ---------------
# 157
# 제목:  코로나 끝나고 마스크 벗었을때 걱정되는거
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  22
# 댓글수:  2
# 추천수:  0
# ---------------
# 158
# 제목:  최저 다 떨어졌어...
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  11
# 댓글수:  1
# 추천수:  0
# ---------------
# 159
# 제목:  토익 문제 하나만 풀어줄 사람..!!
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  12
# 댓글수:  1
# 추천수:  0
# ---------------
# 160
# 제목:  나 이거 권태기일까??
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  14
# 댓글수:  2
# 추천수:  0
# ---------------
# 161
# 제목:  익들아 내가 바닥 깔아줬어
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  11
# 댓글수:  0
# 추천수:  0
# ---------------
# 162
# 제목:  이번에 영어 어려웠어 쉬웠어?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  22
# 댓글수:  6
# 추천수:  0
# ---------------
# 163
# 제목:  생윤 42 윤사 36 등급컷 예상좀
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  22
# 댓글수:  0
# 추천수:  0
# ---------------
# 164
# 제목:  국어 71 3 가능?????
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  27
# 댓글수:  5
# 추천수:  0
# ---------------
# 165
# 제목:  최저 맞췃으면 일단 논술 보러가눈게 맞겟지…
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  11
# 댓글수:  0
# 추천수:  0
# ---------------
# 166
# 제목:  한국에서 지금 유행하는게 뭘까
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  12
# 댓글수:  0
# 추천수:  0
# ---------------
# 167
# 제목:  아이폰 XS 맥스 3년되가는데 점점
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  9
# 댓글수:  2
# 추천수:  0
# ---------------
# 168
# 제목:  번호 따간 사람이 카톡을 너무 느리게 해ㅠ
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  27
# 댓글수:  5
# 추천수:  0
# ---------------
# 169
# 제목:  진지하게 다 잘 해서 고민이야
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  12
# 댓글수:  0
# 추천수:  0
# ---------------
# 170
# 제목:  패딩 지퍼 이렇게 된 것도 수선 가능한가 세탁소에서 ?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  13
# 댓글수:  0
# 추천수:  0
# ---------------
# 171
# 제목:  요새도 수능 34412 나오면 지방대 가지?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  29
# 댓글수:  0
# 추천수:  0
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# ---------------
# 172
# 제목:  대학교 학생회 익들아
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  15
# 댓글수:  8
# 추천수:  0
# ---------------
# 173
# 제목:  그럼 이제 고등학교에서 사탐/과탐만 나뉘는 거야??
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  9
# 댓글수:  1
# 추천수:  0
# ---------------
# 174
# 제목:  12월달에 롱코트+목도리 추울까?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  5
# 댓글수:  0
# 추천수:  0
# ---------------
# 175
# 제목:  안친한 후배한테 뜬금없이연락오는거는 대부분족보때문이지?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  4
# 댓글수:  0
# 추천수:  0
# ---------------
# 176
# 제목:  23344 인서울 가능...?
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  31
# 댓글수:  6
# 추천수:  0
# ---------------
# 177
# 제목:  세지 컷 몇 나올까..ㅠㅠ
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  9
# 댓글수:  0
# 추천수:  0
# ---------------
# 178
# 제목:  익들은 백신 안맞은 친구가 익들에게(백신 2차까지 맞음)
# 글쓴이:  없음
# 날짜:  2021.11.18 20:43
# 조회수:  16
# 댓글수:  10
# 추천수:  0
# ---------------
# 179
# 제목:  아니 인스타 프로필 부분 왜이래,,,? ㅋㅋㅋㅋㅋ
# 글쓴이:  없음
# 날짜:  2021.11.18 20:42
# 조회수:  25
# 댓글수:  2
# 추천수:  0
# ---------------
# 180
# 제목:  할미타령 진짜 너무 보기 싫어서 짜증나네
# 글쓴이:  없음
# 날짜:  2021.11.18 20:42
# 조회수:  11
# 댓글수:  2
# 추천수:  0
# ---------------
# 181
# 제목:  수능 킬러? 는 거의 맞았는데 3점짜리 2개 틀림
# 글쓴이:  없음
# 날짜:  2021.11.18 20:42
# 조회수:  9
# 댓글수:  0
# 추천수:  0
# ---------------
# 182
# 제목:  온 우주가 내 대학 진학을 방해하는 듯
# 글쓴이:  없음
# 날짜:  2021.11.18 20:42
# 조회수:  13
# 댓글수:  0
# 추천수:  0
# ---------------
# 183
# 제목:  아 오늘 치과 최악이었다..
# 글쓴이:  없음
# 날짜:  2021.11.18 20:42
# 조회수:  8
# 댓글수:  0
# 추천수:  0
# ---------------
# 184
# 제목:  다들 가채점 했나보네
# 글쓴이:  없음
# 날짜:  2021.11.18 20:42
# 조회수:  13
# 댓글수:  1
# 추천수:  0
# ---------------
# 185
# 제목:  수능판은 ㄹㅇ 빨리 뜨는게 답이다,,
# 글쓴이:  없음
# 날짜:  2021.11.18 20:42
# 조회수:  28
# 댓글수:  0
# 추천수:  0
# ---------------
# 186
# 제목:  다들 수능쳤을때 당일 오후에 머했엉
# 글쓴이:  없음
# 날짜:  2021.11.18 20:42
# 조회수:  22
# 댓글수:  4
# 추천수:  0
# ---------------
# 187
# 제목:  헤어진지 두 달됐는데 전애인이 다음달에 수료를 해
# 글쓴이:  없음
# 날짜:  2021.11.18 20:42
# 조회수:  12
# 댓글수:  0
# 추천수:  0
# ---------------
# 188
# 제목:  한국사 풀 때 헐 개쉽네?하고 10분만에풀었는데
# 글쓴이:  없음
# 날짜:  2021.11.18 20:42
# 조회수:  23
# 댓글수:  0
# 추천수:  0
# ---------------
# 189
# 제목:  20대익들아 주변에 죽은 친구들 있니 사고사 제외
# 글쓴이:  없음
# 날짜:  2021.11.18 20:42
# 조회수:  24
# 댓글수:  2
# 추천수:  0
# ---------------
# 190
# 제목:  나 생리 9일째 ^^...
# 글쓴이:  없음
# 날짜:  2021.11.18 20:42
# 조회수:  7
# 댓글수:  0
# 추천수:  0

# %%
df2=pd.DataFrame(result2)
df2
# Out:
#                                        제목 글쓴이                날짜 조회수 댓글수 추천수
# 0                  남자 키 170이면 작은거야 보통인거야?  없음  2021.11.18 20:50   1   0   0
# 1    졸업작품 선물로 조말론 핸드워시랑 핸드크림 사서 주면 별로야???  없음  2021.11.18 20:50   1   0   0
# 2                      간호 교직이수 몇학년때 성적 봐?  없음  2021.11.18 20:50   1   0   0
# 3                            과탐 역대급 점수 받음  없음  2021.11.18 20:50   1   0   0
# 4                           무선 충전 무쳣다....  없음  2021.11.18 20:50   1   0   0
# ..                                    ...  ..               ...  ..  ..  ..
# 185                   다들 수능쳤을때 당일 오후에 머했엉  없음  2021.11.18 20:42  22   4   0
# 186           헤어진지 두 달됐는데 전애인이 다음달에 수료를 해  없음  2021.11.18 20:42  12   0   0
# 187            한국사 풀 때 헐 개쉽네?하고 10분만에풀었는데  없음  2021.11.18 20:42  23   0   0
# 188           20대익들아 주변에 죽은 친구들 있니 사고사 제외  없음  2021.11.18 20:42  24   2   0
# 189                        나 생리 9일째 ^^...  없음  2021.11.18 20:42   7   0   0
#
# [190 rows x 6 columns]

# %%
df2.to_excel('data/instiz_익명잡담_수능2.xlsx')

# %%
# 전체 인기글

# %%
contents2=soup.select('#rank1to10 > div')
contents2.extend(soup.select('#rank11to20 > div'))

# %%
#전체 인기글
cnt=1
result2=[]
for i in contents2:
    tmp={}
    print('-'*15)
    print(cnt)
    
    #게시판 추출
    category=i.find('div', {"class":"minitext"}).text
    print("게시판: ", category)
    
    
    # 제목 추출
    title=i.find('a', {"id":("focus"+str(i))})
    
    print("제목: ", title)
    
   
    
#    # 글쓴이 추출
#    writer_tag = i.find('td', {"class":"minitext2 listnm"})
#    if writer_tag is not None: # None 값이 있으므로 조건문을 통해 회피 
#        writer = writer_tag.text
#      
#    else:
#        writer = "없음"
#    print("글쓴이: ", writer)
    
#     # 유동이나 고닉이 아닌 글쓴이 옆에 있는 ip 추출
#     ip_tag = i.find('td', class_='gall_writer ub-writer').find('span', class_='ip')
#     if ip_tag is not None:  # None 값이 있으므로 조건문을 통해 회피 
#         ip = ip_tag.text
#         print("ip: ", ip)



#    # 날짜 추출 
#    date=i.find('td',{"class":"listno regdate"}).text
#    print("날짜: ",date)
    
    
#    # 조회 수 추출
#    views = i.find_all('td', {"class":"listno"})[2].text
#    print("조회수: ", views)


    # 댓글 수
    comment=i.find('a',{"class":"cmt"})
    if comment==None:
        comment=0
    else:
        comment=comment.text
    print("댓글수: ", comment)
    
#    # 추천 수 추출
#    recommend = i.find_all('td', {"class":"listno"})[3].text
#    print("추천수: ", recommend)

    tmp['게시판']=category
    tmp['제목']=title
#    tmp['글쓴이']=writer
#    tmp['날짜']=date
#    tmp['조회수']=views
    tmp['댓글수']=comment
#    tmp['추천수']=recommend
    
    result2.append(tmp)
    
    cnt=cnt+1
# Out:
# ---------------
# 1
# 게시판:  익명잡담
# 제목:  None
# 댓글수:  16
# ---------------
# 2
# 게시판:  인티포털
# 제목:  None
# 댓글수:  56

# %%
df2=pd.DataFrame(result2)
df2
# Out:
#      게시판                                   제목 댓글수
# 0   인티포털                    임시완이 공개한 연애횟수.jpg  10
# 1   익명잡담  우리집 고삼이 바람 쐬고 온다고 하고 이 시간에 울면서 나갔..   6
# 2   익명잡담                    와씨 라면스프 먹는데 대.존.맛  12
# 3   인티포털            용산 아이맥스때문에 남친이랑 싸운 여자.jpg  49
# 4   익명잡담                     이틀에 한번 샤워하면 더러워?  39
# 5   인티포털                최근들어 정말 예쁘다는 생각이 드는 분  33
# 6   익명잡담                       하루에 6~7시간 씩 하는   5
# 7   인티포털                       미쳐버린 어느 웹소설 설정   6
# 8   인티포털          트위치 어느 여스트리머의 방송정지 사유.jpgif   4
# 9   익명잡담                  브라렛이랑 그냥 브라랑 뭐가달라??  11
# 10  익명잡담                   [연애중] 계란말이된 썰 푼다,,   2
# 11  인티포털                   요즘 sns에 미남들이 많은 이유  18
# 12  인티포털          삼성 핸드폰 테스트 엔지니어도 어쩔 수 없는 취향   1
# 13  익명잡담  나 쌍수 망한 걸까… 심각하게 재수술 고민 중인데 한번씩 봐..  23
# 14  인티포털                  KFC 선넘는 신메뉴 폰치밥.jpg  12
# 15  인티포털     환경호르몬 많이 나오는데 흐린눈 하는 사람 많은 것.jpg  42
# 16  익명잡담        어른들 말 중에 틀린말 하나 없다..를 느끼게해준 말   7
# 17  익명잡담                   나 네일아트 자랑해도 될까?(두근  14
# 18  인티포털                        다음날 숙취가 없다는 술  13
# 19  익명잡담               아빠가 대기업 임원인게 엄청 대단한거임?   8

# %%
df2.to_excel('data/instiz_전체인기글.xlsx')

# %%
# 인티포털 인기글

# %%
contents3=soup.select('#rank1to10_menu > div')
contents3.extend(soup.select('#rank11to20_menu > div'))

# %%
#전체 인기글
cnt=1
result3=[]
for i in contents3:
    tmp={}
    print('-'*15)
    print(cnt)
    
    
    # 제목 추출
    if cnt<11:
        title=i.select_one('#rank1to10_menu > div > div.rank_subject > a').text.strip()
    else:
        title=i.select_one('#rank11to20_menu > div > div.rank_subject > a').text.strip()
    print("제목: ", title)
    
   
    
#    # 글쓴이 추출
#    writer_tag = i.find('td', {"class":"minitext2 listnm"})
#    if writer_tag is not None: # None 값이 있으므로 조건문을 통해 회피 
#        writer = writer_tag.text
#      
#    else:
#        writer = "없음"
#    print("글쓴이: ", writer)
    
#     # 유동이나 고닉이 아닌 글쓴이 옆에 있는 ip 추출
#     ip_tag = i.find('td', class_='gall_writer ub-writer').find('span', class_='ip')
#     if ip_tag is not None:  # None 값이 있으므로 조건문을 통해 회피 
#         ip = ip_tag.text
#         print("ip: ", ip)



#    # 날짜 추출 
#    date=i.find('td',{"class":"listno regdate"}).text
#    print("날짜: ",date)
    
    
#    # 조회 수 추출
#    views = i.find_all('td', {"class":"listno"})[2].text
#    print("조회수: ", views)


    # 댓글 수
    comment=i.find('a',{"class":"cmt"})
    if comment==None:
        comment=0
    else:
        comment=comment.text
    print("댓글수: ", comment)
    
#    # 추천 수 추출
#    recommend = i.find_all('td', {"class":"listno"})[3].text
#    print("추천수: ", recommend)

    tmp['제목']=title
#    tmp['글쓴이']=writer
#    tmp['날짜']=date
#    tmp['조회수']=views
    tmp['댓글수']=comment
#    tmp['추천수']=recommend
    
    result3.append(tmp)
    
    cnt=cnt+1
# Out:
# ---------------
# 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-60e38bbd68d2> in <module>
#      10     # 제목 추출
#      11     if cnt<11:
# ---> 12         title=i.select_one('#rank1to10_menu > div > div.rank_subject > a').text.strip()
#      13     else:
#      14         title=i.select_one('#rank11to20_menu > div > div.rank_subject > a').text.strip()
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
df3=pd.DataFrame(result3)
df3
# Out:
#                                   제목 댓글수
# 0                  임시완이 공개한 연애횟수.jpg  10
# 1          용산 아이맥스때문에 남친이랑 싸운 여자.jpg  49
# 2              최근들어 정말 예쁘다는 생각이 드는 분  33
# 3                     미쳐버린 어느 웹소설 설정   6
# 4                 요즘 sns에 미남들이 많은 이유  18
# 5                      다음날 숙취가 없다는 술  13
# 6        트위치 어느 여스트리머의 방송정지 사유.jpgif   4
# 7   환경호르몬 많이 나오는데 흐린눈 하는 사람 많은 것.jpg  42
# 8        삼성 핸드폰 테스트 엔지니어도 어쩔 수 없는 취향   1
# 9                KFC 선넘는 신메뉴 폰치밥.jpg  12
# 10         4만원에 여친한테 정떨어지면 내가 이상한건가?   0
# 11           일반인이 아이돌 메이크업을 받았을때.jpg  42
# 12           연구원에게 발각되어 만짐당하는 팔라스고양이  14
# 13                       털관리 잘한 리트리버   2
# 14           파리에서 오징어게임 배우로 오해받는 유튜버  36
# 15                마블 최초로 토마토 썩은 이터널스  38
# 16                 할로윈때 뚱뚱해지는 서양다람쥐들  67
# 17                      사고치는 고양이.jpg   3
# 18                         서울 뷔페 3대장   0
# 19        영국 데일리메일 홈피에서 발견된 한류...jpg   0

# %%
df3.to_excel('data/instiz_인티포털인기글.xlsx')
