# %% [markdown]
# # Beautiful Soup

# %% [markdown]
# # selenium

# %%
from selenium import webdriver
import time

driver = webdriver.Chrome('C:\selenium\chromedriver.exe')
base_url="https://sports.news.naver.com/wfootball/news/index?isphoto=N&page=1"
driver.get(base_url)

# %%
cnt=1
result=[]

for j in range(1,11):
    contents = driver.find_elements_by_xpath('//*[@id="_newsList"]/ul/li')
    for i in contents:
        tmp={}
        print('-'*15)
        print(cnt)
        cnt=cnt+1
    
        # 분야 추출
        #category=i.find('a', {"class":"list_word"}).text
        #print("분야: ", category)

        # 제목 추출
        title=i.find_element_by_class_name('title').text.strip()
        print("제목: ", title)
    
   
    
        # 글쓴이 추출
        #writer_tag = i.find('span', class_='nick')
        #if writer_tag is not None: # None 값이 있으므로 조건문을 통해 회피 
        #    writer = writer_tag.text
          
        #else:
        #    writer = "없음"
        #print("글쓴이: ", writer)
    
    #    # 유동이나 고닉이 아닌 글쓴이 옆에 있는 ip 추출
    #    ip_tag = i.find('td', class_='gall_writer ub-writer').find('span', class_='ip')
    #    if ip_tag is not None:  # None 값이 있으므로 조건문을 통해 회피 
    #        ip = ip_tag.text
    #        print("ip: ", ip)


        # 날짜 추출 
        date=i.find_element_by_class_name('time').text
        print("날짜: ",date)
    
    
        # 조회 수 추출
        #views = i.find('span',{"class":"viewV"}).text
        #print("조회수: ", views)


        # 댓글 수
        #comment=i.find('span',{"class":"replycnt"})
        #if comment==None:
        #    comment=0
        #else:
        #    comment=comment.text
        #    comment=comment[1:len(comment)-1]
        #print("댓글수: ", comment)
   

        # 추천 수 추출
    #    recommend = i.find_all('td')[-2].text
    #    if recommend == "":
    #        recommend=0
    #    else:
    #        recommend=recommend.split('-')[0].strip()
    #    print("추천수: ", recommend)
    
        #tmp['분야']=category
        tmp['제목']=title
        #tmp['글쓴이']=writer
        tmp['날짜']=date
        #tmp['조회수']=views
        #tmp['댓글수']=comment
    #    tmp['추천수']=recommend
    
        result.append(tmp)
        
    page=driver.find_element_by_xpath('//*[@id="_pageList"]/a['+str(j)+']')
    driver.execute_script("arguments[0].click();", page)
    time.sleep(3)
# Out:
# ---------------
# 1
# 제목:  "이게 샴페인 축구!"…첼시 유스 활약에 '선배' 조 콜, 함박웃음
# 날짜:  2021.11.24 18:46
# ---------------
# 2
# 제목:  벨기에 신트트라위던VV와 결별 이승우, 국내 복귀?
# 날짜:  2021.11.24 18:44
# ---------------
# 3
# 제목:  'CR800'호날두, 데뷔 20주년 앞두고 800호골 금자탑…연 평균 42골
# 날짜:  2021.11.24 18:34
# ---------------
# 4
# 제목:  임시 감독 찾는 맨유, '라리가 우승 2회' 발베르데와 접촉
# 날짜:  2021.11.24 18:31
# ---------------
# 5
# 제목:  '자격 있다!' 맨유 선수들 더 신났다, '7300만 파운드 스타' 드디어 득점포
# 날짜:  2021.11.24 18:27
# ---------------
# 6
# 제목:  맨유, 임시 감독 자리에 발베르데 낙점...'이미 접촉 중'
# 날짜:  2021.11.24 18:26
# ---------------
# 7
# 제목:  호날두, UCL 140호 골 넣었지만...34연속 프리킥 득점 실패 '아쉽네!'
# 날짜:  2021.11.24 18:26
# ---------------
# 8
# 제목:  홈 ‘7승 1무 1패’ 맨시티, ‘메시·음바페·네이마르’ 두렵지 않다 [엠스플 UCL]
# 날짜:  2021.11.24 18:18
# ---------------
# 9
# 제목:  '리버풀의 재능' 엘리엇, 올해의 북서부 '라이징 스타' 선정
# 날짜:  2021.11.24 18:18
# ---------------
# 10
# 제목:  ‘성관계 비디오 협박’ 벤제마, 벌금 1억원+집행유예 1년 판결
# 날짜:  2021.11.24 18:15
# ---------------
# 11
# 제목:  '성관계 영상 협박' 벤제마…유죄 판결 확정 '징역 1년'
# 날짜:  2021.11.24 18:13
# ---------------
# 12
# 제목:  "브루스면 훌륭하지" 맨유 전설 슈마이켈, 구단에 뉴캐슬 전 감독 추천
# 날짜:  2021.11.24 18:08
# ---------------
# 13
# 제목:  '친정 쓴소리 전문' 스콜스, "투톱이 36살 34살? 참나, 우린 맨유야."
# 날짜:  2021.11.24 18:01
# ---------------
# 14
# 제목:  선 그은 아약스 명장 "맨유 연락 없었다. 여기서 우승하고 싶다"
# 날짜:  2021.11.24 18:01
# ---------------
# 15
# 제목:  [스포츠타임]다시 펩 과르디올라 감독 앞에 서는 메시, PSG에 1위 선물?
# 날짜:  2021.11.24 18:01
# ---------------
# 16
# 제목:  '첼시→레알' 아자르와 함께 뛴 GK, "그는 평범한 선수가 아니야!"
# 날짜:  2021.11.24 17:56
# ---------------
# 17
# 제목:  손흥민, 3년 연속 챔스 못 가나…슈퍼컴퓨터, 토트넘에 '비관적'
# 날짜:  2021.11.24 17:50
# ---------------
# 18
# 제목:  유베·토트넘, 김민재 노린다?…현지매체 보도 나와
# 날짜:  2021.11.24 17:48
# ---------------
# 19
# 제목:  맨유 레전드들 냉정한 평가 “캐릭은 임시대행, 감독제안 받기는 어려울 것”
# 날짜:  2021.11.24 17:43
# ---------------
# 20
# 제목:  '챔스 사나이' 레반도프스키, 생애 2번째 9G 연속 골...역대 최초
# 날짜:  2021.11.24 17:40
# ---------------
# 21
# 제목:  포체티노 맨유 예상 라인업 떴다, '아픈 손가락 1~2호' 나란히 선발 예측
# 날짜:  2021.11.24 17:38
# ---------------
# 22
# 제목:  마요르카 감독 "이강인, 퇴장 조심하라 했는데 코치가 교체"
# 날짜:  2021.11.24 17:35
# ---------------
# 23
# 제목:  Lee Seung-woo left without team as Sint-Truiden terminates contract
# 날짜:  2021.11.24 17:29
# ---------------
# 24
# 제목:  퍼거슨의 저주? "맨유 레전드 출신 감독은 실패한다" 벌써 13명 경질 [英언론]
# 날짜:  2021.11.24 17:28
# ---------------
# 25
# 제목:  연봉 2배 더 줄게...홀란드, 남을까 떠날까
# 날짜:  2021.11.24 17:28
# ---------------
# 26
# 제목:  "모우라, 너무 과소평가됐어!"…토트넘 엠버서더의 칭찬
# 날짜:  2021.11.24 17:21
# ---------------
# 27
# 제목:  Hwang Hee-chan could trigger a bidding war this winter
# 날짜:  2021.11.24 17:11
# ---------------
# 28
# 제목:  '메시, PSG 데뷔골 선물' 과르디올라, 이번엔 제자 막고 1위 사수할까
# 날짜:  2021.11.24 17:11
# ---------------
# 29
# 제목:  '스퍼스 열받겠다' 슈퍼컴의 EPL 최종순위 예측, 토트넘 또 7위-맨시티 우승-맨유 5위
# 날짜:  2021.11.24 17:01
# ---------------
# 30
# 제목:  '포체티노 아들' 쇼, 맨유에서 재결합 갈망한다
# 날짜:  2021.11.24 17:01
# ---------------
# 31
# 제목:  ‘1200억 폭락’ 아자르, 친정팀서 ‘월클’ 시절 되찾을까
# 날짜:  2021.11.24 17:00
# ---------------
# 32
# 제목:  '21년 만에 UCL 조별리그 탈락 위기'...사비 "아직 한 번의 기회 있다"
# 날짜:  2021.11.24 16:59
# ---------------
# 33
# 제목:  김민재 영입설 터졌다, ‘유벤투스 133억↑ 토트넘 더 높게 불렀다’
# 날짜:  2021.11.24 16:56
# ---------------
# 34
# 제목:  '발롱도르 내 거야!' 레반도프스키, 신발 끈도 안 묶고 오버헤드킥 작렬
# 날짜:  2021.11.24 16:56
# ---------------
# 35
# 제목:  '호날두 결승골' 맨유, 챔스리그 16강 진출
# 날짜:  2021.11.24 16:53
# ---------------
# 36
# 제목:  칼빈 필립스 "가장 상대하기 어려운 선수는… 김덕배"
# 날짜:  2021.11.24 16:42
# ---------------
# 37
# 제목:  세계 최고 골키퍼의 '황당 헛발질', 골대가 살렸다
# 날짜:  2021.11.24 16:41
# ---------------
# 38
# 제목:  [스토리.1st] 빅클럽들이 모셔가려는 '남미 신성' 디아스, 영양실조 이겨낸 영화 같은 사연
# 날짜:  2021.11.24 16:41
# ---------------
# 39
# 제목:  "하프타임 25분으로 늘리자"… IFAB, FIFA에 공식 제안 예정
# 날짜:  2021.11.24 16:39
# ---------------
# 40
# 제목:  사비, '1004억짜리 먹튀' 향해 "훌륭한 선수"…이유는?
# 날짜:  2021.11.24 16:37
# ---------------
# 41
# 제목:  김민재, 유벤투스‧토트넘 타깃...페네르바체가 원하는 이적료는?
# 날짜:  2021.11.24 16:36
# ---------------
# 42
# 제목:  캐릭의 무한칭찬 “데뷔골 넣은 산초, 오늘 환상적이었다”
# 날짜:  2021.11.24 16:34
# ---------------
# 43
# 제목:  "전반전 두려웠다"던 매과이어, 무실점 승리로 '생명 연장'
# 날짜:  2021.11.24 16:31
# ---------------
# 44
# 제목:  맨유 '감독 선임 열쇠'는 지단?...PSG, 대체자 찾으면 포체티노 보낸다
# 날짜:  2021.11.24 16:31
# ---------------
# 45
# 제목:  결국 아드보카트가 떠났다…경쟁국들의 WC 예선 후유증
# 날짜:  2021.11.24 16:29
# ---------------
# 46
# 제목:  공석인 맨유 사령탑, '전 바르사' 발베르데 감독이 급부상..."포치는 비현실적
# 날짜:  2021.11.24 16:25
# ---------------
# 47
# 제목:  맨유 감독 후보 오른 텐 하흐의 '사이다' 거절..."난 전혀 관심없어!"
# 날짜:  2021.11.24 16:23
# ---------------
# 48
# 제목:  어색한 탈락 위기...사비 "이기기 위해 간다"
# 날짜:  2021.11.24 16:18
# ---------------
# 49
# 제목:  [EPL.1st] '스프린트·활동량↑' 콘테의 토트넘, 벌써 달라지기 시작했다
# 날짜:  2021.11.24 16:16
# ---------------
# 50
# 제목:  “김민재, 유벤투스·토트넘이 260억에 노려” 터키 신문 보도
# 날짜:  2021.11.24 16:14
# ---------------
# 51
# 제목:  'SON-케인 투톱' 토트넘, 무라전 예상 라인업 떴다 (英 매체)
# 날짜:  2021.11.24 16:06
# ---------------
# 52
# 제목:  '90% 출전' 붙박이 주전 MF, 맨유 감독 교체 후 선발 제외
# 날짜:  2021.11.24 16:01
# ---------------
# 53
# 제목:  토트넘서 '졸장' 누누에게 밀린 감독, 맨유가 노린다
# 날짜:  2021.11.24 15:59
# ---------------
# 54
# 제목:  투헬 감독, 챔스 대승+16강 진출에도 울상... '캉테-칠웰 부상'
# 날짜:  2021.11.24 15:58
# ---------------
# 55
# 제목:  "아름다운 추억이었지" 메시, 호날두와 맞붙던 라 리가 시절 회상
# 날짜:  2021.11.24 15:56
# ---------------
# 56
# 제목:  '맨유 부임설' 포체티노 "파리에서 매우 행복합니다"
# 날짜:  2021.11.24 15:51
# ---------------
# 57
# 제목:  [오피셜] 50년 만에 엠블럼 바꾼 노리치...“EPL 20팀 중 마지막 교체”
# 날짜:  2021.11.24 15:42
# ---------------
# 58
# 제목:  '맨유 레전드' 스콜스, 캐릭에 냉정한 평가…"떠났어야 했다"
# 날짜:  2021.11.24 15:40
# ---------------
# 59
# 제목:  '도와주세요 클롭 선생님' 리버풀 손에 달린 아틀레티코, 밀란의 운명
# 날짜:  2021.11.24 15:39
# ---------------
# 60
# 제목:  '호날두·산초 골' 맨유, 16강 진출‥첼시도 합류
# 날짜:  2021.11.24 15:35
# ---------------
# 61
# 제목:  이승우, 벨기에 신트트라이던과 계약 해지
# 날짜:  2021.11.24 15:31
# ---------------
# 62
# 제목:  두 파벌로 찢긴 바이에른…이유는 '백신 접종'
# 날짜:  2021.11.24 15:31
# ---------------
# 63
# 제목:  '맨유 캡틴' 매과이어, "비야레알전 승리는 큰 의미, 다시 시작할 것"
# 날짜:  2021.11.24 15:21
# ---------------
# 64
# 제목:  '4개월 만의 맨유 데뷔골' 산초 "어쩌지! 내가 너무 자랑스러워"
# 날짜:  2021.11.24 15:20
# ---------------
# 65
# 제목:  이승우, 신트트라위던과 계약 해지…국내 유턴해 ‘제 2의 백승호’ 될까
# 날짜:  2021.11.24 15:16
# ---------------
# 66
# 제목:  '시즌 5호 골' 제임스, 첼시 팬들의 연이은 찬사..."아놀드보다 낫다!"
# 날짜:  2021.11.24 15:16
# ---------------
# 67
# 제목:  무리뉴와 싸운 AS로마 영스타, 토트넘은 그 틈에 관심
# 날짜:  2021.11.24 15:08
# ---------------
# 68
# 제목:  클롭 "'뉴캐슬 타깃' 오리기 임대 이적 거절한다"
# 날짜:  2021.11.24 15:02
# ---------------
# 69
# 제목:  솔샤르 신임 잃은 1161억 사나이, 캐릭 체제서 '부활' 신호탄
# 날짜:  2021.11.24 15:00
# ---------------
# 70
# 제목:  토트넘 '성골 유스' 71일 만의 출전... "콘테 밑에서 폭발할 거야"
# 날짜:  2021.11.24 14:53
# ---------------
# 71
# 제목:  나이는 숫자에 불과하다...'평균 나이 36세' UCL 베스트11은?
# 날짜:  2021.11.24 14:51
# ---------------
# 72
# 제목:  ‘데뷔승’ 마이클 캐릭의 자신감 “솔샤르의 실수 반복하지 않을 것”
# 날짜:  2021.11.24 14:47
# ---------------
# 73
# 제목:  [UCL] '영화의 한 장면' 찍은 레반도프스키, 뮌헨 승리 이끌어
# 날짜:  2021.11.24 14:41
# ---------------
# 74
# 제목:  빈 골문에 뻥~… “역대 최악의 실수” 덕에 16강 좌절 면한 바르사
# 날짜:  2021.11.24 14:38
# ---------------
# 75
# 제목:  포체티노 진짜 맨유 감독가나? “EPL 우승을 위해서!” 말실수
# 날짜:  2021.11.24 14:36
# ---------------
# 76
# 제목:  '맨유 안 가요' 선 그은 포체티노, 맨유는 발베르데와 협상 중
# 날짜:  2021.11.24 14:32
# ---------------
# 77
# 제목:  "선 넘은 호날두 영향력, 감독보다 커"...전 잉글랜드 GK '강력 비판'
# 날짜:  2021.11.24 14:31
# ---------------
# 78
# 제목:  나폴리 '주전' 공격수, 얼굴뼈 골절로 90일 아웃
# 날짜:  2021.11.24 14:30
# ---------------
# 79
# 제목:  "맨유 임시 감독으로 우리 아빠 추천합니다"… 브루스, 사령탑 될까
# 날짜:  2021.11.24 14:29
# ---------------
# 80
# 제목:  FC바르셀로나, 21년 만에 챔스 조별라운드 탈락 위기
# 날짜:  2021.11.24 14:27
# ---------------
# 81
# 제목:  '미친 활동량' 콘테의 토트넘, 누누 때보다 '12km 더 뛰었다!'
# 날짜:  2021.11.24 14:26
# ---------------
# 82
# 제목:  첼시 황태자의 마인드, "팀 위해 더러운 일도 하겠다"
# 날짜:  2021.11.24 14:24
# ---------------
# 83
# 제목:  프랑스 매체 "포체티노 떠나도 아쉬울 사람 없어… 지단은 환영"
# 날짜:  2021.11.24 14:12
# ---------------
# 84
# 제목:  이승우, 스위스+MLS서 부른다!…韓 복귀도 검토
# 날짜:  2021.11.24 14:12
# ---------------
# 85
# 제목:  이승우, 벨기에 신트트라위던과 계약 해지
# 날짜:  2021.11.24 14:11
# ---------------
# 86
# 제목:  맨유로 알아본 임시감독 성적표, 거스 히딩크는 '전설'이었네
# 날짜:  2021.11.24 14:09
# ---------------
# 87
# 제목:  과르디올라 ‘맨유 감독설’ 포체티노 극찬 왜?
# 날짜:  2021.11.24 14:08
# ---------------
# 88
# 제목:  '레길론이 최악이라 할 만했네' 토트넘, 콘테 부임 후 18km 더 뛰었다
# 날짜:  2021.11.24 14:01
# ---------------
# 89
# 제목:  산초, '15G 만에' 데뷔골...英 대표팀 동료들도 응원 메시지
# 날짜:  2021.11.24 14:01
# ---------------
# 90
# 제목:  홀란드 노리는 맨시티…토트넘, 케인 대안 공격수 영입에 유리
# 날짜:  2021.11.24 13:57
# ---------------
# 91
# 제목:  손흥민 `이탈리아 축구 영웅` 델피에로와 기념사진…"진정한 전설"
# 날짜:  2021.11.24 13:56
# ---------------
# 92
# 제목:  '솔샤르 시즌2?' 캐러거의 조롱, "캐릭과 당장 정식 감독 계약 맺자!"
# 날짜:  2021.11.24 13:50
# ---------------
# 93
# 제목:  솔샤르 떠난 맨유, ‘믿을 맨’은 역시 호날두…비야레알전 결승골&UCL 16강행 견인
# 날짜:  2021.11.24 13:48
# ---------------
# 94
# 제목:  챔스 9경기 연속 득점...그것도 두번째
# 날짜:  2021.11.24 13:46
# ---------------
# 95
# 제목:  델 피에로, 손흥민‧케인 등 사진 요청에 "순수했던 시절 떠올라"
# 날짜:  2021.11.24 13:39
# ---------------
# 96
# 제목:  'SON+케인' 대신할 최상급 옵션...'세리에 득점 1위' 노리는 이유
# 날짜:  2021.11.24 13:36
# ---------------
# 97
# 제목:  호나우지뉴, 또 체포 위기...전 약혼자에 월 2천만원 위자료 미지급
# 날짜:  2021.11.24 13:32
# ---------------
# 98
# 제목:  [442.star] 월드컵 탈락 위기+가까워진 시대의 종말, 호날두는 살아날까?
# 날짜:  2021.11.24 13:31
# ---------------
# 99
# 제목:  웨스트햄, 경기 중 '팬들이 가장 많이 방귀 뀌는 팀' 1위 등극
# 날짜:  2021.11.24 13:27
# ---------------
# 100
# 제목:  ‘이탈리아 레전드’ 델 피에로 만난 손흥민, "진정한 레전드와 만나 영광"
# 날짜:  2021.11.24 13:24
# ---------------
# 101
# 제목:  이승우, 벨기에 신트트라위던과 작별…K리그도 차기 행선지 거론
# 날짜:  2021.11.24 13:16
# ---------------
# 102
# 제목:  '520조' 뉴캐슬, 1월 '손흥민 입단 동기' 영입 계획
# 날짜:  2021.11.24 13:11
# ---------------
# 103
# 제목:  포체티노 맨유행 가까웠는데…"다른 구단의 일은 나와 상관없다"
# 날짜:  2021.11.24 13:07
# ---------------
# 104
# 제목:  "우리 아빠 맨유 임시감독으로 어때요" 아들의 신박한 '공개구직'
# 날짜:  2021.11.24 12:57
# ---------------
# 105
# 제목:  '에릭센 살린' 덴마크, FIFA 페이플레이 상 후보
# 날짜:  2021.11.24 12:57
# ---------------
# 106
# 제목:  “레전드를 만나 기뻐요!” 손흥민, 이탈리아 전설과 찰칵+웃음꽃 만개
# 날짜:  2021.11.24 12:55
# ---------------
# 107
# 제목:  분데스리가 위대한 도전, 12월 '세계최초 탄소제로' 투표 [이종성의 스포츠 문화&산업]
# 날짜:  2021.11.24 12:51
# ---------------
# 108
# 제목:  즐라탄, '솔샤르 경질' 맨유에 작심 발언..."여전히 과거에 살아"
# 날짜:  2021.11.24 12:46
# ---------------
# 109
# 제목:  손흥민, 델 피에로 만나다…"진정한 전설을 만나 영광"
# 날짜:  2021.11.24 12:32
# ---------------
# 110
# 제목:  이승우, 신트트라위던과 계약해지
# 날짜:  2021.11.24 12:21
# ---------------
# 111
# 제목:  '솔샤르가 옳았다'…英매체, '63일 만에 선발' 반 더 비크 혹평
# 날짜:  2021.11.24 12:21
# ---------------
# 112
# 제목:  "알리, 토트넘에서 끝났다" 필립스 "토트넘, 내년 1월 에버튼 골키퍼 픽포드 거래에 알리 포함시킬 것"
# 날짜:  2021.11.24 12:17
# ---------------
# 113
# 제목:  손흥민, '세리에 A 전설' 델피에로와 우연 회동..."진정한 레전드 만나 영광"
# 날짜:  2021.11.24 12:16
# ---------------
# 114
# 제목:  슈퍼스타가 아니라 유망주…뉴캐슬, 릴 우승 이끈 '신성' 영입 추진
# 날짜:  2021.11.24 12:13
# ---------------
# 115
# 제목:  "캐릭은 코치"… 스콜스·퍼디낸드, 정식 감독 선임에는 반대
# 날짜:  2021.11.24 12:12
# ---------------
# 116
# 제목:  경질 후엔 잘하는 맨유… 감독대행 첫 경기 2대0 승리
# 날짜:  2021.11.24 12:03
# ---------------
# 117
# 제목:  솔샤르 떠나니 타오르는 충성심 "맨유에서 내 이름 떨친다"
# 날짜:  2021.11.24 12:01
# ---------------
# 118
# 제목:  [UCL] 196일만에 '첫 골' 제이든 산초, '역대급 침묵 끝'
# 날짜:  2021.11.24 12:01
# ---------------
# 119
# 제목:  '대체 누가 갈까' 포체티노, 맨유 부임설 일축 "난 PSG서 행복하다"
# 날짜:  2021.11.24 11:59
# ---------------
# 120
# 제목:  황희찬에게 밀린 '피지컬 윙어', 스왑딜로 발렌시아 이적?
# 날짜:  2021.11.24 11:56
# ---------------
# 121
# 제목:  금호타이어, 토트넘 홋스퍼 공식 후원 연장
# 날짜:  2021.11.24 11:56
# ---------------
# 122
# 제목:  '셰필드 핵심 MF' 경기 중 의식 잃고 쓰러져 '충격'
# 날짜:  2021.11.24 11:54
# ---------------
# 123
# 제목:  '첼시 어쩌나' 캉테-칠웰 동시 부상 이탈... 맨유전 출전 불투명
# 날짜:  2021.11.24 11:46
# ---------------
# 124
# 제목:  '호날두·산초 골' 맨유, UCL 16강 진출…첼시도 합류
# 날짜:  2021.11.24 11:43
# ---------------
# 125
# 제목:  셰필드 소속 플랙, 경기 도중 기절… 10분 동안 응급처치 후 병원 이송
# 날짜:  2021.11.24 11:34
# ---------------
# 126
# 제목:  그나브리-무시알라 '백신' 맞았다!…남은 건 '키미히'
# 날짜:  2021.11.24 11:31
# ---------------
# 127
# 제목:  손흥민, 델 피에로와 만남… "두 전설 만났다"
# 날짜:  2021.11.24 11:27
# ---------------
# 128
# 제목:  티아고, 바르사 복귀?..."리버풀행은 100% 옳은 선택"
# 날짜:  2021.11.24 11:25
# ---------------
# 129
# 제목:  '주 득점원 DF'·'중원 엔진' 부상, 첼시가 웃지 못한 이유
# 날짜:  2021.11.24 11:20
# ---------------
# 130
# 제목:  또 결승골… 맨유팬 홀리는 호날두
# 날짜:  2021.11.24 11:11
# ---------------
# 131
# 제목:  손흥민, 이탈리아 축구 영웅 델 피에로와 기념사진…"진정한 전설"
# 날짜:  2021.11.24 11:06
# ---------------
# 132
# 제목:  '루머 난무' 맨체스터에 뜬 포체티노, 맨유행 루머 일축
# 날짜:  2021.11.24 11:06
# ---------------
# 133
# 제목:  '콘테의 황태자 등극?'...3경기 풀타임 뛴 토트넘 CB, 패스 능력 호평
# 날짜:  2021.11.24 11:06
# ---------------
# 134
# 제목:  '1160억 신성' 드디어 터졌다..."맨유 데뷔골 자랑스럽다"
# 날짜:  2021.11.24 11:00
# ---------------
# 135
# 제목:  페네르바체 열성팬, 이스탄불 더비 시청 도중 심장마비로 숨져
# 날짜:  2021.11.24 10:55
# ---------------
# 136
# 제목:  임시 감독 찾는 맨유, 후보만 5명… 그런데 캐릭 대행도 포함됐다
# 날짜:  2021.11.24 10:54
# ---------------
# 137
# 제목:  "천재적인 선수"… 스콜스, 맨유 데뷔골 산초 극찬
# 날짜:  2021.11.24 10:52
# ---------------
# 138
# 제목:  손흥민, 델 피에로와 기념사진… “진정한 전설 만나 영광”
# 날짜:  2021.11.24 10:51
# ---------------
# 139
# 제목:  '축구 몰라요' 맨유 극약처방 통했다, 솔샤르 경질 후 바로 승리-다음은 첼시 원정
# 날짜:  2021.11.24 10:46
# ---------------
# 140
# 제목:  40세 노장 즐라탄 "은퇴 계획 없어. 내 몸엔 아드레날린이 넘치거든"
# 날짜:  2021.11.24 10:43
# ---------------
# 141
# 제목:  이승우 계약해지, 신트트라위던과 결별
# 날짜:  2021.11.24 10:41
# ---------------
# 142
# 제목:  투헬, 첼시 '16강 진출'에도 마냥 웃을 수 없는 이유
# 날짜:  2021.11.24 10:41
# ---------------
# 143
# 제목:  이승우, 신트트라위던과 계약 해지
# 날짜:  2021.11.24 10:40
# ---------------
# 144
# 제목:  "굿바이 '007'" 솔샤르 떠나자 마침내 폭발한 '1200억원의 남자'
# 날짜:  2021.11.24 10:33
# ---------------
# 145
# 제목:  이승우, 국내 복귀할까…벨기에 신트트라위던 계약해지
# 날짜:  2021.11.24 10:27
# ---------------
# 146
# 제목:  아니 이걸 막는다고? 37세 T.실바의 골라인 클리어링에 입이 쩍
# 날짜:  2021.11.24 10:27
# ---------------
# 147
# 제목:  '슈퍼세이브' 데 헤아, 맨유 살렸다...상대 선수도 "OK! 인정!"
# 날짜:  2021.11.24 10:21
# ---------------
# 148
# 제목:  물고 물리는 G조...모든 것은 최종전에서 [UCL]
# 날짜:  2021.11.24 10:21
# ---------------
# 149
# 제목:  '역시 챔스 사나이'...호날두, 英 클럽 최초 UCL 5경기 연속골
# 날짜:  2021.11.24 10:16
# ---------------
# 150
# 제목:  델피에로 만난 손흥민…"진정한 전설 만나 영광"
# 날짜:  2021.11.24 10:14
# ---------------
# 151
# 제목:  델 피에로 만난 손흥민 "진정한 레전드"
# 날짜:  2021.11.24 10:09
# ---------------
# 152
# 제목:  맨유 일부 결별 예정자, 이적 보류… 린가드 "그래도 난 떠난다"
# 날짜:  2021.11.24 10:07
# ---------------
# 153
# 제목:  ‘연봉 4배 올려 줄게’ 뮌헨, 바이아웃만 ‘1조 3382억’ 바르사 유망주 노린다
# 날짜:  2021.11.24 10:05
# ---------------
# 154
# 제목:  '호날두 결승골' 맨유, 유럽 챔스 16강 진출
# 날짜:  2021.11.24 10:04
# ---------------
# 155
# 제목:  새 맨유 감독 들으라고.. 스콜스, "산초, 이제야 1100억 짜리 같네"
# 날짜:  2021.11.24 10:04
# ---------------
# 156
# 제목:  첼시의 기세, 수비의 힘 [UCL]
# 날짜:  2021.11.24 10:02
# ---------------
# 157
# 제목:  '침울→환호' 분위기 반전엔 역시 "호우~!" 호날두, UCL 140번째 골
# 날짜:  2021.11.24 09:54
# ---------------
# 158
# 제목:  세다리 의혹' 잭 그릴리쉬, 모델 여친과 결혼 임박?
# 날짜:  2021.11.24 09:51
# ---------------
# 159
# 제목:  '이번엔 맨유 겨냥' 즐라탄, "맨유는 옛날이야기 너무 많이 해"
# 날짜:  2021.11.24 09:51
# ---------------
# 160
# 제목:  이게 무슨 망신이야...리즈 핵심 MF, 클럽에서 미끄러져 '뇌진탕'
# 날짜:  2021.11.24 09:51
# ---------------
# 161
# 제목:  4대0 완승에도 "슬프다"는 첼시 감독, 캉테-칠웰 정밀검사
# 날짜:  2021.11.24 09:50
# ---------------
# 162
# 제목:  올 시즌 '0경기 출전' 이승우, 신트트라위던과 결별
# 날짜:  2021.11.24 09:49
# ---------------
# 163
# 제목:  손흥민-델 피에로 '인증샷'에 팬들도 환호…"전설이 전설을 만나"
# 날짜:  2021.11.24 09:47
# ---------------
# 164
# 제목:  "축구화 끈 풀렸는데"… '오버헤드킥 골' 레반도프스키, 득점 단독선두
# 날짜:  2021.11.24 09:42
# ---------------
# 165
# 제목:  佛 '물병 투척' 과격 관중, 5년간 경기장 출입 못한다
# 날짜:  2021.11.24 09:39
# ---------------
# 166
# 제목:  '어떻게 놀았길래..' 손흥민 상대한 리즈MF, X-마스 파티 도중 황당 부상
# 날짜:  2021.11.24 09:30
# ---------------
# 167
# 제목:  ‘돌아가신 노부부 팬을 관중석에…’ 김민재 소속팀 페네르바체의 감동 이벤트
# 날짜:  2021.11.24 09:29
# ---------------
# 168
# 제목:  호날두와 맨유, 챔피언스리그 16강 안착…첼시도 합류
# 날짜:  2021.11.24 09:26
# ---------------
# 169
# 제목:  드로그바 "살라 때문에 울고 싶어"...왜?
# 날짜:  2021.11.24 09:22
# ---------------
# 170
# 제목:  손흥민 날개 단다...토트넘, 콘테 감독 첫작품 케시에 1월 영입 '올인'
# 날짜:  2021.11.24 09:15
# ---------------
# 171
# 제목:  레알, 또 다친 베일 덕에 ‘100억’ 벌까... FIFA 보상금 지불↑
# 날짜:  2021.11.24 09:08
# ---------------
# 172
# 제목:  챔스에 강한 호날두 결승골…맨유, 3년만에 UCL 16강
# 날짜:  2021.11.24 09:06
# ---------------
# 173
# 제목:  '호날두 · 산초 골 맛' 맨유, UCL 16강 진출…첼시도 합류
# 날짜:  2021.11.24 09:03
# ---------------
# 174
# 제목:  '전설' 퍼거슨 감독, 맨유 임시 감독으로 누구 지지하나
# 날짜:  2021.11.24 09:01
# ---------------
# 175
# 제목:  '포그바 대체 선수 찾았다' 1191억으로 노린다…맨시티도 영입에 관심
# 날짜:  2021.11.24 09:01
# ---------------
# 176
# 제목:  첼시, 유벤투스 4-0 완파… '동반 16강행' 확정
# 날짜:  2021.11.24 08:57
# ---------------
# 177
# 제목:  첼시에 4골차 '굴욕' 당한 유벤투스, 토티에게 당한 전설적 경기 이후 17년 만
# 날짜:  2021.11.24 08:56
# ---------------
# 178
# 제목:  보누치의 각성, "첼시전은 교훈, 긴장 푸는 순간 끝장"
# 날짜:  2021.11.24 08:53
# ---------------
# 179
# 제목:  맨유의 캐릭 대행, "이번 승리는 솔샤르 위한 것"
# 날짜:  2021.11.24 08:51
# ---------------
# 180
# 제목:  [UCL POINT] '초비상!' 바르사, 무려 '21년' 만에 조별리그 탈락 위기
# 날짜:  2021.11.24 08:51
# ---------------
# 181
# 제목:  "맨유행 루머는 루머일 뿐" 말문 연 포체티노 "PSG에서 행복하다"
# 날짜:  2021.11.24 08:46
# ---------------
# 182
# 제목:  [UCL리액션]'결승골+16강 견인' 호날두 "스페인에서 승리는 기뻐"
# 날짜:  2021.11.24 08:44
# ---------------
# 183
# 제목:  솔샤르 감독 경질한 맨유, 호날두 결승골로 UCL 16강 진출
# 날짜:  2021.11.24 08:39
# ---------------
# 184
# 제목:  [UCL인터뷰]매과이어 "오늘 승리가 시작점될 것"
# 날짜:  2021.11.24 08:36
# ---------------
# 185
# 제목:  이승우, 신트트라위던과 계약해지… "새로운 둥지 물색한다"
# 날짜:  2021.11.24 08:34
# ---------------
# 186
# 제목:  솔샤르 시즌2 나오나...캐릭 코치 데뷔승에 “당장 맨유 감독 해”
# 날짜:  2021.11.24 08:34
# ---------------
# 187
# 제목:  '단기로 일하실 분?' 맨유, 전 바르사 감독 임시 선임 고려
# 날짜:  2021.11.24 08:31
# ---------------
# 188
# 제목:  "맨유엔 관심 없어서요" 클롭 감독, 솔샤르 경질 질문에 재치있게 답변
# 날짜:  2021.11.24 08:31
# ---------------
# 189
# 제목:  "트로피 없어도, 포체티노는 훌륭해" 펩이 말한 '좋은 감독'의 조건
# 날짜:  2021.11.24 08:31
# ---------------
# 190
# 제목:  SON, 델피에로와 인증샷 "트루 레전드 만나 영광"
# 날짜:  2021.11.24 08:30
# ---------------
# 191
# 제목:  “한국의 메시 이승우, 벨기에 떠났다” 日 관심
# 날짜:  2021.11.24 08:24
# ---------------
# 192
# 제목:  메시 떠난 바르셀로나, 챔스 16강도 쉽게 못가네…벤피카와 0-0 무승부
# 날짜:  2021.11.24 08:23
# ---------------
# 193
# 제목:  "역시 호날두"… 맨유, 비야레알 꺾고 16강행 확정
# 날짜:  2021.11.24 08:20
# ---------------
# 194
# 제목:  "손흥민이 왜 아직도 1위지?" 일부 토트넘 팬들, 팀내 1위 SON 평가에 '불만'
# 날짜:  2021.11.24 08:19
# ---------------
# 195
# 제목:  "황인범, 소치전 의심없는 최고의 선수" 지역 매체 극찬
# 날짜:  2021.11.24 08:13
# ---------------
# 196
# 제목:  [UCL 리액션] 캐릭 대행은 마냥 웃지 않았다..."이번 승리, 솔샤르 위한 것"
# 날짜:  2021.11.24 08:11
# ---------------
# 197
# 제목:  첼시 유스 3인방 득점포, '맨유 베컴 세대' 못지않은 기록
# 날짜:  2021.11.24 08:11
# ---------------
# 198
# 제목:  ‘김민재 MOM 경기’서 페네르바체 팬 1명 사망...“너무 기뻐 심장마비”
# 날짜:  2021.11.24 08:04
# ---------------
# 199
# 제목:  이승우, 신트트라위던과 계약 해지…국내행 모색할 듯
# 날짜:  2021.11.24 08:04
# ---------------
# 200
# 제목:  "경배하라", 슈퍼맨처럼 날아서 첼시 구한 37세 노장 수비수
# 날짜:  2021.11.24 08:01

# %%
df=pd.DataFrame(result)
df
# Out:
#                                                  제목                날짜
# 0             "이게 샴페인 축구!"…첼시 유스 활약에 '선배' 조 콜, 함박웃음  2021.11.24 18:46
# 1                      벨기에 신트트라위던VV와 결별 이승우, 국내 복귀?  2021.11.24 18:44
# 2        'CR800'호날두, 데뷔 20주년 앞두고 800호골 금자탑…연 평균 42골  2021.11.24 18:34
# 3                 임시 감독 찾는 맨유, '라리가 우승 2회' 발베르데와 접촉  2021.11.24 18:31
# 4     '자격 있다!' 맨유 선수들 더 신났다, '7300만 파운드 스타' 드디어 득점포  2021.11.24 18:27
# ..                                              ...               ...
# 195  [UCL 리액션] 캐릭 대행은 마냥 웃지 않았다..."이번 승리, 솔샤르 위한 것"  2021.11.24 08:11
# 196               첼시 유스 3인방 득점포, '맨유 베컴 세대' 못지않은 기록  2021.11.24 08:11
# 197      ‘김민재 MOM 경기’서 페네르바체 팬 1명 사망...“너무 기뻐 심장마비”  2021.11.24 08:04
# 198                    이승우, 신트트라위던과 계약 해지…국내행 모색할 듯  2021.11.24 08:04
# 199              "경배하라", 슈퍼맨처럼 날아서 첼시 구한 37세 노장 수비수  2021.11.24 08:01
#
# [200 rows x 2 columns]
